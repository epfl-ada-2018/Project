# %%
import numpy as np
import pandas as pd
import json
import matplotlib.pyplot as plt
import tqdm

# %% [markdown]
# ### read data

# %%
#read cleaned ingredients
ingredients = open("../data/recipeClean/ingredients.txt", mode='r', buffering=-1, encoding="ISO-8859-1", errors=None, newline=None, closefd=True, opener=None)
content = ingredients.readlines()

#read usda mapping
ing_mapping = json.load(open("./../generated/ing_usda_mapping.json"))

#read usda id description
item_describe = json.load(open("./../generated/usda_id_describe.json"))

# %% [markdown]
# ### study mapping

# %% [markdown]
# > Ingredients have been mapped to USDA food items. We first identify the ingredients that have been mapped to the same food item and find a representative name for them.

# %% [markdown]
# #### spot collisions

# %%
mapped_ids = [ing_mapping[k] for k in ing_mapping]

#build dict to store collisions
collisions = {}

for m in tqdm.tqdm(ing_mapping) :
    if ing_mapping[m] not in collisions.keys() :
        collisions[ing_mapping[m]] = [m]
        
    else :
        collisions[ing_mapping[m]].append(m)
# Out:
# 100%|██████████| 4448/4448 [00:00<00:00, 760828.03it/s]

# %% [markdown]
# #### find representative name for each group

# %%
import collections


item_number = 43
proportion = 0.5

no_representative_keys = []
representative_keys = []

for i, c in tqdm.tqdm(enumerate(collisions)) :
    
    all_items = " ".join(collisions[c]).split(" ")
    counter = collections.Counter()
    counter.update(all_items)

    #find common names
    common_names = [x[0] for x in counter.most_common() if x[1] > len(collisions[c])*proportion]

    #order them if multiple
    if len(common_names) == 0 :
        no_representative_keys.append(c)

    elif len(common_names) == 1 :
        representative_keys.append((c, common_names[0]))

    else :
        #determine order

        #case 1, there exist an entry with only wanted words
        exact_match = [x.split(" ") for x in collisions[c] if (len(set(common_names).difference(set(x.split(" "))))== 0)]
        if len(exact_match) != 0 :
            representative_keys.append((c, " ".join(exact_match[0])))

        #case 2, no exact match
        else :

            all_words_collisions = [x.split(" ") for x in collisions[c] if set(common_names).issubset(set(x.split(" ")))]

            index_tuples = [ (word, index) for collision in all_words_collisions for index, word in enumerate(collision) if (word in common_names)]

            index_counts = np.array([0]*len(common_names))

            #average the relative indices
            for it in index_tuples :
                word_index = common_names.index(it[0])
                index_counts[word_index] += it[1]

            index_counts = index_counts

            common_names_ordered = " ".join([common_names[i] for i in np.argsort(index_counts)])
            representative_keys.append((c, common_names_ordered))
# Out:
# 1156it [00:00, 60688.86it/s]

# %% [markdown]
# > Some ingredients may have been mapped to the same representative without having the same usda matching. Did it happened ?

# %%
con = collections.Counter()
con.update([x[1] for x in representative_keys])
len([c for c in con.most_common() if c[1] >=2])
# Out:
# 39

# %%
representative_keys
# Out:
# [(2047, 'salt'),
#  (11282, 'onion'),
#  (1145, 'butter'),
#  (14555, 'water'),
#  (1123, 'egg'),
#  (19334, 'sugar'),
#  (2030, 'black pepper'),
#  (4053, 'olive oil'),
#  (11976, 'pepper'),
#  (11215, 'garlic'),
#  (20481, 'all-purpose flour'),
#  (11695, 'tomato'),
#  (1078, 'milk'),
#  (4513, 'vegetable'),
#  (11165, 'cilantro'),
#  (11297, 'parsley'),
#  (2050, 'vanilla'),
#  (11216, 'ginger'),
#  (9152, 'juice of lemon'),
#  (16124, 'soy sauce'),
#  (11124, 'carrot'),
#  (19336, 'sugar'),
#  (2014, 'cumin'),
#  (2010, 'cinnamon'),
#  (11292, 'green onion'),
#  (2044, 'basil'),
#  (1146, 'parmesan cheese'),
#  (2027, 'oregano'),
#  (11548, 'tomato'),
#  (2049, 'thyme'),
#  (5327, 'chicken breast'),
#  (11362, 'potato'),
#  (5277, 'chicken broth'),
#  (14155, 'soda'),
#  (9160, 'lime juice'),
#  (2020, 'garlic powder'),
#  (2009, 'chili powder'),
#  (1056, 'sour cream'),
#  (2004, 'bay'),
#  (2028, 'spice'),
#  (16117, 'flour'),
#  (1270, 'cheddar cheese'),
#  (9150, 'lemon'),
#  (2031, 'cayenne pepper'),
#  (4058, 'sesame oil'),
#  (2025, 'nutmeg'),
#  (11333, 'green bell pepper'),
#  (15270, 'shrimp'),
#  (19296, 'honey'),
#  (9159, 'lime'),
#  (4047, 'oil'),
#  (1173, 'white wine'),
#  (1053, 'heavy whipping cream'),
#  (11143, 'celery'),
#  (11291, 'scallion'),
#  (5332, 'chicken'),
#  (11950, 'mushroom'),
#  (11677, 'shallot'),
#  (11632, 'salt and pepper'),
#  (4529, 'almond'),
#  (42289, 'oil'),
#  (1017, 'cream cheese'),
#  (4679, 'cooking spray'),
#  (11457, 'spinach'),
#  (1125, 'egg yolk'),
#  (13355, 'beef'),
#  (1124, 'egg white'),
#  (2011, 'clove'),
#  (2013, 'coriander'),
#  (16104, 'bacon'),
#  (6971, 'sauce'),
#  (11286, 'yellow onion'),
#  (2064, 'mint'),
#  (20314, 'corn'),
#  (11979, 'jalapeno pepper'),
#  (1230, 'buttermilk'),
#  (12142, 'pecan'),
#  (11953, 'zucchini'),
#  (2063, 'rosemary'),
#  (42304, 'mozzarella'),
#  (9299, 'raisin'),
#  (43217, 'tomato sauce'),
#  (16014, 'black bean'),
#  (35140, 'bread'),
#  (2069, 'balsamic'),
#  (12117, 'coconut milk'),
#  (42178, 'mayonnaise'),
#  (12156, 'walnut'),
#  (20133, 'rice'),
#  (9038, 'avocado'),
#  (15089, 'fish sauce'),
#  (2068, 'wine'),
#  (12023, 'sesame seed'),
#  (11270, 'mustard'),
#  (9207, 'orange juice'),
#  (2048, 'vinegar'),
#  (43406, 'yeast'),
#  (2043, 'turmeric'),
#  (27054, 'salsa'),
#  (20027, 'cornstarch'),
#  (2032, 'white pepper'),
#  (35239, 'tortilla'),
#  (2026, 'onion powder'),
#  (11205, 'cucumber'),
#  (20086, 'flour tortilla'),
#  (9279, 'plum'),
#  (11537, 'green chily'),
#  (11935, 'ketchup'),
#  (10219, 'pork'),
#  (4073, 'margarine'),
#  (2015, 'curry'),
#  (35134, 'corn'),
#  (2001, 'allspice'),
#  (13000, 'beef steak'),
#  (11156, 'chive'),
#  (19165, 'cocoa powder'),
#  (1019, 'feta cheese'),
#  (2038, 'sage'),
#  (11304, 'pea'),
#  (16093, 'peanut'),
#  (4615, 'shortening'),
#  (11109, 'cabbage'),
#  (9205, 'orange'),
#  (5674, 'chicken'),
#  (4602, 'cinnamon stick'),
#  (11980, 'green chili pepper'),
#  (11052, 'green bean'),
#  (1025, 'cheese'),
#  (4042, 'peanut oil'),
#  (2054, 'caper'),
#  (1054, 'cream'),
#  (11209, 'eggplant'),
#  (11578, 'vegetable'),
#  (19351, 'corn syrup'),
#  (11257, 'lettuce'),
#  (7030, 'ham'),
#  (7926, 'italian'),
#  (9316, 'strawberry'),
#  (1116, 'plain yogurt'),
#  (11722, 'bean'),
#  (20450, 'rice'),
#  (9040, 'banana'),
#  (11246, 'leek'),
#  (5171, 'turkey'),
#  (2006, 'cardamom'),
#  (2045, 'dill'),
#  (43476, 'tofu'),
#  (6961, 'pepper sauce'),
#  (16059, 'chili'),
#  (11182, 'corn kernel'),
#  (35131, 'cornmeal'),
#  (20649, 'wheat flour'),
#  (9004, 'apple'),
#  (9429, 'pineapple'),
#  (2037, 'saffron'),
#  (4542, 'fat chicken broth'),
#  (1036, 'ricotta cheese'),
#  (19879, 'chocolate chip'),
#  (16032, 'kidney bean'),
#  (16166, 'chocolate'),
#  (7955, 'sausage'),
#  (6631, 'chile'),
#  (16157, 'chickpea'),
#  (6150, 'sauce'),
#  (20126, 'spaghetti'),
#  (11962, 'chile pepper'),
#  (11240, 'mushroom'),
#  (9236, 'peach'),
#  (2018, 'fennel seed'),
#  (9078, 'cranberry'),
#  (2076, 'seasoning'),
#  (20033, 'oat'),
#  (42291, 'peanut butter'),
#  (11951, 'yellow bell pepper'),
#  (43128, 'chicken'),
#  (2024, 'mustard seed'),
#  (20445, 'long-grain rice'),
#  (20129, 'wheat bread'),
#  (11353, 'russet potato'),
#  (27063, 'enchilada sauce'),
#  (20091, 'pasta'),
#  (2041, 'tarragon'),
#  (11090, 'broccoli'),
#  (93600, 'green'),
#  (20084, 'cake'),
#  (4518, 'all purpose flour'),
#  (7003, 'beer'),
#  (11278, 'okra'),
#  (11251, 'romaine lettuce'),
#  (16069, 'lentil'),
#  (11954, 'tomatillo'),
#  (11011, 'asparagu'),
#  (6972, 'chili sauce'),
#  (20090, 'brown rice'),
#  (9176, 'mango'),
#  (11429, 'radish'),
#  (7927, 'italian sausage'),
#  (9050, 'blueberry'),
#  (20409, 'noodle'),
#  (11422, 'pumpkin'),
#  (9302, 'raspberry'),
#  (9156, 'lemon'),
#  (10060, 'pork tenderloin'),
#  (11977, 'serrano'),
#  (1040, 'swiss cheese'),
#  (2023, 'marjoram'),
#  (1323, 'ghee'),
#  (16146, 'pinto bean'),
#  (11167, 'yellow corn meal'),
#  (19353, 'syrup'),
#  (11485, 'butternut squash'),
#  (1303, 'half'),
#  (23656, 'flank steak'),
#  (43392, 'heart'),
#  (15079, 'salmon fillet'),
#  (11959, 'arugula'),
#  (2075, 'mix'),
#  (11238, 'shiitake mushroom cap'),
#  (20050, 'long grain white rice'),
#  (11268, 'shiitake'),
#  (7051, 'loaf sourdough bread'),
#  (6633, 'sriracha'),
#  (11135, 'cauliflower'),
#  (12087, 'cashew nut'),
#  (9021, 'apricot'),
#  (19271, 'ice'),
#  (2002, 'anise'),
#  (16056, 'garbanzo bean'),
#  (10072, 'pork shoulder'),
#  (9502, 'granny smith apple'),
#  (20120, 'penne'),
#  (9442, 'juice'),
#  (1156, 'goat cheese'),
#  (11957, 'fennel bulb'),
#  (1029, 'part-skim mozzarella cheese'),
#  (11974, 'grape'),
#  (20035, 'quinoa'),
#  (9020, 'applesauce'),
#  (20083, 'white bread'),
#  (2055, 'horseradish'),
#  (9452, 'pineapple juice'),
#  (1284, 'greek yogurt'),
#  (1035, 'provolone cheese'),
#  (19312, 'pie crust'),
#  (16399, 'creamy peanut butter'),
#  (1038, 'romano cheese'),
#  (17224, 'lamb'),
#  (2007, 'celery seed'),
#  (20028, 'couscou'),
#  (9544, 'powder'),
#  (4501, 'cocoa'),
#  (15164, 'mussel'),
#  (9421, 'date'),
#  (20109, 'egg noodle'),
#  (15001, 'anchovy'),
#  (11080, 'beet'),
#  (1175, 'full fat coconut milk'),
#  (2034, 'poultry seasoning'),
#  (43273, 'cottage cheese'),
#  (15078, 'salmon'),
#  (11116, 'bok choy'),
#  (9070, 'cherry'),
#  (11233, 'kale'),
#  (12147, 'pine nut'),
#  (11492, 'squash'),
#  (9083, 'currant'),
#  (9018, 'apple juice'),
#  (16249, 'coffee'),
#  (4002, 'lard'),
#  (14025, 'whiskey'),
#  (10036, 'pork chop'),
#  (5312, 'chicken wing'),
#  (35078, 'herb'),
#  (1004, 'blue cheese dressing'),
#  (7063, 'pork sausage'),
#  (2005, 'caraway seed'),
#  (11943, 'pimento'),
#  (11973, 'chipotle in adobo'),
#  (16262, 'hazelnut'),
#  (15157, 'clam'),
#  (2035, 'pumpkin pie spice'),
#  (19095, 'vanilla ice cream'),
#  (16106, 'meat'),
#  (19177, 'gelatin'),
#  (11252, 'iceberg lettuce'),
#  (16118, 'flour'),
#  (2046, 'yellow mustard'),
#  (10024, 'pork loin'),
#  (11564, 'turnip'),
#  (11886, 'juice'),
#  (1251, 'mexican cheese blend'),
#  (2033, 'poppy seed'),
#  (4548, 'box yellow cake mix'),
#  (1039, 'cheese'),
#  (11161, 'collard green'),
#  (12151, 'pistachio'),
#  (19137, 'topping'),
#  (9322, 'tamarind'),
#  (1228, 'queso fresco'),
#  (1023, 'gruyere'),
#  (11026, 'bamboo'),
#  (16112, 'miso'),
#  (15172, 'scallop'),
#  (23079, 'chuck'),
#  (19018, 'fruit'),
#  (9252, 'pear'),
#  (27048, 'steak'),
#  (1144, 'egg substitute'),
#  (19314, 'pie'),
#  (11298, 'parsnip'),
#  (9042, 'blackberry'),
#  (17137, 'sirloin'),
#  (15261, 'tilapia'),
#  (7932, 'fat-free cream of chicken soup'),
#  (7081, 'turkey breast'),
#  (12698, 'tahini'),
#  (4583, 'oil'),
#  (16049, 'white bean'),
#  (9003, 'food'),
#  (1212, 'milk'),
#  (20058, 'chinese rice wine'),
#  (1020, 'fontina cheese'),
#  (1151, 'nonfat milk'),
#  (11527, 'tomato'),
#  (9193, 'ripe'),
#  (11978, 'ancho'),
#  (13353, 'beef stew meat'),
#  (43276, 'cheese spread'),
#  (13929, 'beef sirloin steak'),
#  (1267, 'cotija'),
#  (20082, 'self-rising flour'),
#  (7057, 'pepperoni'),
#  (7943, 'lemon pepper'),
#  (13974, 'chuck roast'),
#  (20017, 'masa'),
#  (9272, 'pineapple chunk in juice'),
#  (4645, 'vegetable oil for frying'),
#  (13346, 'beef brisket'),
#  (11533, 'ripe tomato'),
#  (11031, 'lima bean'),
#  (11439, 'sauerkraut'),
#  (15127, 'tuna'),
#  (11987, 'oyster'),
#  (5075, 'chicken leg'),
#  (17433, 'veal'),
#  (12220, 'seed'),
#  (1179, 'non-fat sour cream'),
#  (13047, 'hamburger'),
#  (11147, 'swiss chard'),
#  (10005, 'pork'),
#  (1265, 'fat cheddar cheese'),
#  (6123, 'onion soup mix'),
#  (16026, 'great northern bean'),
#  (19365, 'marshmallow'),
#  (43278, 'american cheese'),
#  (2022, 'mace'),
#  (43134, 'fillet'),
#  (7019, 'chorizo'),
#  (11958, 'pickle relish'),
#  (35137, 'yellow'),
#  (1058, 'dressing'),
#  (11007, 'artichoke'),
#  (9423, 'puree'),
#  (1287, 'greek style plain yogurt'),
#  (11118, 'kimchi'),
#  (11603, 'jicama'),
#  (9328, 'maraschino cherry'),
#  (17074, 'leg of lamb'),
#  (4545, 'sunflower oil'),
#  (9089, 'fig'),
#  (20060, 'rice'),
#  (4576, 'fat'),
#  (11098, 'sprout'),
#  (23441, 'beef tenderloin'),
#  (16037, 'navy bean'),
#  (11260, 'white mushroom'),
#  (20078, 'wheat germ'),
#  (11937, 'dill pickle'),
#  (12040, 'sunflower seed'),
#  (15175, 'squid'),
#  (11300, 'sugar pea'),
#  (20444, 'long-grain white rice'),
#  (6963, 'broth'),
#  (11399, 'pastry puff sheet'),
#  (19206, 'vanilla pudding mix'),
#  (20105, 'macaroni'),
#  (19087, 'white chocolate'),
#  (20068, 'tapioca'),
#  (2019, 'fenugreek'),
#  (17086, 'lamb shoulder'),
#  (1225, 'de'),
#  (16080, 'mung bean sprout'),
#  (19303, 'marmalade'),
#  (9501, 'delicious'),
#  (19119, 'chunky salsa'),
#  (5115, 'roasting chicken'),
#  (10946, 'pork shoulder boston butt'),
#  (12116, 'coconut cream'),
#  (15038, 'halibut'),
#  (9218, 'mandarin orange'),
#  (9110, 'berry'),
#  (16162, 'silken tofu'),
#  (14288, 'lemonade'),
#  (35136, 'white cornmeal'),
#  (16091, 'raw spanish peanut'),
#  (9133, 'seedless grape'),
#  (11266, 'mushroom'),
#  (19064, 'roll'),
#  (12014, 'pumpkin seed'),
#  (11547, 'tomato puree'),
#  (5027, 'chicken liver'),
#  (15015, 'cod'),
#  (20330, 'hominy'),
#  (16237, 'squares chocolate'),
#  (1229, 'white cheddar cheese'),
#  (11211, 'edamame'),
#  (7031, 'italian salad dressing'),
#  (5356, 'rotisserie chicken'),
#  (9202, 'navel orange'),
#  (19246, 'white'),
#  (42063, 'liquid'),
#  (11772, 'cream style corn'),
#  (10094, 'pork loin chop'),
#  (15109, 'fish fillet'),
#  (20114, 'soba noodle'),
#  (20030, 'white hominy'),
#  (9307, 'rhubarb'),
#  (23163, 'skirt'),
#  (11414, 'salad dressing'),
#  (20061, 'white flour'),
#  (20016, 'corn flour'),
#  (9039, 'ripe avocado'),
#  (27064, 'wasabi'),
#  (15117, 'tuna steak'),
#  (19163, 'xanthan gum'),
#  (20005, 'barley'),
#  (11952, 'radicchio'),
#  (20066, 'semolina'),
#  (15147, 'lobster'),
#  (35187, 'plain bread crumb'),
#  (19719, 'apricot'),
#  (19868, 'splenda'),
#  (20466, 'semolina flour'),
#  (11941, 'pickle'),
#  (23066, 'beef rib short'),
#  (6960, 'alfredo sauce'),
#  (20015, 'corn'),
#  (35238, 'tea'),
#  (11601, 'yam'),
#  (16261, 'french'),
#  (4674, 'buttery cracker'),
#  (20070, 'almond flour'),
#  (10225, 'pork loin roast'),
#  (20452, 'short-grain white rice'),
#  (11265, 'portabella mushroom'),
#  (5135, 'chicken meat'),
#  (4698, 'canola'),
#  (11370, 'hash brown potato'),
#  (1117, 'fat yogurt'),
#  (35092, 'sun-tomato in oil'),
#  (19120, 'milk chocolate chip'),
#  (43299, 'curd'),
#  (5143, 'duck'),
#  (11482, 'acorn squash'),
#  (19144, 'grand marnier'),
#  (11096, 'broccoli rabe'),
#  (9326, 'watermelon'),
#  (11119, 'chinese cooking wine'),
#  (10165, 'salt pork'),
#  (7934, 'kielbasa'),
#  (11114, 'savoy cabbage'),
#  (1223, 'protein powder'),
#  (11531, 'tomato in juice'),
#  (1187, 'nonfat yogurt'),
#  (4665, 'pastry'),
#  (7074, 'sausage link'),
#  (5665, 'lean turkey'),
#  (11446, 'seaweed'),
#  (1006, 'brie cheese'),
#  (43114, 'vermicelli'),
#  (19348, 'chocolate syrup'),
#  (16279, 'house seasoning'),
#  (23175, 'rib eye steak'),
#  (17000, 'prime rib roast'),
#  (19188, 'chocolate pudding mix'),
#  (19909, 'sugar substitute'),
#  (14303, 'limeade'),
#  (43382, 'cranberry juice'),
#  (19201, 'vanilla pudding'),
#  (1186, 'fat cream cheese'),
#  (19908, "confectioners' sugar for dusting"),
#  (16161, 'soft tofu'),
#  (13973, 'beef chuck roast'),
#  (1293, 'greek'),
#  (9286, 'pomegranate'),
#  (1159, 'soft goat cheese'),
#  (19029, 'shell'),
#  (1295, 'vanilla yogurt'),
#  (20025, 'self-rising cornmeal'),
#  (19132, 'almond milk'),
#  (43132, 'meatball'),
#  (12001, 'cardamom seed'),
#  (9340, 'asian'),
#  (2053, 'chinese black vinegar'),
#  (16119, 'meal'),
#  (9422, 'or'),
#  (16156, 'chunky peanut butter'),
#  (19070, 'butterscotch'),
#  (12093, 'chestnut'),
#  (19309, 'creme'),
#  (2008, 'chervil'),
#  (9226, 'papaya'),
#  (1011, 'colby jack cheese'),
#  (17017, 'lamb shank'),
#  (20077, 'wheat bran'),
#  (1012, 'curd cottage cheese'),
#  (2039, 'savory'),
#  (11981, 'pepper'),
#  (20113, 'chinese egg noodle'),
#  (11213, 'endive'),
#  (9117, 'white'),
#  (11475, 'summer squash'),
#  (16235, 'plain'),
#  (4511, 'safflower oil'),
#  (35138, 'squash'),
#  (19154, 'sesame'),
#  (11984, 'epazote'),
#  (7058, 'pimiento'),
#  (17080, 'shrimp - and deveined'),
#  (7912, 'roast'),
#  (43212, 'bacon bit'),
#  (10130, 'canadian bacon'),
#  (20080, 'flour for dusting'),
#  (1191, 'velveeta'),
#  (20012, 'bulgur'),
#  (11253, 'lettuce'),
#  (10088, 'sparerib'),
#  (7061, 'loaf french bread'),
#  (20065, 'flour'),
#  (23407, 'beef bouillon cube'),
#  (7954, 'breakfast sausage'),
#  (9132, 'seedless green grape'),
#  (11435, 'rutabaga'),
#  (13227, 'beef shank'),
#  (15139, 'crab'),
#  (12131, 'nut'),
#  (19184, 'chocolate cake mix'),
#  (20087, 'wheat'),
#  (9081, 'cranberry sauce'),
#  (1193, "breakstone'"),
#  (11557, 'and'),
#  (9542, 'plantain'),
#  (1022, 'gouda'),
#  (1180, 'fat sour cream'),
#  (10207, 'pork back rib'),
#  (9215, 'orange flower water'),
#  (4609, 'bacon'),
#  (4528, 'walnut oil'),
#  (19183, 'baking chocolate'),
#  (9546, 'tart cherry'),
#  (11322, 'peas and carrot'),
#  (20011, 'buckwheat flour'),
#  (11250, 'boston lettuce'),
#  (11982, 'pasilla'),
#  (16398, 'smooth peanut butter'),
#  (19227, 'frosting'),
#  (20062, 'rye'),
#  (11354, 'white potato'),
#  (27066, 'sauce'),
#  (19917, 'pretzel'),
#  (9191, 'nectarine'),
#  (19134, 'cereal'),
#  (15091, 'sea bass fillet'),
#  (15101, 'snapper'),
#  (16082, 'noodle'),
#  (11989, 'straw mushroom'),
#  (11149, 'chayote'),
#  (9404, 'pink grapefruit'),
#  (9414, 'bosc pear'),
#  (35073, 'soup'),
#  (19921, 'candy'),
#  (1239, 'cookie'),
#  (31021, 'hash brown'),
#  (15085, 'salmon'),
#  (17180, 'rabbit'),
#  (44158, 'pie'),
#  (12155, 'english'),
#  (5145, 'duck breast'),
#  (19297, 'jam'),
#  (23067, 'short rib'),
#  (15130, 'whitefish'),
#  (11568, 'turnip green'),
#  (9415, 'drops green food coloring'),
#  (23094, 'beef for stew'),
#  (11900, 'white corn'),
#  (48052, 'vital wheat gluten'),
#  (35144, 'dumpling'),
#  (19918, 'stevia'),
#  (20038, 'drops food coloring'),
#  (19074, 'caramel'),
#  (6618, 'coconut sugar'),
#  (9100, 'cocktail cherry'),
#  (1314, 'plain nonfat yogurt'),
#  (1034, 'port'),
#  (43130, 'dog'),
#  (5653, 'pita bread round'),
#  (19912, 'sweetener'),
#  (14355, 'black tea'),
#  (13350, 'beef'),
#  (5165, 'turkey meat'),
#  (17426, 'cutlet'),
#  (20135, 'wheat'),
#  (35190, 'filet'),
#  (2016, 'dill seed'),
#  (15110, 'swordfish'),
#  (16147, 'burger'),
#  (9552, 'seedless raspberry jam'),
#  (1047, 'cheese food'),
#  (7036, 'mild italian sausage'),
#  (15119, 'tuna in olive oil'),
#  (35030, 'or cranberry'),
#  (10040, 'center pork chop'),
#  (7915, 'chicken sausage'),
#  (9063, 'sour cherry'),
#  (23372, 'steak'),
#  (27059, 'peanut sauce'),
#  (10149, 'ham steak'),
#  (42155, 'fat monterey jack cheese'),
#  (5311, 'chicken'),
#  (6121, 'gravy'),
#  (19895, 'caramel ice cream topping'),
#  (9128, 'juice'),
#  (19375, 'glaze'),
#  (7018, 'chicken'),
#  (19157, 'mini chocolate chip'),
#  (43543, 'imitation crabmeat'),
#  (17278, 'shank'),
#  (20054, 'glutinous rice'),
#  (1286, 'nonfat greek yogurt'),
#  (9503, 'gala'),
#  (7028, 'deli ham'),
#  (16114, 'tempeh'),
#  (7201, 'oscar mayer bacon'),
#  (20140, 'spelt'),
#  (15048, 'jack'),
#  (11697, 'arrowroot'),
#  (9251, 'peach nectar'),
#  (19294, 'apple butter'),
#  (11445, 'kelp'),
#  (11082, 'solid pack pumpkin'),
#  (11771, 'yellow food coloring'),
#  (23607, 'new york strip steak'),
#  (9184, 'honeydew melon'),
#  (9412, 'bartlett'),
#  (12195, 'almond butter'),
#  (15138, 'imitation crab meat'),
#  (17195, 'lamb stew meat'),
#  (19109, 'wafer'),
#  (13335, 'suet'),
#  (4001, 'fat beef broth'),
#  (35240, 'corn bread mix'),
#  (5015, 'fryer chicken'),
#  (9221, 'tangerine'),
#  (6118, 'brown'),
#  (5309, 'cornish game hen'),
#  (4708, 'fat mayonnaise'),
#  (1030, 'muenster'),
#  (17078, 'lamb loin chop'),
#  (1094, 'fat-free buttermilk'),
#  (9351, 'fruit cocktail'),
#  (7973, 'turkey bacon'),
#  (11450, 'soybean'),
#  (11154, 'cilantro root'),
#  (10006, 'pork fat'),
#  (20031, 'millet'),
#  (12061, 'almond meal'),
#  (9149, 'kumquat'),
#  (15186, 'tuna in water'),
#  (1059, 'stir fry vegetable blend'),
#  (19333, 'egg beaten with water'),
#  (4594, 'sardine'),
#  (19300, 'jelly'),
#  (16123, 'shoyu'),
#  (17082, 'rack of lamb'),
#  (35146, 'mutton'),
#  (15031, 'grouper'),
#  (23181, 'back rib'),
#  (5193, 'turkey leg'),
#  (9504, 'fuji apple'),
#  (1199, 'fat half half'),
#  (16122, 'soy'),
#  (20075, 'soft'),
#  (7931, 'pork and bean'),
#  (6958, 'beef gravy'),
#  (42307, 'butter-margarine blend'),
#  (11963, 'nopale'),
#  (11199, 'yardlong bean'),
#  (14384, 'lemon-lime beverage'),
#  (15010, 'catfish'),
#  (13926, 'filet mignon'),
#  (15124, 'white'),
#  (11993, 'mushroom'),
#  (19332, 'lemon cake mix'),
#  (16172, 'fat-free bean'),
#  (1003, 'butter oil'),
#  (17343, 'venison'),
#  (14434, 'coca-cola'),
#  (1306, 'chocolate sauce'),
#  (6285, 'sour sauce'),
#  (23059, 'iron steak'),
#  (7040, 'liver'),
#  (19279, 'coffee bean'),
#  (19198, 'pistachio pudding mix'),
#  (19896, 'soft butter'),
#  (31033, 'artificial sweetener'),
#  (7972, 'italian style tomato'),
#  (16022, 'french'),
#  (11170, 'brine'),
#  (5307, 'cornish hen'),
#  (15035, 'haddock'),
#  (16101, 'pigeon pea'),
#  (6962, 'tabasco green pepper sauce'),
#  (5358, 'chicken breast meat'),
#  (4687, 'spread'),
#  (11518, 'taro'),
#  (19226, 'container betty crockerâ® rich & creamy chocolate frosting'),
#  (7050, 'mortadella'),
#  (17392, 'lamb'),
#  (43135, 'sandwich'),
#  (4664, 'icing'),
#  (16137, "taco bellâ® home originalsâ® 'n chunky salsa"),
#  (15115, 'trout'),
#  (1057, 'eggnog'),
#  (16171, 'vegetarian bean'),
#  (12006, 'chia seed'),
#  (9216, 'orange'),
#  (11669, 'wakame'),
#  (11239, 'chanterelle mushroom'),
#  (19270, 'chocolate ice cream'),
#  (15012, 'caviar'),
#  (14543, 'pink lemonade'),
#  (19130, 'gold'),
#  (11992, 'bottle white wine'),
#  (9296, 'quince'),
#  (5158, 'quail'),
#  (19340, 'sugar'),
#  (1166, 'asadero'),
#  (42040, 'grenadine syrup'),
#  (20036, 'long-grain brown rice'),
#  (14605, 'bottle lemon-lime beverage'),
#  (15143, 'dungeness crab'),
#  (23603, 'pot roast'),
#  (11672, 'pancake mix'),
#  (43344, 'preserve'),
#  (20076, 'wheat'),
#  (7045, 'pork stew meat'),
#  (11885, 'ounce tomato in juice'),
#  (15108, 'raw pumpkin seed'),
#  (9267, 'solid pack pumpkin puree'),
#  (19911, 'maple'),
#  (4617, 'stick margarine'),
#  (19364, 'caramel topping'),
#  (9036, 'apricot nectar'),
#  (19091, 'peppermint candy'),
#  (11696, 'tomato'),
#  (10080, 'pork'),
#  (10048, 'rib pork chop'),
#  (5284, 'turkey broth'),
#  (17353, 'lean lamb'),
#  (14431, 'cranberry juice cocktail'),
#  (9413, 'anjou pear'),
#  (16144, 'pink peppercorn'),
#  (9263, 'persimmon'),
#  (10963, 'sirloin tip roast'),
#  (11940, 'bread and butter pickle'),
#  (9118, 'white cheddar'),
#  (7914, 'italian sausage link'),
#  (11437, 'vegetable'),
#  (19194, 'butterscotch pudding mix'),
#  (19249, 'chocolate wafer cooky'),
#  (14604, 'bottle'),
#  (9370, 'peach in heavy syrup'),
#  (1031, 'philadelphia neufchatel cheese'),
#  (9144, 'jackfruit'),
#  (13023, 'brisket'),
#  (1088, 'lowfat buttermilk'),
#  (35054, 'octopus'),
#  (35150, 'silver'),
#  (11413, 'potato flour'),
#  (7942, 'truffle'),
#  (35091, 'head escarole'),
#  (19230, 'betty crockerâ® rich & creamy vanilla frosting'),
#  (10174, 'crawfish tail'),
#  (15107, 'white fish fillet'),
#  (90480, 'syrup'),
#  (15184, 'artichoke heart in water'),
#  (9135, 'grape juice'),
#  (11029, 'kidney'),
#  (9139, 'guava'),
#  (6307, 'kraft'),
#  (16074, 'thin'),
#  (17156, 'lean meat'),
#  (11467, 'yellow crookneck squash'),
#  (17154, 'veal scallop'),
#  (19110, 'chocolate bar'),
#  (6720, 'enchilada sauce mix'),
#  (15083, 'pink salmon'),
#  (20132, 'oat flour'),
#  (11024, 'bitter'),
#  (4601, 'stick'),
#  (5219, 'turkey breast cutlet'),
#  (12097, 'unpeeled'),
#  (35086, 'skin'),
#  (11001, 'alfalfa sprout'),
#  (13339, 'beef tongue'),
#  (23342, 'filet mignon steak'),
#  (9254, 'pear juice'),
#  (20008, 'buckwheat'),
#  (11489, 'winter squash'),
#  (16103, 'ranch style bean'),
#  (5282, 'foie gra'),
#  (16001, 'adzuki bean'),
#  (14075, 'sparkling water'),
#  (43026, 'sugar syrup'),
#  (20647, 'millet flour'),
#  (4581, 'oil'),
#  (11254, 'root'),
#  (9138, 'poha'),
#  (43137, 'meatloaf'),
#  (11913, 'corn-on-the cob'),
#  (16258, 'key lime'),
#  (7053, 'liver pate'),
#  (1162, 'fat greek yogurt'),
#  (19030, 'rum flavored'),
#  (15004, 'bass fillet'),
#  (6999, "campbell's cream of chicken soup"),
#  (16062, 'southern comfort'),
#  (4055, 'palm oil'),
#  (7015, 'bratwurst'),
#  (23073, 'country style bread'),
#  (5227, 'turkey wing'),
#  (4532, 'oil'),
#  (1014, 'nonfat cottage cheese'),
#  (1185, 'topping'),
#  (16115, 'gluten-free flour'),
#  (4630, 'margarine'),
#  (11955, 'tomato'),
#  (1305, 'lowfat milk'),
#  (43125, 'bean'),
#  (12104, "baker's angel flake coconut"),
#  (13325, 'beef liver'),
#  (23431, 'beef rib'),
#  (1167, 'chihuahua cheese'),
#  (10980, 'bone-in'),
#  (19383, 'english toffee bit'),
#  (9510,
#   'this recipe wa by professional chefs and has been down from bulk recipe by restaurant the food network kitchens chefs have not this recipe'),
#  (7059, 'polish sausage'),
#  (11382, 'granule'),
#  (4572, 'nutmeg'),
#  (9107, 'gooseberry'),
#  (11416, 'flower'),
#  (43589, 'fat swiss cheese'),
#  (12154, 'black walnut'),
#  (20648, 'sorghum flour'),
#  (4530, 'kernel'),
#  (16040, 'pink bean'),
#  (9185, 'mozzarella ball'),
#  (11062, 'french style green bean'),
#  (4669, 'vegetable oil for deep-frying'),
#  (42183, 'chocolate cookie crumb'),
#  (15054, 'monkfish'),
#  (20131, 'barley flour'),
#  (11555, 'classico&; tomato and basil sauce'),
#  (90560, 'snail'),
#  (9520, 'kiwifruit'),
#  (11276, 'new mexico chile'),
#  (1111, 'vanilla soy milk'),
#  (16260, "emeril's original essence"),
#  (11207, 'dandelion green'),
#  (15126, 'solid white tuna in water'),
#  (6126, 'turkey gravy'),
#  (23646, 'bottom roast'),
#  (7043, 'deli roast beef'),
#  (9164, 'lychee'),
#  (1026, 'kraft milk mozzarella cheese'),
#  (5109, 'shrimp and crab boil seasoning'),
#  (13342, 'flaked'),
#  (35028, 'cockle'),
#  (5295, 'roast turkey'),
#  (12119, 'coconut water'),
#  (11637, 'white'),
#  (16019, 'cranberry bean'),
#  (1140, 'quail egg'),
#  (7071, 'hard salami'),
#  (7919, 'turkey breakfast sausage'),
#  (12078, 'brazil nut'),
#  (11352, 'potatoes - and cubed'),
#  (12021, 'safflower'),
#  (11104, 'root beer'),
#  (19186, 'crisp'),
#  (11134, 'cassava'),
#  (9436, 'mango nectar'),
#  (20074, 'hard clam'),
#  (11655, 'juice'),
#  (11741, 'stalk lemongras'),
#  (23360, 'eye of roast'),
#  (13464, 'porterhouse steak'),
#  (27065, 'bean dip'),
#  (19107, 'hard'),
#  (4668, 'soy margarine'),
#  (5023, 'chicken gizzard'),
#  (16125, 'vegetable protein'),
#  (20124, 'whole-wheat'),
#  (1294, 'milk greek yogurt'),
#  (16035, 'royal icing'),
#  (1071, 'ounce'),
#  (9433, 'clementine'),
#  (19193, 'pudding'),
#  (42281, 'guar gum'),
#  (17383, 'lamb shoulder chop'),
#  (6114, 'au jus mix'),
#  (43365, 'and'),
#  (1203, 'splenda&; no calorie sweetener'),
#  (19166, 'dutch process cocoa'),
#  (14429, 'tap water'),
#  (35232, 'lily bud'),
#  (4551, 'or coconut'),
#  (19366, 'fat-free topping'),
#  (12012, 'hemp seed'),
#  (10938, 'bone-in ham'),
#  (19129, 'pancake syrup'),
#  (2074, 'sazon'),
#  (6142, 'sofrito sauce'),
#  (35143, 'chip plain tortilla'),
#  (7011, 'bologna'),
#  (9264, 'japanese breadcrumb'),
#  (15185, 'solid white tuna'),
#  (12036, 'sunflower kernel'),
#  (9294, 'juice'),
#  (43285, 'sugar-curing mixture'),
#  (23063, 'london broil beef'),
#  (10957, 'portobello cap'),
#  (17125, 'veal shoulder'),
#  (19104, 'fudge brownie mix'),
#  (35070, 'sea'),
#  (42148, 'miniature chocolate peanut butter'),
#  (43059, 'or'),
#  (9531, 'passion fruit juice'),
#  (15128, 'sushi grade tuna'),
#  (9297, 'seedless raisin'),
#  (17128, 'veal chop'),
#  (19880, 'butter pecan cake mix'),
#  (10004, 'pork neck bone'),
#  (17113, 'veal'),
#  (19920, 'fruit preserve'),
#  (1113, 'citric acid'),
#  (16243, 'fiber one cereal'),
#  (7088, 'bob evans&; original recipe sausage roll'),
#  (12088, 'cashew butter'),
#  (11663, 'agar'),
#  (1289, 'kefir'),
#  (5654, 'tenderloin'),
#  (9183, 'melon'),
#  (7950, 'frankfurter'),
#  (9528, 'ruby grapefruit'),
#  (2052, 'clear imitation vanilla'),
#  (9266, 'pineapple'),
#  (11086, 'beet green'),
#  (19355, 'sorghum syrup'),
#  (20116, 'soman'),
#  (15055, 'mullet'),
#  (42138, 'or mayonnaise'),
#  (13341, 'tripe'),
#  (19169, 'custard'),
#  (9265, 'fuyu persimmon'),
#  (19409, 'chocolate glaze'),
#  (19112, 'mini twist pretzel'),
#  (1188, 'process cheese sauce'),
#  (19202, 'sugar-free vanilla pudding mix'),
#  (10010, 'pork leg'),
#  (19172, 'lime gelatin mix'),
#  (35237, 'tamale filling'),
#  (23057, 'fat ranch dressing'),
#  (15136, 'king crab leg'),
#  (31036, 'mashed'),
#  (1032, 'ounce parmesan'),
#  (35148, 'stew'),
#  (1209, 'fat mexican cheese'),
#  (19097, 'orange sherbet'),
#  (9148, 'chinese'),
#  (23403, 'toast point'),
#  (17387, 'lamb loin'),
#  (20014, 'corn meal'),
#  (23053, 'beef shoulder'),
#  (9317, 'strawberry syrup'),
#  (11241, 'kohlrabi'),
#  (9262, 'pear nectar'),
#  (1018, 'edam'),
#  (9507, 'mango juice'),
#  (6120, 'chicken gravy'),
#  ...]

# %% [markdown]
# > It indeed happened, should we map them to the same usda entry ? let's look at the different ingredient sets

# %%
for c in con.most_common()[:4] :
    print("Group matching : ", c[0], " (", c[1], " times)")
    matching_keys = []
    for key in representative_keys :
        if key[1]== c[0] :
            print("\t ", item_describe[str(key[0])])
            
            for ing in collisions[key[0]] :
                print("\t\t ", ing)
            print("\n")
            
    print("\n")
# Out:
# Group matching :  tomato  ( 5  times)
# 	  Tomatoes, orange, raw
# 		  tomato
# 		  italian tomato
# 		  or tomato
#
#
# 	  Tomato powder
# 		  baking powder
# 		  cherry tomato
# 		  roma tomato
# 		  coriander powder
# 		  tomato purã©e
# 		  tomato soup
# 		  vine tomato
# 		  italian-style tomato
# 		  heirloom tomato
# 		  ounce tomato
# 		  rotel tomato
# 		  beefsteak tomato
# 		  fire tomato
# 		  teaspoon(s) baking powder
# 		  double-acting baking powder
# 		  muir glenâ® tomato
# 		  petite tomato
# 		  mexican-style tomato
# 		  ( oz) tomato
# 		  tomato pesto
# 		  san marzano tomato
# 		  oz tomato
# 		  calumet baking powder
# 		  tea powder
# 		  vine-ripe tomato
# 		  coarsely tomato
# 		  goldâ® tomato
# 		  double tomato
# 		  cream of tomato soup
# 		  cacao powder
# 		  -ounce tomato
# 		  sun tomato
# 		  teardrop tomato
#
#
# 	  Tomatoes, green, raw
# 		  green tomato
# 		  tomato salsa
# 		  campbell's tomato soup
# 		  tomato with green chiles
# 		  tomato with chiles
#
#
# 	  Tomatoes, yellow, raw
# 		  tomatoes -
# 		  yellow tomato
# 		  yellow cherry tomato
# 		  tomato -
# 		  chunky tomato salsa
#
#
# 	  Tomatoes, sun-dried
# 		  tomato with liquid
# 		  peel tomato
#
#
#
#
# Group matching :  oil  ( 5  times)
# 	  Oil, coconut
# 		  oil
# 		  coconut
# 		  coconut oil
# 		  neutral oil
# 		  truffle oil
# 		  coconut amino
# 		  coconut rum
# 		  virgin coconut oil
# 		  oil olife
# 		  garlic-olive oil
# 		  dende oil
#
#
# 	  Oil, corn and canola
# 		  canola oil
# 		  corn oil
# 		  mazola corn oil
# 		  pompeian canola oil and virgin olive oil
#
#
# 	  Oil, mustard
# 		  chili oil
# 		  mustard oil
#
#
# 	  Oil, avocado
# 		  avocado oil
# 		  annatto oil
#
#
# 	  Oil, hazelnut
# 		  hazelnut oil
# 		  herb oil
#
#
#
#
# Group matching :  chicken  ( 5  times)
# 	  Chicken, ground, raw
# 		  chicken
# 		  chicken stock
# 		  chicken bouillon granule
# 		  chicken bouillon
# 		  cubes chicken bouillon
# 		  chicken cutlet
# 		  chicken bouillon cube
# 		  chicken stock cube
# 		  chicken finger
# 		  store bought chicken stock
# 		  cut-up chicken
# 		  cube chicken bouillon
# 		  broiler-fryer chicken
# 		  up chicken
# 		  free-range chicken
# 		  pound chicken
# 		  rich chicken stock
# 		  chicken carcas
# 		  -pound chicken
# 		  chicken foot
# 		  container chicken stock
# 		  creamy chicken mushroom soup
# 		  coarsely chicken
#
#
# 	  Chicken, skin (drumsticks and thighs), raw
# 		  chicken thigh
# 		  chicken drumstick
# 		  bone in chicken thighs
# 		  chicken thigh fillet
# 		  bone in skin on chicken thigh
# 		  bone-in chicken thigh
# 		  drumstick
# 		  chicken and rice soup
# 		  skin on chicken thighs
# 		  bone in chicken thigh
#
#
# 	  Chicken, meatless
# 		  cream of chicken soup
# 		  chicken tenderloin
# 		  campbell's&; cream of chicken soup
# 		  brown chicken stock
# 		  frying chicken
# 		  chicken strip
# 		  reduced-fat cream of chicken soup
# 		  popcorn chicken
#
#
# 	  Chicken, canned, no broth
# 		  chicken bouillon powder
# 		  low-sodium chicken stock
# 		  bone-in chicken
# 		  stove stuffing mix for chicken
# 		  chicken fillet
# 		  chicken noodle soup
#
#
# 	  Chicken spread
# 		  chicken base
# 		  chunk chicken
# 		  chicken bone
# 		  chicken soup base
# 		  chicken ramen noodle
# 		  packages chicken ramen noodle
# 		  recipe fast chicken soup base
#
#
#
#
# Group matching :  juice  ( 5  times)
# 	  Pomegranate juice, bottled
# 		  juice
# 		  pomegranate juice
# 		  calamansi juice
#
#
# 	  Tomato juice, canned, without salt added
# 		  clam juice
# 		  tomato juice
# 		  tomato with juice
# 		  bottle clam juice
# 		  bottle tomato juice
# 		  clam with juice
#
#
# 	  Grapefruit juice, white, raw
# 		  grapefruit juice
# 		  white grape juice
#
#
# 	  Carrot juice, canned
# 		  coconut juice
# 		  carrot juice
#
#
# 	  Prune juice, canned
# 		  kimchi juice
# 		  cane juice
# 		  prune juice

# %%
for ing in ing_mapping :
    if ing_mapping[ing] == 90480 :
        print(ing)
# Out:
# cane syrup
# rice syrup

# %%
item_describe
# Out:
# {'2048': 'Vinegar, cider',
#  '20481': 'Wheat flour, white, all-purpose, unenriched',
#  '2050': 'Vanilla extract',
#  '2049': 'Thyme, fresh',
#  '2052': 'Vanilla extract, imitation, no alcohol',
#  '2053': 'Vinegar, distilled',
#  '2054': 'Capers, canned',
#  '6150': 'Sauce, barbecue',
#  '2055': 'Horseradish, prepared',
#  '16398': 'Peanut butter, smooth style, without salt',
#  '2063': 'Rosemary, fresh',
#  '2064': 'Peppermint, fresh',
#  '16399': 'Peanut butter with omega-3, creamy',
#  '43026': 'Syrups, sugar free',
#  '2039': 'Spices, savory, ground',
#  '2068': 'Vinegar, red wine',
#  '2069': 'Vinegar, balsamic',
#  '14355': 'Beverages, tea, black, brewed, prepared with tap water',
#  '2065': 'Spearmint, fresh',
#  '43028': 'Jams and preserves, no sugar (with sodium saccharin), any flavor',
#  '1226': 'Egg substitute, liquid or frozen, fat free',
#  '2074': 'Seasoning mix, dry, sazon, coriander & annatto',
#  '2075': 'Seasoning mix, dry, taco, original',
#  '2076': 'Seasoning mix, dry, chili, original',
#  '43031': 'Candies, chocolate covered, caramel with nuts',
#  '6114': 'Gravy, au jus, canned',
#  '14384': 'Beverages, water, bottled, PERRIER',
#  '14385': 'Beverages, water, bottled, POLAND SPRING',
#  '43059': 'Candies, chocolate covered, low sugar or low calorie',
#  '6118': 'Gravy, brown, dry',
#  '11003': 'Amaranth leaves, raw',
#  '5305': 'Turkey, Ground, raw',
#  '6120': 'Gravy, chicken, dry',
#  '6121': 'Gravy, mushroom, canned',
#  '14423': 'Beverages, dairy drink mix, chocolate, reduced calorie, with aspartame, powder, prepared with water and ice',
#  '6123': 'Gravy, onion, dry, mix',
#  '14429': 'Beverages, water, tap, municipal',
#  '14431': 'Cranberry juice cocktail, frozen concentrate, prepared with water',
#  '14434': 'Beverages, The COCA-COLA company, DASANI, water, bottled, non-carbonated',
#  '6126': 'Gravy, turkey, dry',
#  '43114': 'Vermicelli, made from soy',
#  '43125': 'Beans, liquid from stewed kidney beans',
#  '43128': 'Chicken, meatless',
#  '6264': 'Sauce, white, thin, prepared-from-recipe, with butter',
#  '43130': 'Frankfurter, meatless',
#  '5316': 'Duck, young duckling, domesticated, White Pekin, breast, meat only, boneless, cooked without skin, broiled',
#  '43132': 'Meatballs, meatless',
#  '43134': 'Vegetarian fillets',
#  '43135': 'Sandwich spread, meatless',
#  '43137': 'Vegetarian meatloaf or patties',
#  '15088': 'Fish, sardine, Atlantic, canned in oil, drained solids with bone',
#  '6285': 'Sauce, sweet and sour, prepared-from-recipe',
#  '10207': 'Pork, fresh, loin, country-style ribs, separable lean only, raw',
#  '6307': 'Sauce, barbecue, KRAFT, original',
#  '11430': 'Radishes, oriental, raw',
#  '20647': 'Millet flour',
#  '20648': 'Sorghum flour, whole-grain',
#  '20649': 'Wheat flour, whole-grain, soft wheat',
#  '15097': 'Fish, sheepshead, raw',
#  '6142': 'Sauce, sofrito, prepared from recipe',
#  '5738': 'Turkey, drumstick, from whole bird, meat only, raw',
#  '43212': 'Bacon bits, meatless',
#  '35021': 'Caribou, bone marrow, raw (Alaska Native)',
#  '14543': 'Beverages, lemonade, frozen concentrate, pink, prepared with water',
#  '43217': 'Tomato sauce, canned, no salt added',
#  '35028': 'Cockles, raw (Alaska Native)',
#  '35030': 'Cranberry, low bush or lingenberry, raw (Alaska Native)',
#  '14555': 'Water, bottled, generic',
#  '35043': 'Huckleberries, raw (Alaska Native)',
#  '35054': 'Octopus (Alaska Native)',
#  '35070': 'Sea cucumber, yane (Alaska Native)',
#  '35073': 'Soup, fish, homemade (Alaska Native)',
#  '35078': 'Tea, tundra, herb and laborador combination (Alaska Native)',
#  '43273': 'Cheese, cottage, with vegetables',
#  '43276': 'Cheese spread, cream cheese base',
#  '14605': 'Beverages, Water with added vitamins and minerals, bottles, sweetened, assorted fruit flavors',
#  '43278': 'Cheese, american cheddar, imitation',
#  '14604': 'Water, non-carbonated, bottles, natural fruit flavors, sweetened with low calorie sweetener',
#  '35086': 'Whale, bowhead, skin and subcutaneous fat (muktuk) (Alaska Native)',
#  '35091': 'Fish, whitefish, broad, head, eyes, cheeks and soft bones (Alaska Native)',
#  '35092': 'Willow, leaves in oil (Alaska Native)',
#  '43285': 'Eggs, scrambled, frozen mixture',
#  '14303': 'Limeade, frozen concentrate, prepared with water',
#  '44018': 'Sweeteners, tabletop, fructose, liquid',
#  '6431': "CAMPBELL'S CHUNKY, New England Clam Chowder",
#  '43299': 'Soybean, curd cheese',
#  '31021': 'Potatoes, hash brown, refrigerated, unprepared',
#  '31033': 'Ginger root, pickled, canned, with artificial sweetener',
#  '35131': 'Cornmeal, blue (Navajo)',
#  '31036': 'Potatoes, mashed, ready-to-eat',
#  '31035': 'Vegetable juice, BOLTHOUSE FARMS, DAILY GREENS',
#  '35134': 'Corn, dried (Navajo)',
#  '35136': 'Cornmeal, white (Navajo)',
#  '35137': 'Cornmeal, yellow (Navajo)',
#  '35138': 'Squash, Indian, raw (Navajo)',
#  '35140': 'Bread, kneel down (Navajo)',
#  '35143': 'Tortilla, includes plain and from mutton sandwich (Navajo)',
#  '35144': 'Stew, dumpling with mutton (Navajo)',
#  '80200': 'Frog legs, raw',
#  '35146': 'Stew, mutton, corn, squash (Navajo)',
#  '35147': 'Tamales (Navajo)',
#  '35148': 'Stew, steamed corn (Navajo)',
#  '35150': 'Fish, salmon, coho (silver), raw (Alaska Native)',
#  '43344': 'Jams, preserves, marmalade, reduced sugar',
#  '43365': 'Tomato and vegetable juice, low sodium',
#  '35179': 'Chokecherries, raw, pitted (Shoshone Bannock)',
#  '90480': 'Syrup, Cane',
#  '35187': 'Tennis Bread, plain (Apache)',
#  '43382': 'Cranberry juice, unsweetened',
#  '35190': 'Salmon, red (sockeye), filets with skin, smoked (Alaska Native)',
#  '35192': 'Agave, raw (Southwest)',
#  '43392': 'Hearts of palm, raw',
#  '35203': 'Rose Hips, wild (Northern Plains Indians)',
#  '43406': 'Yeast extract spread',
#  '4501': 'Oil, cocoa butter',
#  '12698': 'Seeds, sesame butter, tahini, type of kernels unspecified',
#  '4511': 'Oil, safflower, salad or cooking, high oleic (primary safflower oil of commerce)',
#  '35232': 'Wocas, dried seeds, Oregon, yellow pond lily (Klamath)',
#  '4513': 'Vegetable oil, palm kernel',
#  '35237': 'Tamales, masa and pork filling (Hopi)',
#  '4518': 'Oil, corn, industrial and retail, all purpose salad or cooking',
#  '35239': 'Tortilla, blue corn, Sakwavikaviki (Hopi)',
#  '27048': 'Sauce, steak, tomato based',
#  '35238': 'Tea, herbal, brewed, Hohoysi (Hopi)',
#  '35240': 'Bread, blue corn, somiviki (Hopi)',
#  '27052': 'Dip, salsa con queso, cheese and salsa- medium',
#  '27054': 'Dip, TOSTITOS, salsa con queso, medium',
#  '4528': 'Oil, walnut',
#  '4529': 'Oil, almond',
#  '4530': 'Oil, apricot kernel',
#  '27059': 'Sauce, peanut, made from peanut butter, water, soy sauce',
#  '4532': 'Oil, hazelnut',
#  '27056': "Sauce, barbecue, BULL'S-EYE, original",
#  '4531': 'Oil, soybean lecithin',
#  '27063': 'Sauce, enchilada, red, mild, ready to serve',
#  '27064': 'Wasabi',
#  '27065': 'Dip, bean, original flavor',
#  '27066': 'Sauce, horseradish',
#  '4542': 'Fat, chicken',
#  '90560': 'Mollusks, snail, raw',
#  '4545': 'Oil, sunflower, linoleic, (partially hydrogenated)',
#  '4548': 'Shortening cake mix, soybean (hydrogenated) and cottonseed (hydrogenated)',
#  '4551': 'Shortening confectionery, coconut (hydrogenated) and or palm kernel (hydrogenated)',
#  '43476': 'Tofu yogurt',
#  '6618': 'Sauce, peanut, made from coconut, water, sugar, peanuts',
#  '15242': 'Crustaceans, crayfish, mixed species, farmed, raw',
#  '4572': 'Oil, nutmeg butter',
#  '4575': 'Fat, turkey',
#  '4576': 'Fat, goose',
#  '11086': 'Beet greens, raw',
#  '4581': 'Oil, avocado',
#  '6631': 'Sauce, hot chile, sriracha',
#  '4583': 'Oil, mustard',
#  '6633': 'Sauce, hot chile, sriracha, TUONG OT SRIRACHA',
#  '19313': 'Candies, MARS SNACKFOOD US, STARBURST Fruit Chews, Tropical fruits',
#  '4587': 'Shortening, special purpose for baking, soybean (hydrogenated) palm and cottonseed',
#  '7018': 'Chicken spread',
#  '4594': 'Fish oil, sardine',
#  '20452': 'Rice, white, short-grain, raw, unenriched',
#  '4601': 'Butter, light, stick, with salt',
#  '4602': 'Butter, light, stick, without salt',
#  '4609': 'Animal fat, bacon grease',
#  '7917': 'Sausage, pork and beef, with cheddar cheese, smoked',
#  '4615': 'Shortening, vegetable, household, composite',
#  '4617': 'Margarine, regular, 80% fat, composite, stick, without salt',
#  '23053': 'Beef, chuck, shoulder clod, shoulder tender, medallion, separable lean and fat, trimmed to 0" fat, all grades, raw',
#  '23057': 'Beef, chuck, shoulder clod, shoulder top and center steaks, separable lean and fat, trimmed to 0" fat, all grades, raw',
#  '23059': 'Beef, chuck, shoulder clod, top blade, steak, separable lean and fat, trimmed to 0" fat, all grades, raw',
#  '17202': 'Veal, variety meats and by-products, liver, raw',
#  '23061': 'Beef, round, knuckle, tip center, steak, separable lean and fat, trimmed to 0" fat, all grades, raw',
#  '4630': 'Margarine Spread, 40-49% fat, tub',
#  '43543': 'Milk, imitation, non-soy',
#  '23063': 'Beef, round, outside round, bottom round, steak, separable lean and fat, trimmed to 0" fat, all grades, raw',
#  '23066': 'Beef, chuck, short ribs, boneless, separable lean only, trimmed to 0" fat, choice, raw',
#  '23067': 'Beef, chuck, short ribs, boneless, separable lean only, trimmed to 0" fat, select, raw',
#  '23073': 'Beef, chuck eye Country-Style ribs, boneless, separable lean only, trimmed to 0" fat, select, raw',
#  '4645': 'Oil, industrial, canola (partially hydrogenated) oil for deep fat frying',
#  '23079': 'Beef, chuck eye steak, boneless, separable lean only, trimmed to 0" fat, select, raw',
#  '4648': 'Oil, industrial, soy (partially hydrogenated), principal uses popcorn and flavoring vegetables',
#  '4651': 'Oil, industrial, soy (partially hydrogenated), multiuse for non-dairy butter flavor',
#  '4659': 'Oil, industrial, coconut, confection fat, typical basis for ice cream coatings',
#  '4660': 'Oil, industrial, palm kernel (hydrogenated) , used for whipped toppings, non-dairy',
#  '23094': 'Beef, chuck for stew, separable lean and fat, select, raw',
#  '4664': 'Oil, industrial, soy (partially hydrogenated ), palm, principal uses icings and fillings',
#  '4665': 'Margarine, industrial, non-dairy, cottonseed, soy oil (partially hydrogenated ), for flaky pastries',
#  '4668': 'Margarine, industrial, soy and partially hydrogenated soy oil, use for baking, sauces and candy',
#  '4669': 'Oil, vegetable, soybean, refined',
#  '6720': 'Sauce, cheese sauce mix, dry',
#  '4673': 'Margarine-like spread, SMART BALANCE Regular Buttery Spread with flax oil',
#  '4674': 'Margarine-like spread, SMART BALANCE Light Buttery Spread',
#  '43589': 'Cheese, swiss, low fat',
#  '4677': 'Margarine-like spread, SMART BALANCE Omega Plus Spread (with plant sterols & fish oil)',
#  '4679': 'Oil, PAM cooking spray, original',
#  '19018': 'Fruit syrup',
#  '4687': 'Margarine-like spread, BENECOL Light Spread',
#  '7038': 'Knackwurst, knockwurst, pork, beef',
#  '19029': "Topping, SMUCKER'S MAGIC SHELL",
#  '19030': 'Syrup, fruit flavored',
#  '4698': 'Oil, industrial, canola, high oleic',
#  '4708': 'Mayonnaise, reduced fat, with olive oil',
#  '17000': 'Veal, Australian, rib, rib roast, separable lean only, raw',
#  '19064': 'Candies, TOOTSIE ROLL, chocolate-flavor roll',
#  '17017': 'Lamb, leg, shank half, separable lean only, trimmed to 1/4" fat, choice, raw',
#  '23163': 'Beef, plate steak, boneless, inside skirt, separable lean only, trimmed to 0" fat, all grades, raw',
#  '19069': 'Candies, NESTLE, BUTTERFINGER Bar',
#  '19070': 'Candies, butterscotch',
#  '19074': 'Candies, caramels',
#  '23175': 'Beef, rib eye steak, boneless, lip off, separable lean only, trimmed to 0" fat, all grades, raw',
#  '23181': 'Beef, rib, back ribs, bone-in, separable lean only, trimmed to 0" fat, all grades, raw',
#  '19087': 'Candies, white chocolate',
#  '10898': 'Pork, pickled pork hocks',
#  '19091': 'Candies, YORK Peppermint Pattie',
#  '19095': 'Ice creams, vanilla',
#  '15001': 'Fish, anchovy, european, raw',
#  '19097': 'Sherbet, orange',
#  '7052': 'Pastrami, turkey',
#  '15004': 'Fish, bass, striped, raw',
#  '19100': 'Candies, fudge, chocolate, prepared-from-recipe',
#  '19104': 'Candies, fudge, vanilla with nuts',
#  '19106': 'Candies, gumdrops, starch jelly pieces',
#  '15010': 'Fish, catfish, channel, wild, raw',
#  '15012': 'Fish, caviar, black and red, granular',
#  '19109': 'Candies, KIT KAT Wafer Bar',
#  '19110': 'Candies, KRACKEL Chocolate Bar',
#  '15015': 'Fish, cod, Atlantic, raw',
#  '19107': 'Candies, hard',
#  '19112': 'Candies, TWIZZLERS Strawberry Twists Candy',
#  '5020': 'Chicken, broilers or fryers, giblets, raw',
#  '15022': 'Fish, cusk, raw',
#  '19119': 'Candies, NESTLE, CHUNKY Bar',
#  '19120': 'Candies, milk chocolate',
#  '15023': 'Fish, mahimahi, raw',
#  '17074': 'Lamb, New Zealand, imported, leg chop/steak, bone-in, separable lean only, raw',
#  '15028': 'Fish, flatfish (flounder and sole species), raw',
#  '17078': 'Lamb, New Zealand, imported, loin chop, separable lean only, raw',
#  '15031': 'Fish, grouper, mixed species, raw',
#  '17080': 'Lamb, New Zealand, imported, rack - partly frenched, separable lean and fat, raw',
#  '5023': 'Chicken, gizzard, all classes, raw',
#  '17082': 'Lamb, New Zealand, imported, rack - partly frenched, separable lean only, raw',
#  '15035': 'Fish, haddock, smoked',
#  '19132': 'Candies, milk chocolate, with almonds',
#  '19130': "Candies, HERSHEY'S POT OF GOLD Almond Bar",
#  '17086': 'Lamb, New Zealand, imported, square-cut shoulder, separable lean only, raw',
#  '15038': 'Fish, halibut, Greenland, raw',
#  '19134': 'Candies, milk chocolate, with rice cereal',
#  '19137': 'Toppings, strawberry',
#  '10946': 'Pork, fresh, shoulder, (Boston butt), blade (steaks), separable lean only, with added solution, raw',
#  '23342': 'Beef, loin, tenderloin steak, boneless, separable lean and fat, trimmed to 0" fat, all grades, raw',
#  '7059': 'Polish sausage, pork',
#  '15039': 'Fish, herring, Atlantic, raw',
#  '7060': 'Luxury loaf, pork',
#  '13000': 'Beef, grass-fed, strip steaks, lean only, raw',
#  '19144': 'Candies, NESTLE, 100 GRAND Bar',
#  '15048': 'Fish, mackerel, jack, canned, drained solids',
#  '15049': 'Fish, mackerel, king, raw',
#  '10957': 'Pork, Leg Cap Steak, boneless, separable lean and fat, raw',
#  '15054': 'Fish, monkfish, raw',
#  '15055': 'Fish, mullet, striped, raw',
#  '19154': 'Candies, sesame crunch',
#  '10963': 'Pork, Leg sirloin tip roast, boneless, separable lean and fat, raw',
#  '19157': "Candies, MARS SNACKFOOD US, M&M's MINIs Milk Chocolate Candies",
#  '17113': 'Veal, rib, separable lean only, raw',
#  '19162': 'Candies, WHATCHAMACALLIT Candy Bar',
#  '19163': 'Chewing gum',
#  '19161': 'Candies, MARS SNACKFOOD US, TWIX Peanut Butter Cookie Bars',
#  '19165': 'Cocoa, dry powder, unsweetened',
#  '19166': 'Cocoa, dry powder, unsweetened, processed with alkali',
#  '13023': 'Beef, brisket, whole, separable lean only, all grades, raw',
#  '19169': 'Egg custards, dry mix',
#  '10938': 'Pork, cured, ham, slice, bone-in, separable lean only, unheated',
#  '10980': 'Pork loin, fresh, backribs, bone-in, raw, lean only',
#  '17125': 'Veal, shoulder, arm, separable lean only, raw',
#  '15078': 'Fish, salmon, chinook, raw',
#  '15079': 'Fish, salmon, chum, raw',
#  '17128': 'Veal, shoulder, blade chop, separable lean and fat, raw',
#  '19177': 'Gelatins, dry powder, unsweetened',
#  '19172': 'Gelatin desserts, dry mix',
#  '15083': 'Fish, salmon, pink, raw',
#  '15085': 'Fish, salmon, sockeye, raw',
#  '19183': 'Puddings, chocolate, ready-to-eat',
#  '19184': 'Puddings, chocolate, dry mix, instant',
#  '15089': 'Fish, sardine, Pacific, canned in tomato sauce, drained solids with bone',
#  '17137': 'Veal, sirloin, separable lean only, raw',
#  '15091': 'Fish, sea bass, mixed species, raw',
#  '19188': 'Puddings, chocolate, dry mix, regular',
#  '17140': 'Veal, cubed for stew (leg and shoulder), separable lean only, raw',
#  '19186': 'Desserts, apple crisp, prepared-from-recipe',
#  '13047': 'Beef, grass-fed, ground, raw',
#  '7071': 'Salami, dry or hard, pork',
#  '11001': 'Alfalfa seeds, sprouted, raw',
#  '19194': 'Puddings, rice, dry mix',
#  '19193': 'Puddings, rice, ready-to-eat',
#  '9107': 'Gooseberries, raw',
#  '15101': 'Fish, snapper, mixed species, raw',
#  '19198': 'Puddings, tapioca, dry mix',
#  '11007': 'Artichokes, (globe or french), raw',
#  '17149': 'Bison, ground, grass-fed, raw',
#  '19201': 'Puddings, vanilla, ready-to-eat',
#  '17154': 'Veal, Australian, separable fat, raw',
#  '11011': 'Asparagus, raw',
#  '15108': 'Fish, sunfish, pumpkin seed, raw',
#  '15109': 'Fish, surimi',
#  '19206': 'Puddings, vanilla, dry mix, regular',
#  '15110': 'Fish, swordfish, raw',
#  '15107': 'Fish, sucker, white, raw',
#  '17156': 'Game meat, bison, separable lean only, raw',
#  '19202': 'Puddings, vanilla, dry mix, instant',
#  '15115': 'Fish, trout, rainbow, wild, raw',
#  '17158': 'Game meat, boar, wild, raw',
#  '15117': 'Fish, tuna, fresh, bluefin, raw',
#  '15119': 'Fish, tuna, light, canned in oil, drained solids',
#  '11024': 'Balsam-pear (bitter gourd), pods, raw',
#  '15121': "Fish, tuna, light, canned in water, drained solids (Includes foods for USDA's Food Distribution Program)",
#  '11026': 'Bamboo shoots, raw',
#  '19216': 'Candies, praline, prepared-from-recipe',
#  '15124': 'Fish, tuna, white, canned in oil, drained solids',
#  '11029': 'Beans, kidney, mature seeds, sprouted, raw',
#  '15126': 'Fish, tuna, white, canned in water, drained solids',
#  '11031': 'Lima beans, immature seeds, raw',
#  '15127': 'Fish, tuna, fresh, yellowfin, raw',
#  '15128': 'Fish, tuna salad',
#  '15130': 'Fish, whitefish, mixed species, raw',
#  '19227': 'Frostings, coconut-nut, ready-to-eat',
#  '17180': 'Game meat, rabbit, wild, raw',
#  '19226': 'Frostings, chocolate, creamy, ready-to-eat',
#  '19230': 'Frostings, vanilla, creamy, ready-to-eat',
#  '7077': 'Sausage, smoked link sausage, pork and beef (nonfat dry milk added)',
#  '15136': 'Crustaceans, crab, alaska king, raw',
#  '15138': 'Crustaceans, crab, alaska king, imitation, made from surimi',
#  '15139': 'Crustaceans, crab, blue, raw',
#  '16035': 'Beans, kidney, royal red, mature seeds, raw',
#  '15143': 'Crustaceans, crab, dungeness, raw',
#  '9003': "Apples, raw, with skin (Includes foods for USDA's Food Distribution Program)",
#  '11052': 'Beans, snap, green, raw',
#  '9004': 'Apples, raw, without skin',
#  '19246': 'Frostings, white, fluffy, dry mix',
#  '15147': 'Crustaceans, lobster, northern, raw',
#  '6960': 'Sauce, alfredo mix, dry',
#  '6961': 'Sauce, peppers, hot, chili, mature red, canned',
#  '17195': 'Lamb, variety meats and by-products, kidneys, raw',
#  '6963': 'Fish broth',
#  '6958': 'Gravy, instant beef, dry',
#  '15157': 'Mollusks, clam, mixed species, raw',
#  '6962': 'Sauce, chili, peppers, hot, immature green, canned',
#  '11154': 'Chicory roots, raw',
#  '19249': 'Candies, HERSHEY, REESESTICKS crispy wafers, peanut butter, milk chocolate',
#  '11062': 'Beans, snap, green, frozen, all styles, microwaved',
#  '9018': 'Apple juice, frozen concentrate, unsweetened, diluted with 3 volume water without added ascorbic acid',
#  '6971': 'Sauce, worcestershire',
#  '6972': 'Sauce, tomato chili sauce, bottled, with salt',
#  '9021': 'Apricots, raw',
#  '9020': 'Applesauce, canned, sweetened, without salt',
#  '15164': 'Mollusks, mussel, blue, raw',
#  '23360': 'Beef, round, eye of round roast, boneless, separable lean only, trimmed to 0" fat, all grades, raw',
#  '23366': 'Beef, loin, tenderloin roast, boneless, separable lean only, trimmed to 0" fat, all grades, raw',
#  '15172': 'Mollusks, scallop, mixed species, raw',
#  '19270': 'Ice creams, chocolate',
#  '19271': 'Ice creams, strawberry',
#  '17224': 'Lamb, ground, raw',
#  '11080': 'Beets, raw',
#  '15175': 'Mollusks, squid, mixed species, raw',
#  '11082': 'Beets, canned, regular pack, solids and liquids',
#  '23372': 'Beef, loin, tenderloin steak, boneless, separable lean only, trimmed to 0" fat, all grades, raw',
#  '9036': 'Apricot nectar, canned, with added ascorbic acid',
#  '9038': 'Avocados, raw, California',
#  '9039': 'Avocados, raw, Florida',
#  '9040': 'Bananas, raw',
#  '19279': 'Candies, milk chocolate coated coffee beans',
#  '11090': 'Broccoli, raw',
#  '9042': 'Blackberries, raw',
#  '15186': 'Fish, tuna, white, canned in water, without salt, drained solids',
#  '15184': 'Fish, tuna, light, canned in water, without salt, drained solids',
#  '15185': 'Fish, tuna, white, canned in oil, without salt, drained solids',
#  '6999': "Gravy, CAMPBELL'S, chicken",
#  '11096': 'Broccoli raab, raw',
#  '9043': 'Blackberry juice, canned',
#  '9050': 'Blueberries, raw',
#  '7003': 'Beerwurst, beer salami, pork',
#  '11098': 'Brussels sprouts, raw',
#  '7001': 'Barbecue loaf, pork, beef',
#  '19294': 'Fruit butters, apple',
#  '19296': 'Honey',
#  '19297': 'Jams and preserves',
#  '11104': 'Burdock root, raw',
#  '7011': 'Bologna, turkey',
#  '19300': 'Jellies',
#  '11109': 'Cabbage, raw',
#  '19303': 'Marmalade, orange',
#  '9063': 'Cherries, sour, red, raw',
#  '7015': 'Bratwurst, pork, beef, link',
#  '11114': 'Cabbage, savoy, raw',
#  '7019': 'Sausage, pork, chorizo, link or ground, raw',
#  '11116': 'Cabbage, chinese (pak-choi), raw',
#  '19309': 'Candies, MARS SNACKFOOD US, STARBURST Fruit Chews, Fruit and Creme',
#  '9070': 'Cherries, sweet, raw',
#  '11118': 'Cabbage, kimchi',
#  '19312': 'Pie fillings, apple, canned',
#  '11119': 'Cabbage, chinese (pe-tsai), raw',
#  '19314': 'Pie fillings, canned, cherry',
#  '23407': 'Beef, New Zealand, imported, cube roll, separable lean only, raw',
#  '11124': 'Carrots, raw',
#  '7028': 'Ham, sliced, pre-packaged, deli meat (96%fat free, water added)',
#  '7030': 'Ham, minced',
#  '9078': 'Cranberries, raw',
#  '7031': 'Ham salad spread',
#  '9081': 'Cranberry sauce, canned, sweetened',
#  '17271': 'Veal, breast, whole, boneless, separable lean and fat, raw',
#  '9083': 'Currants, european black, raw',
#  '7036': 'Sausage, Italian, pork, mild, raw',
#  '17278': 'Veal, shank (fore and hind), separable lean only, raw',
#  '11135': 'Cauliflower, raw',
#  '7040': 'Liver cheese, pork',
#  '9089': 'Figs, raw',
#  '11134': 'Cassava, raw',
#  '7043': 'Roast beef, deli style, prepackaged, sliced',
#  '19332': 'Puddings, lemon, dry mix, regular',
#  '19333': 'Pudding, lemon, dry mix, regular, prepared with sugar, egg yolk and water',
#  '19334': 'Sugars, brown',
#  '11143': 'Celery, raw',
#  '19336': 'Sugars, powdered',
#  '7045': 'Luncheon meat, pork, canned',
#  '7050': 'Mortadella, beef, pork',
#  '7051': 'Olive loaf, pork',
#  '11147': 'Chard, swiss, raw',
#  '11149': 'Chayote, fruit, raw',
#  '9100': 'Fruit cocktail, (peach and pineapple and pear and grape and cherry), canned, heavy syrup, solids and liquids',
#  '19340': 'Sugars, maple',
#  '7053': 'Pate, chicken liver, canned',
#  '7057': 'Pepperoni, beef and pork, sliced',
#  '23441': 'Beef, New Zealand, imported, tenderloin, separable lean only, raw',
#  '7058': 'Pickle and pimiento loaf, pork',
#  '11156': 'Chives, raw',
#  '19348': 'Syrups, chocolate, fudge-type',
#  '9110': 'Goji berries, dried',
#  '19351': 'Syrups, corn, high-fructose',
#  '7063': 'Pork sausage, link/patty, unprepared',
#  '19353': 'Syrups, maple',
#  '11161': 'Collards, raw',
#  '7061': "Mother's loaf, pork",
#  '5015': 'Chicken, broilers or fryers, skin only, raw',
#  '11165': 'Coriander (cilantro) leaves, raw',
#  '15261': 'Fish, tilapia, raw',
#  '11167': 'Corn, sweet, yellow, raw',
#  '9117': 'Grapefruit, raw, white, California',
#  '9118': 'Grapefruit, raw, white, Florida',
#  '7074': 'Sausage, smoked link sausage, pork',
#  '5027': 'Chicken, liver, all classes, raw',
#  '11170': 'Corn, sweet, yellow, canned, brine pack, regular pack, solids and liquids',
#  '19365': 'Toppings, marshmallow cream',
#  '15270': 'Crustaceans, shrimp, raw',
#  '19364': 'Toppings, butterscotch or caramel',
#  '9128': 'Grapefruit juice, white, raw',
#  '7081': 'Turkey breast, sliced, prepackaged',
#  '19366': 'Toppings, pineapple',
#  '13227': 'Beef, shank crosscuts, separable lean only, trimmed to 1/4" fat, choice, raw',
#  '9132': 'Grapes, red or green (European type, such as Thompson seedless), raw',
#  '9133': 'Grapes, canned, thompson seedless, water pack, solids and liquids',
#  '11182': 'Corn, yellow, whole kernel, frozen, microwaved',
#  '19375': 'Frostings, glaze, prepared-from-recipe',
#  '9135': 'Grape juice, canned or bottled, unsweetened, without added ascorbic acid',
#  '7088': 'Honey roll sausage, beef',
#  '9138': 'Groundcherries, (cape-gooseberries or poha), raw',
#  '9139': 'Guavas, common, raw',
#  '48052': 'Vital wheat gluten',
#  '11180': 'Corn, sweet, yellow, frozen, kernels on cob, unprepared',
#  '11184': 'Corn with red and green peppers, canned, solids and liquids',
#  '19383': 'Candies, toffee, prepared-from-recipe',
#  '9144': 'Jackfruit, raw',
#  '9147': 'Jujube, Chinese, fresh, dried',
#  '9148': 'Kiwifruit, green, raw',
#  '9149': 'Kumquats, raw',
#  '9150': 'Lemons, raw, without peel',
#  '11199': 'Yardlong bean, raw',
#  '9152': 'Lemon juice, raw',
#  '17343': 'Game meat, deer, ground, raw',
#  '9156': 'Lemon peel, raw',
#  '11205': 'Cucumber, with peel, raw',
#  '9159': 'Limes, raw',
#  '9160': 'Lime juice, raw',
#  '11209': 'Eggplant, raw',
#  '17353': 'Lamb, Australian, ground,  85% lean / 15% fat, raw',
#  '11211': 'Edamame, frozen, unprepared',
#  '11207': 'Dandelion greens, raw',
#  '11213': 'Endive, raw',
#  '9164': 'Litchis, raw',
#  '11215': 'Garlic, raw',
#  '11216': 'Ginger root, raw',
#  '19409': 'Frostings, glaze, chocolate, prepared-from-recipe, with butter, NFSMI Recipe No. C-32',
#  '11218': 'Gourd, white-flowered (calabash), raw',
#  '5075': 'Chicken, broilers or fryers, leg, meat and skin, raw',
#  '1007': 'Cheese, camembert',
#  '1008': 'Cheese, caraway',
#  '23403': 'Beef, New Zealand, imported, brisket point end, separable lean only, raw',
#  '9176': 'Mangos, raw',
#  '9181': 'Melons, cantaloupe, raw',
#  '9183': 'Melons, casaba, raw',
#  '9184': 'Melons, honeydew, raw',
#  '11233': 'Kale, raw',
#  '9185': 'Melon balls, frozen',
#  '11238': 'Mushrooms, shiitake, raw',
#  '9191': 'Nectarines, raw',
#  '11240': 'Mushrooms, morel, raw',
#  '9193': 'Olives, ripe, canned (small-extra large)',
#  '11239': 'Mushrooms, Chanterelle, raw',
#  '1003': 'Butter oil, anhydrous',
#  '1004': 'Cheese, blue',
#  '16074': 'Lima beans, thin seeded (baby), mature seeds, raw',
#  '11246': 'Leeks, (bulb and lower leaf-portion), raw',
#  '1006': 'Cheese, brie',
#  '17392': 'Lamb, New Zealand, imported, neck chops, separable lean only, raw',
#  '1014': 'Cheese, cottage, nonfat, uncreamed, dry, large or small curd',
#  '9202': "Oranges, raw, navels (Includes foods for USDA's Food Distribution Program)",
#  '11251': 'Lettuce, cos or romaine, raw',
#  '11252': 'Lettuce, iceberg (includes crisphead types), raw',
#  '9205': 'Oranges, raw, with peel',
#  '1011': 'Cheese, colby',
#  '9207': 'Orange juice, canned, unsweetened',
#  '1012': 'Cheese, cottage, creamed, large or small curd',
#  '11257': 'Lettuce, red leaf, raw',
#  '1017': 'Cheese, cream',
#  '1019': 'Cheese, feta',
#  '1020': 'Cheese, fontina',
#  '11260': 'Mushrooms, white, raw',
#  '5115': 'Chicken, roasting, giblets, raw',
#  '1023': 'Cheese, gruyere',
#  '1022': 'Cheese, gouda',
#  '1025': 'Cheese, monterey',
#  '9218': 'Tangerines, (mandarin oranges), raw',
#  '11266': 'Mushrooms, brown, italian, or crimini, raw',
#  '11268': 'Mushrooms, shiitake, dried',
#  '1029': 'Cheese, mozzarella, low moisture, part-skim',
#  '11270': 'Mustard greens, raw',
#  '11265': 'Mushrooms, portabella, raw',
#  '9215': 'Orange juice, frozen concentrate, unsweetened, diluted with 3 volume water',
#  '9221': 'Tangerine juice, raw',
#  '9226': 'Papayas, raw',
#  '1035': 'Cheese, provolone',
#  '1036': 'Cheese, ricotta, whole milk',
#  '1034': 'Cheese, port de salut',
#  '11278': 'Okra, raw',
#  '1038': 'Cheese, romano',
#  '1040': 'Cheese, swiss',
#  '1039': 'Cheese, roquefort',
#  '11282': 'Onions, raw',
#  '5135': 'Chicken, capons, meat and skin, raw',
#  '9236': 'Peaches, yellow, raw',
#  '17426': 'Veal, leg, top round, cap off, cutlet, boneless, raw',
#  '11286': 'Onions, yellow, sauteed',
#  '5143': 'Duck, domesticated, liver, raw',
#  '1047': 'Cheese food, pasteurized process, swiss',
#  '17433': 'Veal, seam fat only, raw',
#  '5145': 'Duck, wild, breast, meat only, raw',
#  '11291': 'Onions, spring or scallions (includes tops and bulb), raw',
#  '11292': 'Onions, young green, tops only',
#  '1053': 'Cream, fluid, heavy whipping',
#  '1054': 'Cream, whipped, cream topping, pressurized',
#  '13335': 'Beef, variety meats and by-products, suet, raw',
#  '1056': 'Cream, sour, cultured',
#  '11297': 'Parsley, fresh',
#  '11298': 'Parsnips, raw',
#  '13346': 'Beef, cured, corned beef, brisket, raw',
#  '9252': 'Pears, raw',
#  '1058': 'Sour dressing, non-butterfat, cultured, filled cream-type',
#  '11300': 'Peas, edible-podded, raw',
#  '13350': 'Beef, cured, dried',
#  '11304': 'Peas, green, raw',
#  '13353': 'Beef, cured, luncheon meat, jellied',
#  '7201': 'Oscar Mayer, Bologna (beef)',
#  '13355': 'Beef, cured, pastrami',
#  '9251': 'Peach nectar, canned, with sucralose, without added ascorbic acid',
#  '5165': 'Turkey, whole, meat and skin, raw',
#  '5158': 'Quail, meat only, raw',
#  '9263': 'Persimmons, japanese, raw',
#  '1026': 'Cheese, mozzarella, whole milk',
#  '1071': 'Dessert topping, powdered, 1.5 ounce prepared with 1/2 cup milk',
#  '9264': 'Persimmons, japanese, dried',
#  '5171': 'Turkey, whole, giblets, raw',
#  '23603': 'Beef, chuck, arm pot roast, separable lean only, trimmed to 1/8" fat, all grades, raw',
#  '9267': 'Pineapple, canned, water pack, solids and liquids',
#  '1078': 'Milk, producer, fluid, 3.7% milkfat',
#  '23607': 'Beef, short loin, top loin steak, separable lean only, trimmed to 1/8" fat, all grades, raw',
#  '9272': 'Pineapple, frozen, chunks, sweetened',
#  '42040': 'Syrups, grenadine',
#  '11322': 'Peas and carrots, frozen, unprepared',
#  '9266': 'Pineapple, raw, all varieties',
#  '1018': 'Cheese, edam',
#  '9277': 'Plantains, yellow, raw',
#  '15266': 'Fish, pollock, Alaska, raw',
#  '9279': 'Plums, raw',
#  '1030': 'Cheese, muenster',
#  '1088': 'Milk, buttermilk, fluid, cultured, lowfat',
#  '12021': 'Seeds, safflower seed kernels, dried',
#  '11324': 'Peas and onions, canned, solids and liquids',
#  '1031': 'Cheese, neufchatel',
#  '11333': 'Peppers, sweet, green, raw',
#  '9286': 'Pomegranates, raw',
#  '1094': 'Milk, buttermilk, dried',
#  '7236': 'Oscar Mayer, Smokies Sausage Little Cheese (pork, turkey)',
#  '5193': 'Turkey, all classes, leg, meat and skin, raw',
#  '1032': 'Cheese, parmesan, grated',
#  '19337': 'Sweeteners, tabletop, aspartame, EQUAL, packets',
#  '9292': 'Plums, dried (prunes), stewed, without added sugar',
#  '9294': 'Prune juice, canned',
#  '42063': 'Pectin, liquid',
#  '9296': 'Quinces, raw',
#  '9297': 'Raisins, golden, seedless',
#  '9299': 'Raisins, seeded',
#  '19352': 'Syrups, malt',
#  '9302': 'Raspberries, raw',
#  '1111': 'Milk shakes, thick vanilla',
#  '11352': 'Potatoes, flesh and skin, raw',
#  '11353': "Potatoes, russet, flesh and skin, raw (Includes foods for USDA's Food Distribution Program)",
#  '11354': 'Potatoes, white, flesh and skin, raw',
#  '9307': 'Rhubarb, raw',
#  '1116': 'Yogurt, plain, whole milk',
#  '1117': 'Yogurt, plain, low fat',
#  '23646': 'Beef, bottom sirloin, tri-tip roast, separable lean only, trimmed to 0" fat, all grades, raw',
#  '1113': 'Whey, acid, dried',
#  '11362': 'Potatoes, raw, skin',
#  '1123': 'Egg, whole, raw, fresh',
#  '1124': 'Egg, white, raw, fresh',
#  '1125': 'Egg, yolk, raw, fresh',
#  '9316': 'Strawberries, raw',
#  '5219': 'Turkey, whole, breast, meat only, raw',
#  '23656': 'Beef, flank, steak, separable lean only, trimmed to 0" fat, all grades, raw',
#  '5109': 'Chicken, roasting, meat and skin and giblets and neck, raw',
#  '9322': 'Tamarinds, raw',
#  '11370': 'Potatoes, hash brown, home-prepared',
#  '5227': 'Turkey, whole, wing, meat only, raw',
#  '19355': 'Syrups, sorghum',
#  '9326': 'Watermelon, raw',
#  '9328': 'Maraschino cherries, canned, drained',
#  '1140': 'Egg, quail, whole, fresh, raw',
#  '11382': 'Potatoes, mashed, dehydrated, granules with milk, dry form',
#  '1144': 'Egg substitute, powder',
#  '1145': 'Butter, without salt',
#  '1146': 'Cheese, parmesan, shredded',
#  '9340': 'Pears, asian, raw',
#  '5113': 'Chicken, roasting, meat only, raw',
#  '44158': 'Pie fillings, blueberry, canned',
#  '1151': 'Milk, nonfat, fluid, without added vitamin A and vitamin D (fat free or skim)',
#  '23431': 'Beef, New Zealand, imported, ribs prepared, raw',
#  '1156': 'Cheese, goat, hard type',
#  '11399': 'Potato puffs, frozen, oven-heated',
#  '1159': 'Cheese, goat, soft type',
#  '9351': 'Fruit cocktail, canned, heavy syrup, drained',
#  '1162': 'Yogurt, Greek, 2% fat, mango, CHOBANI',
#  '19362': 'Syrups, table blends, corn, refiner, and sugar',
#  '1045': 'Cheese food, cold pack, American',
#  '1165': 'Cheese, mexican, queso anejo',
#  '1166': 'Cheese, mexican, queso asadero',
#  '1167': 'Cheese, mexican, queso chihuahua',
#  '1171': "Egg, whole, raw, frozen, pasteurized (Includes foods for USDA's Food Distribution Program)",
#  '16108': 'Soybeans, mature seeds, raw',
#  '1173': 'Egg, white, dried',
#  '11414': 'Potato salad, home-prepared',
#  '1175': 'Milk, fluid, 1% fat, without added vitamin A and vitamin D',
#  '11413': 'Potato flour',
#  '11416': 'Pumpkin flowers, raw',
#  '9370': 'Peaches, canned, heavy syrup, drained',
#  '1179': 'Sour cream, light',
#  '1180': 'Sour cream, fat free',
#  '5277': 'Chicken, canned, meat only, with broth',
#  '11422': 'Pumpkin, raw',
#  '13464': 'Beef, short loin, porterhouse steak, separable lean only, trimmed to 1/8" fat, all grades, raw',
#  '42138': 'Mayonnaise, reduced-calorie or diet, cholesterol-free',
#  '1185': 'Parmesan cheese topping, fat free',
#  '1186': 'Cheese, cream, fat free',
#  '1187': 'Yogurt, chocolate, nonfat milk',
#  '5284': 'Turkey, canned, meat only, with broth',
#  '11429': 'Radishes, raw',
#  '5282': 'Pate de foie gras, canned (goose liver pate), smoked',
#  '1191': 'KRAFT VELVEETA Pasteurized Process Cheese Spread',
#  '42148': "Candies, MARS SNACKFOOD US, M&M's Peanut Butter Chocolate Candies",
#  '1193': "KRAFT BREAKSTONE'S Reduced Fat Sour Cream",
#  '1188': 'KRAFT CHEEZ WHIZ Pasteurized Process Cheese Sauce',
#  '11435': 'Rutabagas, raw',
#  '42155': 'Cheese, monterey, low fat',
#  '11437': 'Salsify, (vegetable oyster), raw',
#  '1190': 'KRAFT FREE Singles American Nonfat Pasteurized Process Cheese Product',
#  '11439': 'Sauerkraut, canned, solids and liquids',
#  '1199': 'Cream, half and half, fat free',
#  '5295': 'Turkey roast, boneless, frozen, seasoned, light and dark meat, raw',
#  '1203': 'Yogurt, fruit, lowfat, with low calorie sweetener',
#  '11445': 'Seaweed, kelp, raw',
#  '11446': 'Seaweed, laver, raw',
#  '5302': 'Poultry, mechanically deboned, from backs and necks without skin, raw',
#  '1209': 'Cheese, Mexican, blend, reduced fat',
#  '11450': 'Soybeans, green, raw',
#  '5307': 'Chicken, cornish game hens, meat and skin, raw',
#  '1212': 'Milk, dry, whole, without added vitamin D',
#  '9404': 'Grapefruit juice, pink, raw',
#  '5309': 'Chicken, cornish game hens, meat only, raw',
#  '5311': 'Chicken, canned, no broth',
#  '5312': 'Chicken, wing, frozen, glazed, barbecue flavored',
#  '11457': 'Spinach, raw',
#  '42178': 'Mayonnaise, made with tofu',
#  '9412': "Pears, raw, bartlett (Includes foods for USDA's Food Distribution Program)",
#  '9413': 'Pears, raw, red anjou',
#  '9414': "Pears, raw, bosc (Includes foods for USDA's Food Distribution Program)",
#  '1223': 'Protein supplement, milk based, Muscle Milk, powder',
#  '9415': "Pears, raw, green anjou (Includes foods for USDA's Food Distribution Program)",
#  '1225': 'Dulce de Leche',
#  '1057': 'Eggnog',
#  '11467': 'Squash, summer, crookneck and straightneck, raw',
#  '1228': 'Cheese, fresh, queso fresco',
#  '9421': 'Dates, medjool',
#  '1230': 'Milk, buttermilk, fluid, whole',
#  '5327': 'Chicken breast tenders, breaded, uncooked',
#  '9423': 'Prune puree',
#  '1229': 'Cheese, white, queso blanco',
#  '9422': 'Durian, raw or frozen',
#  '11475': 'Squash, summer, scallop, raw',
#  '5332': 'Chicken, ground, raw',
#  '9429': 'Pineapple, raw, traditional varieties',
#  '1059': 'Milk, filled, fluid, with blend of hydrogenated vegetable oils',
#  '1239': 'Ice cream cookie sandwich',
#  '1238': 'Ice cream sandwich',
#  '9433': 'Clementines, raw',
#  '11482': 'Squash, winter, acorn, raw',
#  '1242': 'Ice cream sandwich, vanilla, light, no sugar added',
#  '9436': 'Mango nectar, canned',
#  '11485': 'Squash, winter, butternut, raw',
#  '11489': 'Squash, winter, hubbard, raw',
#  '9442': 'Pomegranate juice, bottled',
#  '1251': 'Cheese, Mexican blend',
#  '11492': 'Squash, winter, spaghetti, raw',
#  '1253': 'Cheese, pasteurized process, American, without added vitamin D',
#  '9452': 'Orange Pineapple Juice Blend',
#  '5356': 'Chicken, broiler, rotisserie, BBQ, skin',
#  '5358': 'Chicken, broiler, rotisserie, BBQ, breast, meat and skin',
#  '11241': 'Kohlrabi, raw',
#  '11503': 'Water convolvulus,raw',
#  '1265': 'Cheese, cheddar, nonfat or fat free',
#  '9206': "Orange juice, raw (Includes foods for USDA's Food Distribution Program)",
#  '1267': 'Cheese, mexican, queso cotija',
#  '42227': "Candies, MARS SNACKFOOD US, M&M's Almond Chocolate Candies",
#  '1270': 'Cheese, cheddar, sharp, sliced',
#  '11518': 'Taro, raw',
#  '1284': 'Yogurt, Greek, strawberry, lowfat',
#  '1286': 'Yogurt, Greek, vanilla, nonfat',
#  '11527': 'Tomatoes, green, raw',
#  '1287': 'Yogurt, Greek, plain, lowfat',
#  '19719': 'Jams and preserves, apricot',
#  '42183': 'Candies, MARS SNACKFOOD US, TWIX chocolate fudge cookie bars',
#  '11531': 'Tomatoes, red, ripe, canned, packed in tomato juice',
#  '1289': 'Kefir, lowfat, plain, LIFEWAY',
#  '11533': 'Tomatoes, red, ripe, canned, stewed',
#  '1293': 'Yogurt, Greek, plain, whole milk',
#  '1295': 'Yogurt, vanilla, non-fat',
#  '1294': 'Yogurt, Greek, fruit, whole milk',
#  '11537': 'Tomatoes, red, ripe, canned, with green chilies',
#  '1297': 'Yogurt, Greek, vanilla, lowfat',
#  '1072': 'Dessert topping, pressurized',
#  '11540': 'Tomato juice, canned, with salt added',
#  '1303': 'Cream, half and half, lowfat',
#  '1305': 'Milk, chocolate, lowfat, reduced sugar',
#  '11250': 'Lettuce, butterhead (includes boston and bibb types), raw',
#  '11547': 'Tomato products, canned, puree, without salt added',
#  '11548': 'Tomato powder',
#  '9501': 'Apples, raw, golden delicious, with skin',
#  '9502': "Apples, raw, granny smith, with skin (Includes foods for USDA's Food Distribution Program)",
#  '9503': "Apples, raw, gala, with skin (Includes foods for USDA's Food Distribution Program)",
#  '9504': "Apples, raw, fuji, with skin (Includes foods for USDA's Food Distribution Program)",
#  '1306': 'Ice cream, lowfat, no sugar added, cone, added peanuts and chocolate sauce',
#  '1314': 'Yogurt, Greek, nonfat, plain, CHOBANI',
#  '9216': 'Orange peel, raw',
#  '11555': 'Tomato products, canned, sauce, with herbs and cheese',
#  '11557': 'Tomato products, canned, sauce, with onions, green peppers, and celery',
#  '9510': 'Pineapple juice, canned, not from concentrate, unsweetened, with added vitamins A, C and E',
#  '9507': 'Fruit juice smoothie, NAKED JUICE, MIGHTY MANGO',
#  '42189': 'Milk, buttermilk, fluid, cultured, reduced fat',
#  '11253': 'Lettuce, green leaf, raw',
#  '42281': 'Gums, seed gums (includes locust bean, guar)',
#  '1323': 'Butter, Clarified butter (ghee)',
#  '11564': 'Turnips, raw',
#  '1322': 'Yogurt, Greek, nonfat, Fruit on Bottom, Blackberry, CHOBANI',
#  '11254': 'Lotus root, raw',
#  '11568': 'Turnip greens, raw',
#  '42289': 'Oil, corn and canola',
#  '9520': 'Kiwifruit, ZESPRI SunGold, raw',
#  '42291': 'Peanut butter, reduced sodium',
#  '23466': 'Beef, New Zealand, imported, rump centre, separable lean only, raw',
#  '5150': 'Goose, liver, raw',
#  '9528': 'Ruby Red grapefruit juice blend (grapefruit, grape, apple), OCEAN SPRAY, bottled, with added vitamin C',
#  '11578': 'Vegetable juice cocktail, canned',
#  '9531': 'Fruit juice smoothie, NAKED JUICE, strawberry banana',
#  '11583': 'Vegetables, mixed, frozen, unprepared',
#  '42304': 'Cheese, mozzarella, nonfat',
#  '11258': 'Mountain yam, hawaii, raw',
#  '42307': 'Margarine-like, butter-margarine blend, 80% fat, stick, without salt',
#  '9542': 'Plantains, green, raw',
#  '9544': 'Baobab powder',
#  '9546': 'Cherry juice, tart',
#  '5154': 'Pheasant, raw, meat only',
#  '9552': 'Raspberries, puree, seedless',
#  '11601': 'Yam, raw',
#  '13649': 'Beef, shoulder pot roast or steak, boneless, separable lean only, trimmed to 0" fat, select, raw',
#  '11603': 'Yambean (jicama), raw',
#  '9554': 'Raspberry juice concentrate',
#  '13648': 'Beef, shoulder pot roast or steak, boneless, separable lean only, trimmed to 0" fat, choice, raw',
#  '9231': 'Passion-fruit, (granadilla), purple, raw',
#  '11632': 'Peppers, jalapeno, canned, solids and liquids',
#  '11637': 'Radishes, white icicle, raw',
#  '11649': 'Tomato products, canned, sauce, spanish style',
#  '11653': 'Beans, pinto, mature seeds, sprouted, raw',
#  '11655': 'Carrot juice, canned',
#  '11663': 'Seaweed, agar, dried',
#  '9238': 'Peaches, canned, juice pack, solids and liquids',
#  '11669': 'Seaweed, wakame, raw',
#  '11672': 'Potato pancakes',
#  '19866': 'Candies, soft fruit and nut squares',
#  '19868': 'Sweeteners, tabletop, sucralose, SPLENDA packets',
#  '11677': 'Shallots, raw',
#  '11276': 'New Zealand spinach, raw',
#  '93600': 'Turtle, green, raw',
#  '17383': 'Lamb, New Zealand, imported, square-cut shoulder chops, separable lean only, raw',
#  '19879': 'Ice creams, BREYERS, All Natural Light Mint Chocolate Chip',
#  '19880': 'Ice creams, BREYERS, No Sugar Added, Butter Pecan',
#  '11695': 'Tomatoes, orange, raw',
#  '11696': 'Tomatoes, yellow, raw',
#  '11697': 'Arrowroot, raw',
#  '11698': 'Chrysanthemum leaves, raw',
#  '1021': 'Cheese, gjetost',
#  '19895': 'Ice creams, BREYERS, No Sugar Added, Chocolate Caramel',
#  '19896': "Candies, REESE's Fast Break, milk chocolate, peanut butter, soft nougats, candy bar",
#  '17387': 'Lamb, New Zealand, imported, loin saddle, separable lean only, raw',
#  '7212': 'Oscar Mayer, Ham (chopped with natural juice)',
#  '19903': 'Chocolate, dark, 60-69% cacao solids',
#  '19908': 'Sugar, turbinado',
#  '19909': 'Sweeteners, sugar substitute, granulated, brown',
#  '19911': 'Syrup, maple, Canadian',
#  '19912': 'Sweetener, syrup, agave',
#  '11722': 'Beans, snap, yellow, raw',
#  '19917': 'Candies, M&M MARS Pretzel Chocolate Candies',
#  '19918': 'Sweetener, herbal extract powder from Stevia leaf',
#  '13321': 'Beef, variety meats and by-products, heart, raw',
#  '19920': 'Jams, preserves, marmalades, sweetened with fruit juice',
#  '19921': 'Candies, Tamarind',
#  '13323': 'Beef, variety meats and by-products, kidneys, raw',
#  '11740': 'Broccoli, flower clusters, raw',
#  '11741': 'Broccoli, stalks, raw',
#  '9254': 'Pears, canned, juice pack, solids and liquids',
#  '13325': 'Beef, variety meats and by-products, liver, raw',
#  '11771': "Corn, sweet, yellow, canned, no salt added, solids and liquids (Includes foods for USDA's Food Distribution Program)",
#  '11772': 'Corn, sweet, yellow, canned, cream style, no salt added',
#  '9262': 'Pear nectar, canned, without added ascorbic acid',
#  '5653': 'Ostrich, round, raw',
#  '5654': 'Ostrich, tenderloin, raw',
#  '9265': 'Persimmons, native, raw',
#  '5655': 'Ostrich, tip trimmed, raw',
#  '7230': 'Oscar Mayer, Salami (hard)',
#  '5665': 'Turkey, ground, 93% lean, 7% fat, raw',
#  '20005': 'Barley, pearled, raw',
#  '13339': 'Beef, variety meats and by-products, tongue, raw',
#  '20008': 'Buckwheat',
#  '5674': 'Chicken, skin (drumsticks and thighs), raw',
#  '20011': 'Buckwheat flour, whole-groat',
#  '20012': 'Bulgur, dry',
#  '20014': 'Corn grain, yellow',
#  '20015': 'Corn bran, crude',
#  '20016': 'Corn flour, whole-grain, yellow',
#  '20017': 'Corn flour, masa, enriched, white',
#  '13341': 'Beef, variety meats and by-products, tripe, raw',
#  '13342': 'Beef, sandwich steaks, flaked, chopped, formed and thinly sliced, raw',
#  '20025': 'Cornmeal, yellow, self-rising, degermed, enriched',
#  '20027': 'Cornstarch',
#  '20028': 'Couscous, dry',
#  '20030': 'Hominy, canned, white',
#  '20031': 'Millet, raw',
#  '20033': 'Oat bran, raw',
#  '20035': 'Quinoa, uncooked',
#  '20036': "Rice, brown, long-grain, raw (Includes foods for USDA's Food Distribution Program)",
#  '13891': 'Beef, round, top round, steak, separable lean and fat, trimmed to 1/8" fat, all grades, raw',
#  '20038': "Oats (Includes foods for USDA's Food Distribution Program)",
#  '20042': "Rice, brown, parboiled, dry, UNCLE BEN'S",
#  '11311': 'Peas, green, canned, drained solids, rinsed in tap water',
#  '20049': 'Rice, white, long-grain, precooked or instant, enriched, prepared',
#  '20050': 'Rice, white, medium-grain, raw, enriched',
#  '20054': 'Rice, white, glutinous, unenriched, uncooked',
#  '20058': 'Rice, white, steamed, Chinese restaurant',
#  '20060': 'Rice bran, crude',
#  '20061': 'Rice flour, white, unenriched',
#  '20062': 'Rye grain',
#  '20065': 'Rye flour, light',
#  '20066': 'Semolina, enriched',
#  '20067': 'Sorghum grain',
#  '20068': 'Tapioca, pearl, dry',
#  '20070': 'Triticale flour, whole-grain',
#  '13926': 'Beef, tenderloin, separable lean and fat, trimmed to 1/8" fat, prime, raw',
#  '13929': 'Beef, top sirloin, steak, separable lean and fat, trimmed to 1/8" fat, all grades, raw',
#  '20074': 'Wheat, hard white',
#  '20075': 'Wheat, soft white',
#  '20076': 'Wheat, durum',
#  '20077': 'Wheat bran, crude',
#  '11886': 'Tomato juice, canned, without salt added',
#  '20078': 'Wheat germ, crude',
#  '20080': "Wheat flour, whole-grain (Includes foods for USDA's Food Distribution Program)",
#  '11885': 'Tomatoes, red, ripe, canned, packed in tomato juice, no salt added',
#  '20082': 'Wheat flour, white, all-purpose, self-rising, enriched',
#  '20083': 'Wheat flour, white, bread, enriched',
#  '20084': 'Wheat flour, white, cake, enriched',
#  '5740': 'Turkey, thigh, from whole bird, meat only, raw',
#  '20086': 'Wheat flour, white, tortilla mix, enriched',
#  '20087': 'Wheat, sprouted',
#  '20090': 'Rice flour, brown',
#  '20091': 'Pasta, gluten-free, corn, dry',
#  '11900': 'Corn, sweet, white, raw',
#  '20095': 'Pasta, fresh-refrigerated, spinach, as purchased',
#  '16001': 'Beans, adzuki, mature seeds, raw',
#  '20105': 'Macaroni, vegetable, enriched, dry',
#  '11913': 'Corn, sweet, white, frozen, kernels on cob, unprepared',
#  '20109': 'Noodles, egg, dry, enriched',
#  '16014': 'Beans, black, mature seeds, raw',
#  '16016': 'Beans, black turtle, mature seeds, raw',
#  '20113': 'Noodles, chinese, chow mein',
#  '20114': 'Noodles, japanese, soba, dry',
#  '16019': 'Beans, cranberry (roman), mature seeds, raw',
#  '20116': 'Noodles, japanese, somen, dry',
#  '13973': 'Beef, chuck eye roast, boneless, America\'s Beef Roast, separable lean only, trimmed to 0" fat, choice, raw',
#  '13974': 'Beef, chuck eye roast, boneless, America\'s Beef Roast, separable lean only, trimmed to 0" fat, select, raw',
#  '16022': 'Beans, french, mature seeds, raw',
#  '20120': 'Pasta, dry, enriched',
#  '16026': 'Beans, great northern, mature seeds, canned',
#  '20124': "Pasta, whole-wheat, dry (Includes foods for USDA's Food Distribution Program)",
#  '20126': 'Spaghetti, spinach, dry',
#  '11935': 'Catsup',
#  '16032': 'Beans, kidney, red, mature seeds, raw',
#  '20129': 'Wheat flours, bread, unenriched',
#  '11937': 'Pickles, cucumber, dill or kosher dill',
#  '20131': 'Barley malt flour',
#  '11940': 'Pickles, cucumber, sweet (includes bread and butter pickles)',
#  '20133': 'Rice noodles, dry',
#  '16037': 'Beans, navy, mature seeds, raw',
#  '11943': 'Pimento, canned',
#  '11941': 'Pickles, cucumber, sour',
#  '20135': 'Pasta, whole grain, 51% whole wheat, remaining unenriched semolina, dry',
#  '20132': 'Oat flour, partially debranned',
#  '16040': 'Beans, pink, mature seeds, raw',
#  '20140': 'Spelt, uncooked',
#  '11950': 'Mushrooms, enoki, raw',
#  '11951': 'Peppers, sweet, yellow, raw',
#  '11952': 'Radicchio, raw',
#  '11953': 'Squash, zucchini, baby, raw',
#  '11954': 'Tomatillos, raw',
#  '16049': 'Beans, white, mature seeds, raw',
#  '11955': 'Tomatoes, sun-dried',
#  '11957': 'Fennel, bulb, raw',
#  '11958': 'Pickle relish, hamburger',
#  '11959': 'Arugula, raw',
#  '16056': 'Chickpeas (garbanzo beans, bengal gram), mature seeds, raw',
#  '16055': 'Carob flour',
#  '11962': 'Peppers, hot chile, sun-dried',
#  '16059': 'Chili with beans, canned',
#  '11963': 'Nopales, raw',
#  '11956': 'Tomatoes, sun-dried, packed in oil, drained',
#  '16062': 'Cowpeas, common (blackeyes, crowder, southern), mature seeds, raw',
#  '16069': 'Lentils, raw',
#  '11974': 'Grape leaves, raw',
#  '11973': 'Beans, fava, in pod, raw',
#  '11976': 'Pepper, banana, raw',
#  '11977': 'Peppers, serrano, raw',
#  '14025': 'Alcoholic beverage, whiskey sour, prepared with water, whiskey and powder mix',
#  '11979': 'Peppers, jalapeno, raw',
#  '11980': 'Peppers, chili, green, canned',
#  '11978': 'Peppers, ancho, dried',
#  '11981': 'Peppers, hungarian, raw',
#  '11982': 'Peppers, pasilla, dried',
#  '16080': 'Mung beans, mature seeds, raw',
#  '11984': 'Epazote, raw',
#  '16082': 'Noodles, chinese, cellophane or long rice (mung beans), dehydrated',
#  '11987': 'Mushrooms, oyster, raw',
#  '11989': 'Mushrooms, straw, canned, drained solids',
#  '11990': 'Wasabi, root, raw',
#  '11992': 'Mushrooms, white, microwaved',
#  '11993': 'Mushrooms, maitake, raw',
#  '11141': 'Celeriac, raw',
#  '16091': 'Peanuts, spanish, raw',
#  '16093': 'Peanuts, valencia, raw',
#  '16095': 'Peanuts, virginia, raw',
#  '12001': 'Seeds, breadfruit seeds, raw',
#  '7908': 'Luncheon meat, pork with ham, minced, canned, includes Spam (Hormel)',
#  '16101': 'Pigeon peas (red gram), mature seeds, raw',
#  '12006': 'Seeds, chia seeds, dried',
#  '16103': 'Refried beans, canned, traditional style',
#  '16104': 'Bacon, meatless',
#  '7912': 'Roast beef spread',
#  '16106': 'Meat extender',
#  '7915': 'Sausage, Polish, beef with chicken, hot',
#  '7914': 'Sausage, Italian, sweet, links',
#  '12012': 'Seeds, hemp seed, hulled',
#  '12014': 'Seeds, pumpkin and squash seed kernels, dried',
#  '7919': 'Sausage, turkey, breakfast links, mild, raw',
#  '16112': 'Miso',
#  '16107': 'Sausage, meatless',
#  '16114': 'Tempeh',
#  '16115': 'Soy flour, full-fat, raw',
#  '7921': 'Bacon and beef sticks',
#  '16117': 'Soy flour, defatted',
#  '7926': 'Salami, Italian, pork',
#  ...}
