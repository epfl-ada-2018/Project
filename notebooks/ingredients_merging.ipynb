# %%
import numpy as np
import pandas as pd
import json
import matplotlib.pyplot as plt
import tqdm

# %% [markdown]
# ### read data

# %%
#whether we do the work with low_score or high_score mappings
high_score = True

# %%
#read usda mapping
if high_score :
    ing_mapping = json.load(open("./../generated/ing_usda_mapping_high_score.json"))
else :
    ing_mapping = json.load(open("./../generated/ing_usda_mapping_low_score.json"))

#read usda id description
item_describe = json.load(open("./../generated/usda_id_describe.json"))

#read cleaned recipes
cleaned_kaggle_recipes = json.load(open("./../generated/clean_kaggle_recipes.json"))['recipe']
cleaned_cookies_recipes = json.load(open("./../generated/clean_cookies_recipes.json"))['recipe']

cleaned_kaggle_recipes  = [cleaned_kaggle_recipes[c]  for c in cleaned_kaggle_recipes]
cleaned_cookies_recipes = [cleaned_cookies_recipes[c] for c in cleaned_cookies_recipes]

#read ingredients count
ingredients_count = json.load(open("./../generated/ingredients_count.json"))['count']

# %% [markdown]
# ### study mapping

# %% [markdown]
# > Ingredients have been mapped to USDA food items. We first identify the ingredients that have been mapped to the same food item and find a representative name for them.

# %% [markdown]
# #### spot collisions

# %%
mapped_ids = [ing_mapping[k] for k in ing_mapping]

#build dict to store collisions
collisions = {}

for m in tqdm.tqdm(ing_mapping) :
    if ing_mapping[m] not in collisions.keys() :
        collisions[ing_mapping[m]] = [m]
        
    else :
        collisions[ing_mapping[m]].append(m)
# Out:
# 100%|██████████| 1643/1643 [00:00<00:00, 290610.28it/s]

# %%
collisions
# Out:
# {2047: ['salt'],
#  11282: ['onion', 'raw onion'],
#  1145: ['butter'],
#  14555: ['water'],
#  1123: ['egg', 'raw egg'],
#  19908: ['sugar', 'turbinado', 'turbinado sugar'],
#  2030: ['black pepper'],
#  4053: ['olive oil', 'salad oil'],
#  11981: ['pepper'],
#  11215: ['garlic'],
#  20481: ['all-purpose flour', 'all-purpose', 'all-purpose white flour'],
#  11695: ['tomato'],
#  1212: ['milk'],
#  4669: ['vegetable oil'],
#  11165: ['cilantro'],
#  11297: ['parsley'],
#  2050: ['vanilla'],
#  11216: ['ginger', 'ginger root'],
#  9152: ['lemon juice'],
#  19334: ['brown sugar'],
#  16124: ['soy sauce', 'tamari soy sauce', 'tamari'],
#  11124: ['carrot', 'raw carrot'],
#  2014: ['cumin', 'cumin seed'],
#  28315: ['cinnamon'],
#  11292: ['green onion', 'onion top', 'green onion top'],
#  2044: ['basil'],
#  1146: ['parmesan cheese'],
#  2027: ['oregano'],
#  18371: ['baking powder'],
#  2049: ['thyme'],
#  7935: ['chicken breast'],
#  11362: ['potato', 'raw potato'],
#  6194: ['chicken broth', 'soup'],
#  18372: ['baking soda'],
#  9160: ['lime juice'],
#  2020: ['garlic powder'],
#  2009: ['chili powder'],
#  1179: ['sour cream'],
#  2004: ['bay'],
#  2028: ['paprika', 'spice'],
#  20063: ['flour'],
#  1270: ['cheddar cheese', 'cheddar'],
#  9156: ['lemon', 'lemon peel'],
#  2031: ['cayenne pepper', 'cayenne'],
#  4058: ['sesame oil'],
#  4572: ['nutmeg'],
#  25070: ['shrimp'],
#  19296: ['honey'],
#  9159: ['lime'],
#  4532: ['oil', 'hazelnut oil'],
#  14106: ['white wine'],
#  1053: ['heavy cream',
#   'heavy whipping cream',
#   'heavy',
#   'whipping heavy cream'],
#  11143: ['celery'],
#  11291: ['scallion', 'spring onion', 'or onion'],
#  43128: ['chicken'],
#  11993: ['mushroom'],
#  11677: ['shallot'],
#  12071: ['almond'],
#  42289: ['canola oil', 'corn oil'],
#  1017: ['cream cheese'],
#  4679: ['cooking spray', 'cooking oil'],
#  11457: ['spinach', 'raw spinach'],
#  1125: ['egg yolk'],
#  13350: ['beef'],
#  1124: ['egg white'],
#  2011: ['clove'],
#  2013: ['coriander', 'coriander seed'],
#  16104: ['bacon'],
#  6971: ['worcestershire sauce', 'worcestershire'],
#  11286: ['yellow onion'],
#  2065: ['mint'],
#  6172: ['chicken stock'],
#  28341: ['corn starch'],
#  1094: ['buttermilk'],
#  12142: ['pecan'],
#  11953: ['zucchini', 'zucchini squash'],
#  2063: ['rosemary'],
#  42304: ['mozzarella cheese', 'mozzarella'],
#  9299: ['raisin', 'seeded'],
#  43217: ['tomato sauce'],
#  16014: ['black bean', 'black'],
#  18079: ['bread crumb', 'plain bread crumb'],
#  12117: ['coconut milk'],
#  43598: ['mayonnaise'],
#  4528: ['walnut', 'walnut oil'],
#  6150: ['sauce', 'barbecue sauce'],
#  25071: ['rice', 'rice cracker'],
#  9039: ['avocado'],
#  6179: ['fish sauce'],
#  2068: ['wine vinegar', 'red'],
#  12023: ['sesame seed'],
#  9207: ['orange juice'],
#  43406: ['yeast'],
#  2043: ['turmeric'],
#  6164: ['salsa'],
#  20027: ['cornstarch'],
#  2069: ['balsamic vinegar', 'vinegar', 'balsamic'],
#  2032: ['white pepper'],
#  35239: ['corn tortilla'],
#  2026: ['onion powder'],
#  11205: ['cucumber'],
#  28309: ['coconut'],
#  18450: ['flour tortilla'],
#  11537: ['green chily', 'chily'],
#  11935: ['ketchup', 'catsup'],
#  10004: ['pork'],
#  1052: ['whipping cream'],
#  4630: ['margarine'],
#  2015: ['curry powder', 'curry'],
#  11270: ['mustard', 'mustard green'],
#  21150: ['white onion'],
#  20014: ['corn'],
#  2001: ['allspice'],
#  14553: ['wine'],
#  13000: ['lean beef', 'beef steak', 'lean steak', 'strip steak'],
#  11156: ['chive'],
#  19165: ['cocoa powder'],
#  1019: ['feta cheese', 'feta'],
#  2038: ['sage'],
#  11304: ['pea', 'green pea'],
#  16093: ['peanut'],
#  4615: ['shortening', 'vegetable shortening'],
#  11109: ['cabbage'],
#  9205: ['orange'],
#  5674: ['chicken thigh', 'chicken drumstick', 'drumstick'],
#  11980: ['chili pepper', 'green chili pepper', 'green chili'],
#  11052: ['green bean', 'bean'],
#  1030: ['cheese', 'muenster cheese', 'muenster'],
#  4042: ['peanut oil'],
#  2054: ['caper'],
#  6076: ['beef broth', 'cubed'],
#  1054: ['cream'],
#  11209: ['eggplant'],
#  6615: ['vegetable broth'],
#  19349: ['corn syrup'],
#  2048: ['cider vinegar', 'cider'],
#  11257: ['lettuce'],
#  7030: ['ham'],
#  9316: ['strawberry'],
#  1116: ['plain yogurt', 'plain milk yogurt'],
#  20452: ['white rice', 'short-grain rice', 'short-grain white rice'],
#  9040: ['banana'],
#  11246: ['leek'],
#  11333: ['green pepper'],
#  5305: ['turkey'],
#  2006: ['cardamom'],
#  2045: ['dill', 'dill weed'],
#  43476: ['tofu'],
#  6169: ['pepper sauce', 'tabasco pepper sauce', 'tabasco sauce', 'tabasco'],
#  22911: ['chili'],
#  11182: ['corn kernel', 'kernel corn'],
#  35131: ['cornmeal'],
#  20649: ['wheat flour'],
#  9004: ['apple'],
#  9429: ['pineapple'],
#  2037: ['saffron'],
#  1036: ['ricotta cheese', 'ricotta', 'milk ricotta cheese', 'milk ricotta'],
#  1033: ['parmesan'],
#  18163: ['chocolate chip'],
#  11029: ['kidney bean'],
#  16237: ['chocolate'],
#  16107: ['sausage'],
#  11962: ['chile', 'chile pepper'],
#  16157: ['chickpea', 'chickpea flour'],
#  6176: ['oyster sauce', 'oyster'],
#  6175: ['hoisin sauce'],
#  20126: ['spaghetti'],
#  6043: ['cream of mushroom soup'],
#  9236: ['peach'],
#  2018: ['fennel seed'],
#  9078: ['cranberry'],
#  20033: ['oat', 'oat bran'],
#  14050: ['rum'],
#  42291: ['peanut butter'],
#  3282: ['vegetable'],
#  6016: ['cream of chicken soup'],
#  11979: ['jalapeno pepper', 'jalapeno'],
#  2024: ['mustard seed'],
#  20444: ['long-grain rice'],
#  20129: ['bread flour', 'wheat bread flour'],
#  11356: ['russet potato', 'russet'],
#  27063: ['enchilada sauce'],
#  19433: ['tortilla chip', 'tortilla', 'chip', 'fat tortilla chip'],
#  20098: ['pasta'],
#  2041: ['tarragon'],
#  11090: ['broccoli'],
#  20084: ['cake flour', 'white wheat flour'],
#  7003: ['beer'],
#  18373: ['cream of tartar'],
#  11278: ['okra'],
#  11251: ['romaine lettuce', 'romaine'],
#  16069: ['lentil'],
#  11954: ['tomatillo'],
#  11011: ['asparagu'],
#  6972: ['chili sauce'],
#  20090: ['brown rice', 'rice flour', 'brown rice flour'],
#  9176: ['mango'],
#  11429: ['radish'],
#  43479: ['sake'],
#  7036: ['italian sausage',
#   'mild italian sausage',
#   'italian pork sausage',
#   'mild pork sausage'],
#  9050: ['blueberry'],
#  11422: ['pumpkin'],
#  9302: ['raspberry'],
#  18060: ['bread', 'rye bread'],
#  10060: ['pork tenderloin'],
#  4602: ['stick butter', 'sticks butter'],
#  1040: ['swiss cheese'],
#  2023: ['marjoram'],
#  1323: ['ghee'],
#  11653: ['pinto bean'],
#  19353: ['maple syrup'],
#  11485: ['butternut squash', 'winter squash'],
#  23656: ['flank steak', 'beef flank steak'],
#  20133: ['rice noodle'],
#  11959: ['arugula'],
#  2075: ['taco seasoning', 'taco seasoning mix', 'seasoning'],
#  11238: ['shiitake mushroom', 'shiitake'],
#  36058: ['olive'],
#  6633: ['sriracha'],
#  14423: ['ice water'],
#  11135: ['cauliflower'],
#  12151: ['nut', 'pistachio', 'pistachio nut', 'raw pistachio'],
#  6170: ['beef stock', 'stock'],
#  9021: ['apricot'],
#  6931: ['pasta sauce'],
#  19271: ['ice', 'strawberry ice cream'],
#  36054: ['marinara sauce'],
#  16056: ['garbanzo bean', 'bengal gram'],
#  10072: ['pork shoulder', 'lean pork'],
#  9502: ['granny smith apple', 'granny smith'],
#  20421: ['penne pasta',
#   'elbow macaroni',
#   'penne',
#   'pasta shell',
#   'farfalle pasta',
#   'shell pasta',
#   'shell macaroni'],
#  9221: ['juice', 'tangerine', 'tangerine juice'],
#  1157: ['goat cheese'],
#  11970: ['napa cabbage'],
#  11957: ['fennel bulb', 'fennel', 'bulb fennel', 'bulb'],
#  1029: ['part-skim mozzarella cheese',
#   'part-skim mozzarella',
#   'moisture mozzarella'],
#  20137: ['quinoa'],
#  9019: ['applesauce'],
#  18967: ['white bread'],
#  2055: ['horseradish'],
#  9452: ['pineapple juice'],
#  1287: ['greek yogurt', 'plain lowfat yogurt'],
#  1035: ['provolone cheese', 'provolone'],
#  18943: ['pie crust', 'crust'],
#  16399: ['creamy peanut butter'],
#  1038: ['romano cheese', 'romano'],
#  17224: ['lamb'],
#  2007: ['celery seed'],
#  20029: ['couscou'],
#  4501: ['cocoa', 'cocoa butter'],
#  15164: ['mussel'],
#  9216: ['orange peel', 'peel'],
#  9421: ['date', 'medjool date'],
#  20410: ['egg noodle'],
#  11080: ['beet'],
#  4047: ['coconut oil'],
#  42137: ['peppercorn'],
#  1175: ['fat milk'],
#  93600: ['green', 'raw'],
#  2034: ['poultry seasoning'],
#  43273: ['cottage cheese'],
#  12087: ['cashew nut', 'cashew', 'raw cashew'],
#  20115: ['noodle', 'soba noodle', 'soba'],
#  15085: ['salmon'],
#  28318: ['french bread'],
#  11116: ['bok choy', 'pak choi'],
#  9070: ['cherry'],
#  11233: ['kale', 'raw kale'],
#  12147: ['pine nut'],
#  9083: ['currant'],
#  3166: ['apple juice'],
#  16249: ['coffee'],
#  4002: ['lard'],
#  10050: ['pork chop',
#   'chop pork',
#   'bone-in pork chop',
#   'rib pork chop',
#   'pork rib chop'],
#  5312: ['chicken wing'],
#  14545: ['herb'],
#  14051: ['vodka'],
#  1004: ['blue cheese', 'blue'],
#  7063: ['pork sausage'],
#  2005: ['caraway seed'],
#  11943: ['pimento'],
#  16262: ['hazelnut'],
#  14019: ['tequila'],
#  15157: ['clam'],
#  2035: ['pumpkin pie spice', 'pumpkin spice'],
#  19095: ['vanilla ice cream'],
#  8314: ['grit', 'grit quick', 'hominy grit'],
#  16106: ['meat'],
#  19172: ['gelatin'],
#  18368: ['wonton wrapper', 'egg roll wrapper'],
#  11252: ['iceberg lettuce', 'iceberg'],
#  19813: ['plain flour'],
#  2046: ['yellow mustard'],
#  10024: ['pork loin'],
#  11564: ['turnip'],
#  14187: ['clam juice'],
#  1251: ['mexican cheese blend', 'mexican cheese', 'mexican blend cheese'],
#  2033: ['poppy seed'],
#  11886: ['tomato juice'],
#  18453: ['yellow cake mix'],
#  9322: ['tamarind'],
#  1228: ['queso fresco', 'queso fresco cheese'],
#  1023: ['gruyere cheese', 'gruyere'],
#  11026: ['bamboo shoot'],
#  16112: ['miso'],
#  90240: ['sea scallop', 'bay scallop'],
#  23079: ['chuck', 'chuck steak'],
#  19018: ['fruit'],
#  11764: ['celery salt'],
#  18175: ['lemon rind'],
#  15001: ['anchovy'],
#  9252: ['pear'],
#  19137: ['topping'],
#  32031: ['steak'],
#  1144: ['egg substitute'],
#  11298: ['parsnip'],
#  9042: ['blackberry'],
#  17137: ['sirloin', 'lean veal', 'lean sirloin'],
#  18457: ['fat-free', 'saltine cracker', 'saltine'],
#  5219: ['turkey breast'],
#  22401: ['spaghetti sauce', 'meat sauce'],
#  12698: ['tahini'],
#  6629: ['pesto', 'basil pesto sauce', 'basil pesto'],
#  16049: ['white bean'],
#  11977: ['serrano pepper', 'serrano'],
#  1020: ['fontina cheese', 'fontina'],
#  1151: ['nonfat milk', 'nonfat'],
#  11527: ['green tomato'],
#  27047: ['salsa verde'],
#  13929: ['sirloin steak', 'beef sirloin', 'beef sirloin steak'],
#  1267: ['cotija', 'cotija cheese'],
#  6624: ['thai curry', 'thai'],
#  20082: ['self-rising flour'],
#  7057: ['pepperoni'],
#  7943: ['lemon pepper'],
#  13973: ['chuck roast'],
#  9272: ['pineapple chunk'],
#  13346: ['beef brisket'],
#  11530: ['ripe tomato'],
#  11031: ['lima bean'],
#  18033: ['italian bread'],
#  11439: ['sauerkraut'],
#  15128: ['tuna'],
#  5075: ['chicken leg'],
#  17431: ['veal'],
#  12220: ['seed', 'flaxseed'],
#  11147: ['swiss chard', 'chard'],
#  10005: ['pork belly'],
#  6112: ['teriyaki sauce'],
#  1265: ['fat cheddar cheese'],
#  6094: ['onion soup mix'],
#  16026: ['great northern bean', 'great northern'],
#  43278: ['american cheese'],
#  2022: ['mace'],
#  6152: ['pizza sauce'],
#  7019: ['chorizo sausage', 'chorizo'],
#  11958: ['pickle relish', 'pickle'],
#  6159: ['tomato soup'],
#  35137: ['yellow cornmeal'],
#  4638: ['ranch dressing'],
#  4645: ['oil for frying',
#   'oil for deep frying',
#   'canola oil for frying',
#   'frying oil'],
#  11007: ['artichoke'],
#  9423: ['prune'],
#  15097: ['fish'],
#  11118: ['kimchi'],
#  11603: ['jicama'],
#  9328: ['maraschino cherry'],
#  28340: ['potato starch', 'tapioca starch'],
#  4506: ['sunflower oil'],
#  43017: ['salad green'],
#  9089: ['fig'],
#  18338: ['dough', 'phyllo dough', 'phyllo'],
#  32002: ['rice vermicelli', 'rice pilaf'],
#  4576: ['fat', 'goose fat'],
#  11098: ['brussels sprout', 'sprout'],
#  2002: ['anise', 'anise seed'],
#  23441: ['beef tenderloin'],
#  16037: ['navy bean'],
#  11260: ['white mushroom'],
#  20078: ['wheat germ'],
#  11937: ['dill pickle', 'kosher', 'kosher dill pickle'],
#  12040: ['sunflower seed'],
#  15175: ['squid'],
#  28295: ['wheat tortilla'],
#  11300: ['sugar pea', 'raw sugar', 'sugar snap pea', 'snap pea'],
#  20044: ['long-grain white rice'],
#  6963: ['broth'],
#  11805: ['onion salt'],
#  18212: ['vanilla wafer'],
#  19206: ['vanilla pudding mix'],
#  20105: ['macaroni'],
#  19087: ['white chocolate'],
#  28342: ['tapioca flour'],
#  9279: ['plum'],
#  2019: ['fenugreek', 'fenugreek seed'],
#  17086: ['lamb shoulder'],
#  6010: ['cream of celery soup'],
#  43535: ['apples -', 'apple -'],
#  9129: ['grape'],
#  19303: ['orange marmalade', 'marmalade'],
#  9501: ['delicious apple'],
#  5115: ['roasting chicken'],
#  10946: ['pork butt', 'pork shoulder boston butt', 'boston butt'],
#  6080: ['chicken bouillon'],
#  12116: ['coconut cream'],
#  9218: ['mandarin orange'],
#  9110: ['berry', 'goji berry'],
#  16161: ['silken tofu', 'soft tofu', 'soft silken tofu'],
#  21497: ['pizza crust'],
#  14542: ['lemonade', 'pink lemonade'],
#  18243: ['crouton'],
#  35136: ['white cornmeal'],
#  9133: ['seedless grape'],
#  11266: ['crimini mushroom', 'brown mushroom'],
#  43441: ['roll'],
#  12163: ['pumpkin seed'],
#  11547: ['tomato puree'],
#  5027: ['chicken liver'],
#  18337: ['puff pastry'],
#  18139: ['cake', 'white'],
#  21415: ['biscuit'],
#  20330: ['hominy', 'yellow hominy'],
#  19078: ['squares chocolate',
#   'square chocolate',
#   'squares baking chocolate',
#   'chocolate square'],
#  11212: ['edamame'],
#  4636: ['italian salad dressing', 'italian dressing'],
#  5356: ['rotisserie chicken'],
#  14163: ['soy milk'],
#  9202: ['navel orange'],
#  18419: ['white cake mix'],
#  1295: ['yogurt', 'vanilla yogurt'],
#  6174: ['fish stock'],
#  11772: ['cream style corn'],
#  10094: ['pork loin chop', 'loin', 'loin pork chop'],
#  36029: ['fish fillet'],
#  16059: ['chili bean'],
#  20030: ['white hominy'],
#  9307: ['rhubarb'],
#  14121: ['club soda'],
#  15172: ['scallop'],
#  10864: ['bacon dripping', 'dripping'],
#  13979: ['skirt steak'],
#  43016: ['salad dressing', 'salad'],
#  20061: ['white flour', 'white rice flour'],
#  11243: ['portobello mushroom'],
#  19352: ['syrup', 'malt syrup'],
#  20316: ['corn flour'],
#  27064: ['wasabi'],
#  6983: ['ramen noodle', 'chicken ramen noodle'],
#  19314: ['cherry pie filling'],
#  11214: ['escarole'],
#  18942: ['graham cracker crust', 'graham cracker pie crust'],
#  11951: ['yellow pepper'],
#  11952: ['radicchio'],
#  7070: ['salami'],
#  20466: ['semolina'],
#  18029: ['sourdough bread', 'sourdough'],
#  15147: ['lobster'],
#  18042: ['pita bread', 'pita', 'whole-wheat bread'],
#  43134: ['fillet'],
#  19719: ['apricot preserve', 'apricot jam'],
#  19868: ['splenda'],
#  23066: ['beef rib short', 'beef short rib', 'short rib'],
#  6960: ['alfredo sauce'],
#  14649: ['tea', 'hibiscu'],
#  28292: ['cracker'],
#  18174: ['graham cracker'],
#  11492: ['spaghetti squash'],
#  4015: ['dressing'],
#  11601: ['yam'],
#  10225: ['pork loin roast', 'pork roast', 'loin pork roast'],
#  18176: ['marshmallow'],
#  18040: ['oatmeal'],
#  11265: ['portabello mushroom', 'portabella mushroom'],
#  5123: ['chicken meat'],
#  4698: ['canola'],
#  14210: ['espresso', 'espresso coffee'],
#  6622: ['masala'],
#  22901: ['cheese tortellini', 'tortellini'],
#  11370: ['hash brown potato', 'brown hash potato'],
#  1117: ['fat yogurt'],
#  18448: ['taco shell', 'shell'],
#  19024: ['milk chocolate chip'],
#  43299: ['curd', 'cheese curd'],
#  7927: ['italian turkey sausage', 'turkey italian sausage'],
#  43154: ['cooking wine'],
#  5143: ['duck', 'duck liver'],
#  11482: ['acorn squash'],
#  6631: ['chile sauce', 'sriracha sauce'],
#  11096: ['broccoli rabe'],
#  9326: ['watermelon'],
#  11119: ['chinese cabbage'],
#  10165: ['salt pork'],
#  7970: ['kielbasa'],
#  11114: ['savoy cabbage'],
#  1223: ['milk powder', 'protein supplement'],
#  11531: ['tomato in juice'],
#  1187: ['nonfat yogurt'],
#  21158: ['white sandwich bread'],
#  7074: ['sausage link', 'link sausage', 'links pork sausage'],
#  5668: ['lean turkey'],
#  14414: ['coffee liqueur'],
#  14028: ['whiskey', 'sour mix'],
#  8444: ['country ham'],
#  11442: ['seaweed'],
#  1006: ['brie cheese', 'brie'],
#  20121: ['rotini', 'rotini pasta', 'farfalle'],
#  43114: ['vermicelli'],
#  19348: ['chocolate syrup'],
#  23175: ['rib eye steak', 'beef rib eye steak'],
#  16166: ['soymilk'],
#  18423: ['ladyfinger'],
#  20005: ['barley'],
#  17000: ['rib', 'rib roast'],
#  19184: ['chocolate pudding mix', 'chocolate mix'],
#  15015: ['cod', 'cod fish'],
#  18064: ['wheat bread'],
#  19909: ['sugar substitute', 'brown sugar substitute'],
#  14303: ['limeade'],
#  42063: ['liquid', 'pectin', 'liquid pectin'],
#  43382: ['cranberry juice'],
#  19201: ['vanilla pudding'],
#  1186: ['fat cream cheese', 'fat cheese', 'fat cream'],
#  43364: ['corn tortilla chip', 'corn chip', 'white corn tortilla'],
#  5327: ['chicken breast tender'],
#  19120: ['milk chocolate', 'chocolate milk'],
#  13974: ['beef chuck roast'],
#  1159: ['soft goat cheese', 'goat'],
#  10087: ['pork shoulder roast', 'shoulder roast'],
#  20325: ['self-rising cornmeal'],
#  19132: ['almond milk'],
#  19039: ['popcorn'],
#  27048: ['steak sauce'],
#  11973: ['fava bean'],
#  2064: ['peppermint'],
#  43132: ['meatball'],
#  18084: ['cornbread', 'cornbread stuffing mix'],
#  9340: ['asian pear'],
#  14161: ['kiwi'],
#  9422: ['or'],
#  16156: ['chunky peanut butter'],
#  12202: ['chestnut'],
#  2008: ['chervil'],
#  9226: ['papaya'],
#  17017: ['lamb shank'],
#  18361: ['pastry'],
#  20077: ['wheat bran'],
#  1012: ['curd cottage cheese'],
#  2039: ['savory'],
#  9181: ['cantaloupe', 'melon'],
#  6008: ['beef bouillon'],
#  11475: ['summer squash'],
#  1011: ['colby cheese', 'colby'],
#  4511: ['safflower oil'],
#  35138: ['squash'],
#  19154: ['sesame'],
#  11984: ['epazote'],
#  20113: ['chow mein noodle', 'chinese noodle'],
#  7058: ['pimiento'],
#  11987: ['oyster mushroom'],
#  43212: ['bacon bit'],
#  10130: ['canadian bacon'],
#  1191: ['velveeta cheese', 'velveeta'],
#  20012: ['bulgur'],
#  11253: ['green lettuce'],
#  10088: ['pork sparerib', 'sparerib'],
#  20065: ['rye flour'],
#  7954: ['breakfast sausage'],
#  9132: ['seedless green grape', 'green grape', 'green seedless grape'],
#  11435: ['rutabaga'],
#  13227: ['beef shank'],
#  15139: ['crab', 'blue crab'],
#  12131: ['macadamia nut'],
#  18097: ['chocolate cake mix'],
#  20087: ['wheat'],
#  9081: ['cranberry sauce'],
#  1193: ["breakstone'"],
#  36020: ['chicken finger'],
#  42157: ['fat-free sour cream', 'fat-free buttermilk'],
#  9542: ['plantain', 'green plantain'],
#  19270: ['ice cream', 'chocolate ice cream'],
#  11976: ['banana pepper'],
#  1022: ['gouda', 'gouda cheese'],
#  9442: ['pomegranate juice'],
#  6626: ['pesto sauce'],
#  14533: ['gin'],
#  1180: ['fat sour cream'],
#  4609: ['bacon grease', 'bacon fat'],
#  7912: ['beef roast', 'roast', 'roast beef'],
#  7955: ['turkey sausage'],
#  18621: ['ritz cracker'],
#  19124: ['baking chocolate', 'mexican chocolate'],
#  9546: ['tart cherry', 'cherry juice'],
#  11322: ['peas and carrot'],
#  28307: ['naan', 'naan bread'],
#  14534: ['liqueur'],
#  3046: ['cheese ravioli'],
#  22978: ['chicken tender'],
#  16080: ['mung bean', 'raw mung bean'],
#  20011: ['buckwheat flour'],
#  11250: ['boston lettuce', 'bibb lettuce', 'boston bibb'],
#  11945: ['relish'],
#  16398: ['smooth peanut butter'],
#  19375: ['frosting', 'glaze'],
#  11354: ['white potato'],
#  43109: ['pretzel'],
#  9191: ['nectarine'],
#  15101: ['snapper'],
#  11989: ['straw mushroom'],
#  15261: ['tilapia'],
#  11149: ['chayote'],
#  14152: ['burgundy wine', 'burgundy'],
#  43390: ['meat bone', 'or turkey'],
#  43276: ['base', 'cheese spread', 'cream cheese spread'],
#  9128: ['grapefruit', 'grapefruit juice'],
#  9414: ['bosc pear'],
#  19107: ['candy'],
#  18172: ['cookie', 'gingersnap'],
#  21319: ['hash brown'],
#  17180: ['rabbit'],
#  44158: ['filling', 'blueberry pie filling'],
#  28293: ['icing sugar', 'or sugar'],
#  10207: ['pork rib',
#   'country-style pork rib',
#   'pork country-style rib',
#   'country pork rib'],
#  18264: ['english muffin'],
#  5145: ['duck breast'],
#  19297: ['jam'],
#  18010: ['buttermilk biscuit', 'biscuit mix'],
#  15130: ['whitefish'],
#  11568: ['turnip green'],
#  23094: ['beef chuck', 'beef for stew'],
#  19106: ['starch', 'gumdrop'],
#  21228: ['hamburger'],
#  25022: ['french onion'],
#  11900: ['white corn'],
#  48052: ['gluten', 'vital wheat gluten', 'wheat gluten'],
#  18081: ['stuffing', 'stuffing mix', 'bread stuffing mix', 'bread mix'],
#  11167: ['yellow corn'],
#  19918: ['stevia', 'stevia powder'],
#  19074: ['caramel'],
#  43100: ['coconut sugar'],
#  4704: ['creamy salad dressing'],
#  9097: ['cocktail cherry'],
#  1314: ['plain nonfat yogurt',
#   'nonfat yogurt plain',
#   'nonfat plain yogurt',
#   'nonfat plain greek yogurt'],
#  19416: ['rice cake'],
#  19823: ['potato chip'],
#  1034: ['port'],
#  22973: ['dog'],
#  19912: ['sweetener', 'agave syrup'],
#  14211: ['black tea'],
#  5165: ['turkey meat'],
#  17425: ['veal cutlet', 'cutlet'],
#  20135: ['wheat spaghetti', 'wheat pasta', 'wheat rotini pasta'],
#  6032: ['beef consomme'],
#  35190: ['filet', 'salmon filet'],
#  20019: ['masa'],
#  2016: ['dill seed'],
#  16147: ['veggie'],
#  35144: ['dumpling'],
#  1047: ['cheese food'],
#  35030: ['or cranberry'],
#  10040: ['center pork chop',
#   'center loin pork chop',
#   'center',
#   'center pork loin chop'],
#  4583: ['mustard oil'],
#  16118: ['soy flour'],
#  7915: ['chicken sausage'],
#  12016: ['pepita'],
#  21416: ['coleslaw'],
#  9063: ['sour cherry'],
#  23372: ['beef tenderloin steak',
#   'beef fillet',
#   'steak fillet',
#   'tenderloin steak'],
#  27059: ['peanut sauce'],
#  10149: ['ham steak'],
#  14260: ['green tea'],
#  6121: ['gravy'],
#  18947: ['deep dish pie crust'],
#  14144: ['soda', 'lemon-lime soda'],
#  18973: ['flatbread', 'focaccia'],
#  8639: ['cinnamon sugar'],
#  14136: ['ginger ale', 'ale'],
#  18952: ['tostada shell', 'tostada'],
#  36024: ['chicken tenderloin'],
#  15270: ['raw shrimp'],
#  17278: ['veal shank', 'shank'],
#  20054: ['glutinous rice'],
#  15038: ['halibut'],
#  1285: ['nonfat greek yogurt'],
#  9503: ['gala apple', 'gala'],
#  7028: ['deli ham'],
#  43392: ['heart of palm', 'of'],
#  4014: ['miracle whip',
#   'miracle whip dressing',
#   'kraft miracle whip dressing'],
#  16114: ['tempeh'],
#  4706: ['honey mustard'],
#  15048: ['jack'],
#  8156: ['rice cereal'],
#  11697: ['arrowroot'],
#  9251: ['peach nectar'],
#  19294: ['apple butter'],
#  11445: ['kelp'],
#  19312: ['apple pie filling', 'pie filling'],
#  16158: ['hummu'],
#  23607: ['new york strip steak'],
#  15091: ['sea bass'],
#  9184: ['honeydew melon', 'honeydew'],
#  9412: ['bartlett pear', 'bartlett'],
#  18022: ['cornbread mix', 'corn bread mix'],
#  12195: ['almond butter'],
#  36055: ['italian cheese', 'marinara'],
#  13335: ['suet'],
#  5015: ['fryer chicken', 'fryer'],
#  5309: ['cornish game hen', 'cornish hen'],
#  4708: ['fat mayonnaise'],
#  27049: ['tartar sauce'],
#  17078: ['lamb loin chop', 'lamb chop'],
#  11578: ['vegetable juice', 'vegetable juice cocktail'],
#  9351: ['fruit cocktail'],
#  7973: ['turkey bacon'],
#  11450: ['soybean'],
#  7934: ['turkey kielbasa', 'polish kielbasa'],
#  4648: ['flavoring'],
#  10006: ['pork fat'],
#  20031: ['millet'],
#  6053: ['cream of potato soup'],
#  20068: ['tapioca', 'pearl tapioca', 'tapioca pearl'],
#  9149: ['kumquat'],
#  13407: ['cube steak', 'beef cube steak'],
#  15186: ['tuna in water', 'solid white tuna in water', 'white tuna in water'],
#  8402: ['quick oat'],
#  18370: ['double-acting baking powder'],
#  4594: ['sardine'],
#  18964: ['bun'],
#  19300: ['jelly'],
#  16123: ['shoyu'],
#  20050: ['medium-grain rice', 'raw white rice'],
#  35141: ['mutton'],
#  9278: ['yellow'],
#  16011: ['bean sauce'],
#  15031: ['grouper'],
#  23181: ['back rib'],
#  5193: ['turkey leg'],
#  9504: ['fuji apple'],
#  18280: ['corn mix muffin', 'corn muffin mix'],
#  42173: ['bulk pork sausage', 'bulk sausage'],
#  4635: ['thousand island dressing', 'thousand island salad dressing'],
#  28348: ['dinner roll'],
#  16115: ['soy'],
#  18069: ['soft bread crumb', 'white bread crumb'],
#  19027: ['peanut butter chip'],
#  16010: ['pork and bean'],
#  18152: ['brownie mix'],
#  25036: ['granola'],
#  1137: ['yolk'],
#  6116: ['beef gravy'],
#  42307: ['butter-margarine blend'],
#  18204: ['vanilla sugar'],
#  11963: ['nopale'],
#  11199: ['yardlong bean'],
#  14461: ['lemon-lime beverage'],
#  15010: ['catfish'],
#  1039: ['roquefort cheese', 'roquefort'],
#  13926: ['filet mignon'],
#  18353: ['kaiser roll', 'hard roll'],
#  6042: ['mushroom soup'],
#  35240: ['corn bread'],
#  16172: ['fat-free bean'],
#  1003: ['butter oil'],
#  17343: ['venison'],
#  14189: ['coca-cola'],
#  1306: ['chocolate sauce'],
#  27050: ['sour sauce'],
#  23059: ['iron steak'],
#  7040: ['liver', 'pork liver'],
#  19279: ['coffee bean'],
#  19021: ['soft butter'],
#  18268: ['toast'],
#  31033: ['artificial sweetener'],
#  19365: ['marshmallow cream'],
#  4367: ['french dressing', 'french salad dressing'],
#  11170: ['brine'],
#  6243: ['fat cream of mushroom soup'],
#  16082: ['long bean', 'cellophane noodle', 'mung bean noodle'],
#  15033: ['haddock'],
#  18017: ['biscuit dough'],
#  16101: ['pigeon pea'],
#  5000: ['chicken breast meat'],
#  18376: ['crumb'],
#  11518: ['taro'],
#  19226: ['chocolate frosting'],
#  9286: ['pomegranate'],
#  7050: ['mortadella'],
#  42153: ['blue cheese dressing'],
#  28335: ['gluten-free vanilla'],
#  28294: ['icing'],
#  15115: ['trout', 'rainbow trout'],
#  6151: ['plum sauce'],
#  1057: ['eggnog'],
#  16171: ['vegetarian bean'],
#  36043: ['lasagne'],
#  12006: ['chia seed'],
#  14073: ['cola'],
#  22914: ['tomato pasta sauce'],
#  11669: ['wakame'],
#  11239: ['chanterelle', 'chanterelle mushroom'],
#  15012: ['caviar'],
#  9296: ['quince'],
#  11161: ['collard'],
#  5157: ['quail'],
#  1166: ['asadero', 'queso asadero'],
#  8025: ['crisp rice cereal'],
#  42040: ['grenadine syrup', 'grenadine'],
#  20036: ['long-grain brown rice'],
#  18114: ['cake mix'],
#  15143: ['dungeness crab'],
#  13383: ['pot roast'],
#  22899: ['ravioli'],
#  28324: ['pancake mix'],
#  27051: ['cocktail sauce'],
#  43344: ['preserve'],
#  15108: ['raw pumpkin seed'],
#  14155: ['soda water', 'tonic water'],
#  14145: ['sprite'],
#  19911: ['maple'],
#  4617: ['stick margarine'],
#  19364: ['caramel topping'],
#  9036: ['apricot nectar'],
#  18349: ['french roll'],
#  19332: ['lemon pudding mix'],
#  19091: ['peppermint candy'],
#  1229: ['queso blanco', 'white cheese'],
#  10080: ['pork shoulder butt', 'pork steak'],
#  11240: ['morel'],
#  17461: ['lamb rib chop'],
#  5284: ['turkey broth'],
#  17353: ['lean lamb'],
#  14613: ['passion fruit', 'passion fruit juice'],
#  18133: ['sponge cake', 'sponge'],
#  14242: ['cranberry juice cocktail'],
#  9413: ['anjou pear'],
#  19438: ['rice krispy'],
#  43015: ['caesar salad dressing'],
#  10963: ['sirloin tip roast', 'sirloin tip'],
#  11940: ['bread and butter pickle'],
#  11696: ['yellow tomato'],
#  14160: ['chardonnay', 'chardonnay wine'],
#  14097: ['cabernet sauvignon'],
#  7914: ['italian sausage link', 'links italian sausage'],
#  7051: ['loaf'],
#  8160: ['corn grit'],
#  18234: ['butter cracker'],
#  14218: ['coffee powder'],
#  9144: ['jackfruit'],
#  13023: ['brisket'],
#  1225: ['dulce de leche'],
#  16095: ['raw peanut'],
#  1088: ['lowfat buttermilk'],
#  6981: ['bouillon', 'bouillon cube'],
#  36018: ['hand'],
#  35054: ['octopus'],
#  11413: ['potato flour'],
#  1031: ['neufchatel cheese'],
#  19230: ['vanilla frosting'],
#  28339: ['grain bread'],
#  90480: ['cane syrup'],
#  44074: ['grape juice'],
#  16032: ['kidney'],
#  9140: ['guava'],
#  6307: ['kraft original barbecue sauce'],
#  21505: ['thin pizza crust', 'pizza topping'],
#  17156: ['lean meat'],
#  6611: ['lower beef broth', 'swanson beef broth'],
#  25017: ['chocolate bar'],
#  6930: ['cheese sauce'],
#  15083: ['pink salmon'],
#  20132: ['oat flour'],
#  21525: ['breadstick'],
#  21396: ['condiment'],
#  14132: ['riesling'],
#  16315: ['black salt'],
#  18239: ['croissant'],
#  11978: ['ancho'],
#  12097: ['unpeeled'],
#  13339: ['beef tongue'],
#  23342: ['filet mignon steak'],
#  43408: ['pear juice'],
#  15107: ['white fish'],
#  43112: ['ranch style bean'],
#  5282: ['foie gra'],
#  16119: ['meal'],
#  32011: ['yellow rice'],
#  16001: ['adzuki bean'],
#  14075: ['sparkling water'],
#  43026: ['sugar syrup'],
#  20647: ['millet flour'],
#  4581: ['avocado oil'],
#  9038: ['california avocado'],
#  11254: ['lotus root'],
#  9138: ['poha'],
#  43137: ['meatloaf'],
#  16258: ['key lime'],
#  2010: ['cassia cinnamon'],
#  7053: ['liver pate'],
#  2076: ['chili seasoning mix', 'chili seasoning', 'seasoning mix'],
#  21238: ['french fry'],
#  1162: ['fat greek yogurt'],
#  7956: ['beef sausage'],
#  20420: ['elbow pasta'],
#  4055: ['palm oil'],
#  7910: ['bratwurst'],
#  5227: ['turkey wing'],
#  1014: ['nonfat cottage cheese'],
#  20141: ['spelt'],
#  20655: ['gluten-free flour', 'quinoa flour'],
#  18320: ['meringue'],
#  18228: ['oyster cracker', 'soda cracker'],
#  16235: ['plain', 'plain soymilk'],
#  1305: ['lowfat milk'],
#  8061: ['bran cereal'],
#  14639: ['rice milk'],
#  9404: ['pink grapefruit', 'pink grapefruit juice'],
#  13325: ['beef liver'],
#  27066: ['horseradish sauce'],
#  23431: ['beef rib'],
#  1167: ['chihuahua cheese'],
#  10980: ['bone-in'],
#  7059: ['polish sausage'],
#  2066: ['spearmint'],
#  32018: ['spanish rice'],
#  11024: ['bitter'],
#  21244: ['chicken fillet'],
#  9107: ['gooseberry'],
#  4128: ['fat margarine'],
#  13891: ['london broil'],
#  1286: ['nonfat vanilla yogurt'],
#  43589: ['fat swiss cheese'],
#  12154: ['black walnut'],
#  20648: ['sorghum flour'],
#  4530: ['kernel'],
#  18323: ['pie'],
#  16040: ['pink bean'],
#  6620: ['french lentil'],
#  5171: ['giblet', 'turkey giblet'],
#  8083: ['corn cereal'],
#  25037: ['pita chip'],
#  20131: ['barley flour'],
#  90560: ['snail'],
#  9520: ['kiwifruit'],
#  11207: ['dandelion green'],
#  6126: ['turkey gravy'],
#  6011: ['cheese soup'],
#  6192: ['or pea'],
#  23646: ['tri-tip roast', 'bottom roast', 'beef bottom roast', 'beef bottom'],
#  7043: ['deli roast beef', 'deli beef'],
#  14099: ['pinot noir'],
#  9164: ['lychee'],
#  13342: ['flaked'],
#  35028: ['cockle'],
#  5295: ['roast turkey'],
#  12119: ['coconut water'],
#  11637: ['white radish'],
#  16019: ['cranberry bean'],
#  1140: ['quail egg'],
#  7071: ['hard salami'],
#  7919: ['turkey breakfast sausage'],
#  19183: ['chocolate pudding', 'pudding'],
#  19340: ['maple sugar'],
#  6377: ["campbell's tomato soup"],
#  18044: ['pumpernickel bread'],
#  12078: ['brazil nut'],
#  12021: ['safflower'],
#  14157: ['root beer'],
#  19186: ['crisp', 'crisp apple'],
#  11134: ['cassava'],
#  17074: ['lamb leg'],
#  9436: ['mango nectar'],
#  23360: ['eye of roast', 'beef eye of roast'],
#  13464: ['porterhouse steak'],
#  28397: ['whole-grain bread'],
#  14366: ['tea powder'],
#  27065: ['bean dip'],
#  18363: ['or corn'],
#  5016: ['batter'],
#  14250: ['hard cider'],
#  4668: ['soy margarine'],
#  5023: ['chicken gizzard'],
#  16125: ['vegetable protein'],
#  20136: ['wheat penne', 'wheat penne pasta'],
#  20124: ['whole-wheat spaghetti', 'whole-wheat penne'],
#  1293: ['milk greek yogurt'],
#  14102: ['zinfandel'],
#  1071: ['ounce', 'ounce milk'],
#  18205: ['sugar cookie dough'],
#  9433: ['clementine'],
#  42281: ['guar gum'],
#  17383: ['lamb shoulder chop'],
#  3007: ['pork meat'],
#  19110: ['chocolate candy bar'],
#  6338: ["campbell's cream of mushroom soup"],
#  20067: ['sorghum'],
#  14411: ['tap water'],
#  4551: ['or coconut'],
#  12012: ['hemp seed'],
#  21247: ['french'],
#  10934: ['bone-in ham'],
#  19129: ['pancake syrup'],
#  ...}

# %% [markdown]
# #### find representative name for each group

# %%
import collections


item_number = 43
proportion = 0.5

representative_keys = dict()

for i, c in tqdm.tqdm(enumerate(collisions)) :
    
    all_items = " ".join(collisions[c]).split(" ")
    counter = collections.Counter()
    counter.update(all_items)

    #find common names
    common_names = [x[0] for x in counter.most_common() if x[1] > len(collisions[c])*proportion]

    #choose database description
    if len(common_names) == 0 :
        representative_keys[c] = item_describe[str(c)]

    elif len(common_names) == 1 :
        representative_keys[c] = common_names[0]

    else :
        #determine order

        #case 1, there exist an entry with only wanted words
        exact_match = [x.split(" ") for x in collisions[c] if (len(set(common_names).difference(set(x.split(" "))))== 0)]
        if len(exact_match) != 0 :
            representative_keys[c] = " ".join(exact_match[0])

        #case 2, no exact match
        else :

            all_words_collisions = [x.split(" ") for x in collisions[c] if set(common_names).issubset(set(x.split(" ")))]

            index_tuples = [ (word, index) for collision in all_words_collisions for index, word in enumerate(collision) if (word in common_names)]

            index_counts = np.array([0]*len(common_names))

            #average the relative indices
            for it in index_tuples :
                word_index = common_names.index(it[0])
                index_counts[word_index] += it[1]

            index_counts = index_counts

            common_names_ordered = " ".join([common_names[i] for i in np.argsort(index_counts)])
            representative_keys[c] = common_names_ordered
# Out:
# 1260it [00:00, 152926.18it/s]

# %%
representative_keys
# Out:
# {2047: 'salt',
#  11282: 'onion',
#  1145: 'butter',
#  14555: 'water',
#  1123: 'egg',
#  19908: 'turbinado sugar',
#  2030: 'black pepper',
#  4053: 'oil',
#  11981: 'pepper',
#  11215: 'garlic',
#  20481: 'all-purpose flour',
#  11695: 'tomato',
#  1212: 'milk',
#  4669: 'vegetable oil',
#  11165: 'cilantro',
#  11297: 'parsley',
#  2050: 'vanilla',
#  11216: 'ginger',
#  9152: 'lemon juice',
#  19334: 'brown sugar',
#  16124: 'tamari soy sauce',
#  11124: 'carrot',
#  2014: 'cumin',
#  28315: 'cinnamon',
#  11292: 'green onion top',
#  2044: 'basil',
#  1146: 'parmesan cheese',
#  2027: 'oregano',
#  18371: 'baking powder',
#  2049: 'thyme',
#  7935: 'chicken breast',
#  11362: 'potato',
#  6194: 'Soup, chicken broth, ready-to-serve',
#  18372: 'baking soda',
#  9160: 'lime juice',
#  2020: 'garlic powder',
#  2009: 'chili powder',
#  1179: 'sour cream',
#  2004: 'bay',
#  2028: 'Spices, paprika',
#  20063: 'flour',
#  1270: 'cheddar',
#  9156: 'lemon',
#  2031: 'cayenne',
#  4058: 'sesame oil',
#  4572: 'nutmeg',
#  25070: 'shrimp',
#  19296: 'honey',
#  9159: 'lime',
#  4532: 'oil',
#  14106: 'white wine',
#  1053: 'heavy cream',
#  11143: 'celery',
#  11291: 'onion',
#  43128: 'chicken',
#  11993: 'mushroom',
#  11677: 'shallot',
#  12071: 'almond',
#  42289: 'oil',
#  1017: 'cream cheese',
#  4679: 'cooking',
#  11457: 'spinach',
#  1125: 'egg yolk',
#  13350: 'beef',
#  1124: 'egg white',
#  2011: 'clove',
#  2013: 'coriander',
#  16104: 'bacon',
#  6971: 'worcestershire',
#  11286: 'yellow onion',
#  2065: 'mint',
#  6172: 'chicken stock',
#  28341: 'corn starch',
#  1094: 'buttermilk',
#  12142: 'pecan',
#  11953: 'zucchini',
#  2063: 'rosemary',
#  42304: 'mozzarella',
#  9299: 'Raisins, seeded',
#  43217: 'tomato sauce',
#  16014: 'black',
#  18079: 'bread crumb',
#  12117: 'coconut milk',
#  43598: 'mayonnaise',
#  4528: 'walnut',
#  6150: 'sauce',
#  25071: 'rice',
#  9039: 'avocado',
#  6179: 'fish sauce',
#  2068: 'Vinegar, red wine',
#  12023: 'sesame seed',
#  9207: 'orange juice',
#  43406: 'yeast',
#  2043: 'turmeric',
#  6164: 'salsa',
#  20027: 'cornstarch',
#  2069: 'balsamic vinegar',
#  2032: 'white pepper',
#  35239: 'corn tortilla',
#  2026: 'onion powder',
#  11205: 'cucumber',
#  28309: 'coconut',
#  18450: 'flour tortilla',
#  11537: 'chily',
#  11935: 'Catsup',
#  10004: 'pork',
#  1052: 'whipping cream',
#  4630: 'margarine',
#  2015: 'curry',
#  11270: 'mustard',
#  21150: 'white onion',
#  20014: 'corn',
#  2001: 'allspice',
#  14553: 'wine',
#  13000: 'steak',
#  11156: 'chive',
#  19165: 'cocoa powder',
#  1019: 'feta',
#  2038: 'sage',
#  11304: 'pea',
#  16093: 'peanut',
#  4615: 'shortening',
#  11109: 'cabbage',
#  9205: 'orange',
#  5674: 'chicken drumstick',
#  11980: 'green chili pepper',
#  11052: 'bean',
#  1030: 'muenster cheese',
#  4042: 'peanut oil',
#  2054: 'caper',
#  6076: 'Soup, beef broth, cubed, dry',
#  1054: 'cream',
#  11209: 'eggplant',
#  6615: 'vegetable broth',
#  19349: 'corn syrup',
#  2048: 'cider',
#  11257: 'lettuce',
#  7030: 'ham',
#  9316: 'strawberry',
#  1116: 'plain yogurt',
#  20452: 'short-grain white rice',
#  9040: 'banana',
#  11246: 'leek',
#  11333: 'green pepper',
#  5305: 'turkey',
#  2006: 'cardamom',
#  2045: 'dill',
#  43476: 'tofu',
#  6169: 'tabasco pepper sauce',
#  22911: 'chili',
#  11182: 'corn kernel',
#  35131: 'cornmeal',
#  20649: 'wheat flour',
#  9004: 'apple',
#  9429: 'pineapple',
#  2037: 'saffron',
#  1036: 'ricotta',
#  1033: 'parmesan',
#  18163: 'chocolate chip',
#  11029: 'kidney bean',
#  16237: 'chocolate',
#  16107: 'sausage',
#  11962: 'chile',
#  16157: 'chickpea',
#  6176: 'oyster',
#  6175: 'hoisin sauce',
#  20126: 'spaghetti',
#  6043: 'cream of mushroom soup',
#  9236: 'peach',
#  2018: 'fennel seed',
#  9078: 'cranberry',
#  20033: 'oat',
#  14050: 'rum',
#  42291: 'peanut butter',
#  3282: 'vegetable',
#  6016: 'cream of chicken soup',
#  11979: 'jalapeno',
#  2024: 'mustard seed',
#  20444: 'long-grain rice',
#  20129: 'bread flour',
#  11356: 'russet',
#  27063: 'enchilada sauce',
#  19433: 'tortilla chip',
#  20098: 'pasta',
#  2041: 'tarragon',
#  11090: 'broccoli',
#  20084: 'flour',
#  7003: 'beer',
#  18373: 'cream of tartar',
#  11278: 'okra',
#  11251: 'romaine',
#  16069: 'lentil',
#  11954: 'tomatillo',
#  11011: 'asparagu',
#  6972: 'chili sauce',
#  20090: 'brown rice flour',
#  9176: 'mango',
#  11429: 'radish',
#  43479: 'sake',
#  7036: 'italian sausage',
#  9050: 'blueberry',
#  11422: 'pumpkin',
#  9302: 'raspberry',
#  18060: 'bread',
#  10060: 'pork tenderloin',
#  4602: 'butter',
#  1040: 'swiss cheese',
#  2023: 'marjoram',
#  1323: 'ghee',
#  11653: 'pinto bean',
#  19353: 'maple syrup',
#  11485: 'squash',
#  23656: 'flank steak',
#  20133: 'rice noodle',
#  11959: 'arugula',
#  2075: 'taco seasoning',
#  11238: 'shiitake',
#  36058: 'olive',
#  6633: 'sriracha',
#  14423: 'ice water',
#  11135: 'cauliflower',
#  12151: 'pistachio',
#  6170: 'stock',
#  9021: 'apricot',
#  6931: 'pasta sauce',
#  19271: 'ice',
#  36054: 'marinara sauce',
#  16056: 'Chickpeas (garbanzo beans, bengal gram), mature seeds, raw',
#  10072: 'pork',
#  9502: 'granny smith apple',
#  20421: 'pasta',
#  9221: 'tangerine juice',
#  1157: 'goat cheese',
#  11970: 'napa cabbage',
#  11957: 'fennel bulb',
#  1029: 'part-skim mozzarella cheese',
#  20137: 'quinoa',
#  9019: 'applesauce',
#  18967: 'white bread',
#  2055: 'horseradish',
#  9452: 'pineapple juice',
#  1287: 'yogurt',
#  1035: 'provolone',
#  18943: 'crust',
#  16399: 'creamy peanut butter',
#  1038: 'romano',
#  17224: 'lamb',
#  2007: 'celery seed',
#  20029: 'couscou',
#  4501: 'cocoa',
#  15164: 'mussel',
#  9216: 'peel',
#  9421: 'date',
#  20410: 'egg noodle',
#  11080: 'beet',
#  4047: 'coconut oil',
#  42137: 'peppercorn',
#  1175: 'fat milk',
#  93600: 'Turtle, green, raw',
#  2034: 'poultry seasoning',
#  43273: 'cottage cheese',
#  12087: 'cashew',
#  20115: 'soba noodle',
#  15085: 'salmon',
#  28318: 'french bread',
#  11116: 'Cabbage, chinese (pak-choi), raw',
#  9070: 'cherry',
#  11233: 'kale',
#  12147: 'pine nut',
#  9083: 'currant',
#  3166: 'apple juice',
#  16249: 'coffee',
#  4002: 'lard',
#  10050: 'pork chop',
#  5312: 'chicken wing',
#  14545: 'herb',
#  14051: 'vodka',
#  1004: 'blue',
#  7063: 'pork sausage',
#  2005: 'caraway seed',
#  11943: 'pimento',
#  16262: 'hazelnut',
#  14019: 'tequila',
#  15157: 'clam',
#  2035: 'pumpkin pie spice',
#  19095: 'vanilla ice cream',
#  8314: 'grit',
#  16106: 'meat',
#  19172: 'gelatin',
#  18368: 'wrapper',
#  11252: 'iceberg',
#  19813: 'plain flour',
#  2046: 'yellow mustard',
#  10024: 'pork loin',
#  11564: 'turnip',
#  14187: 'clam juice',
#  1251: 'mexican cheese blend',
#  2033: 'poppy seed',
#  11886: 'tomato juice',
#  18453: 'yellow cake mix',
#  9322: 'tamarind',
#  1228: 'queso fresco',
#  1023: 'gruyere',
#  11026: 'bamboo shoot',
#  16112: 'miso',
#  90240: 'scallop',
#  23079: 'chuck',
#  19018: 'fruit',
#  11764: 'celery salt',
#  18175: 'lemon rind',
#  15001: 'anchovy',
#  9252: 'pear',
#  19137: 'topping',
#  32031: 'steak',
#  1144: 'egg substitute',
#  11298: 'parsnip',
#  9042: 'blackberry',
#  17137: 'lean sirloin',
#  18457: 'saltine',
#  5219: 'turkey breast',
#  22401: 'sauce',
#  12698: 'tahini',
#  6629: 'basil pesto sauce',
#  16049: 'white bean',
#  11977: 'serrano',
#  1020: 'fontina',
#  1151: 'nonfat',
#  11527: 'green tomato',
#  27047: 'salsa verde',
#  13929: 'beef sirloin steak',
#  1267: 'cotija',
#  6624: 'thai',
#  20082: 'self-rising flour',
#  7057: 'pepperoni',
#  7943: 'lemon pepper',
#  13973: 'chuck roast',
#  9272: 'pineapple chunk',
#  13346: 'beef brisket',
#  11530: 'ripe tomato',
#  11031: 'lima bean',
#  18033: 'italian bread',
#  11439: 'sauerkraut',
#  15128: 'tuna',
#  5075: 'chicken leg',
#  17431: 'veal',
#  12220: 'Seeds, flaxseed',
#  11147: 'chard',
#  10005: 'pork belly',
#  6112: 'teriyaki sauce',
#  1265: 'fat cheddar cheese',
#  6094: 'onion soup mix',
#  16026: 'great northern bean',
#  43278: 'american cheese',
#  2022: 'mace',
#  6152: 'pizza sauce',
#  7019: 'chorizo',
#  11958: 'pickle',
#  6159: 'tomato soup',
#  35137: 'yellow cornmeal',
#  4638: 'ranch dressing',
#  4645: 'oil for frying',
#  11007: 'artichoke',
#  9423: 'prune',
#  15097: 'fish',
#  11118: 'kimchi',
#  11603: 'jicama',
#  9328: 'maraschino cherry',
#  28340: 'starch',
#  4506: 'sunflower oil',
#  43017: 'salad green',
#  9089: 'fig',
#  18338: 'phyllo dough',
#  32002: 'rice',
#  4576: 'fat',
#  11098: 'sprout',
#  2002: 'anise',
#  23441: 'beef tenderloin',
#  16037: 'navy bean',
#  11260: 'white mushroom',
#  20078: 'wheat germ',
#  11937: 'kosher dill pickle',
#  12040: 'sunflower seed',
#  15175: 'squid',
#  28295: 'wheat tortilla',
#  11300: 'sugar pea',
#  20044: 'long-grain white rice',
#  6963: 'broth',
#  11805: 'onion salt',
#  18212: 'vanilla wafer',
#  19206: 'vanilla pudding mix',
#  20105: 'macaroni',
#  19087: 'white chocolate',
#  28342: 'tapioca flour',
#  9279: 'plum',
#  2019: 'fenugreek',
#  17086: 'lamb shoulder',
#  6010: 'cream of celery soup',
#  43535: '-',
#  9129: 'grape',
#  19303: 'marmalade',
#  9501: 'delicious apple',
#  5115: 'roasting chicken',
#  10946: 'pork shoulder boston butt',
#  6080: 'chicken bouillon',
#  12116: 'coconut cream',
#  9218: 'mandarin orange',
#  9110: 'berry',
#  16161: 'soft silken tofu',
#  21497: 'pizza crust',
#  14542: 'lemonade',
#  18243: 'crouton',
#  35136: 'white cornmeal',
#  9133: 'seedless grape',
#  11266: 'mushroom',
#  43441: 'roll',
#  12163: 'pumpkin seed',
#  11547: 'tomato puree',
#  5027: 'chicken liver',
#  18337: 'puff pastry',
#  18139: 'Cake, white, prepared from recipe without frosting',
#  21415: 'biscuit',
#  20330: 'hominy',
#  19078: 'chocolate',
#  11212: 'edamame',
#  4636: 'italian salad dressing',
#  5356: 'rotisserie chicken',
#  14163: 'soy milk',
#  9202: 'navel orange',
#  18419: 'white cake mix',
#  1295: 'yogurt',
#  6174: 'fish stock',
#  11772: 'cream style corn',
#  10094: 'pork loin chop',
#  36029: 'fish fillet',
#  16059: 'chili bean',
#  20030: 'white hominy',
#  9307: 'rhubarb',
#  14121: 'club soda',
#  15172: 'scallop',
#  10864: 'dripping',
#  13979: 'skirt steak',
#  43016: 'salad',
#  20061: 'white flour',
#  11243: 'portobello mushroom',
#  19352: 'syrup',
#  20316: 'corn flour',
#  27064: 'wasabi',
#  6983: 'ramen noodle',
#  19314: 'cherry pie filling',
#  11214: 'escarole',
#  18942: 'graham cracker crust',
#  11951: 'yellow pepper',
#  11952: 'radicchio',
#  7070: 'salami',
#  20466: 'semolina',
#  18029: 'sourdough',
#  15147: 'lobster',
#  18042: 'pita bread',
#  43134: 'fillet',
#  19719: 'apricot',
#  19868: 'splenda',
#  23066: 'beef rib short',
#  6960: 'alfredo sauce',
#  14649: 'Beverages, tea, hibiscus, brewed',
#  28292: 'cracker',
#  18174: 'graham cracker',
#  11492: 'spaghetti squash',
#  4015: 'dressing',
#  11601: 'yam',
#  10225: 'pork loin roast',
#  18176: 'marshmallow',
#  18040: 'oatmeal',
#  11265: 'mushroom',
#  5123: 'chicken meat',
#  4698: 'canola',
#  14210: 'espresso',
#  6622: 'masala',
#  22901: 'tortellini',
#  11370: 'hash brown potato',
#  1117: 'fat yogurt',
#  18448: 'shell',
#  19024: 'milk chocolate chip',
#  43299: 'curd',
#  7927: 'italian turkey sausage',
#  43154: 'cooking wine',
#  5143: 'duck',
#  11482: 'acorn squash',
#  6631: 'sauce',
#  11096: 'broccoli rabe',
#  9326: 'watermelon',
#  11119: 'chinese cabbage',
#  10165: 'salt pork',
#  7970: 'kielbasa',
#  11114: 'savoy cabbage',
#  1223: 'Protein supplement, milk based, Muscle Milk, powder',
#  11531: 'tomato in juice',
#  1187: 'nonfat yogurt',
#  21158: 'white sandwich bread',
#  7074: 'sausage link',
#  5668: 'lean turkey',
#  14414: 'coffee liqueur',
#  14028: 'Beverages, Whiskey sour mix, bottled',
#  8444: 'country ham',
#  11442: 'seaweed',
#  1006: 'brie',
#  20121: 'rotini',
#  43114: 'vermicelli',
#  19348: 'chocolate syrup',
#  23175: 'rib eye steak',
#  16166: 'soymilk',
#  18423: 'ladyfinger',
#  20005: 'barley',
#  17000: 'rib',
#  19184: 'chocolate pudding mix',
#  15015: 'cod',
#  18064: 'wheat bread',
#  19909: 'sugar substitute',
#  14303: 'limeade',
#  42063: 'liquid pectin',
#  43382: 'cranberry juice',
#  19201: 'vanilla pudding',
#  1186: 'fat cream cheese',
#  43364: 'corn tortilla chip',
#  5327: 'chicken breast tender',
#  19120: 'milk chocolate',
#  13974: 'beef chuck roast',
#  1159: 'goat',
#  10087: 'pork shoulder roast',
#  20325: 'self-rising cornmeal',
#  19132: 'almond milk',
#  19039: 'popcorn',
#  27048: 'steak sauce',
#  11973: 'fava bean',
#  2064: 'peppermint',
#  43132: 'meatball',
#  18084: 'cornbread',
#  9340: 'asian pear',
#  14161: 'kiwi',
#  9422: 'or',
#  16156: 'chunky peanut butter',
#  12202: 'chestnut',
#  2008: 'chervil',
#  9226: 'papaya',
#  17017: 'lamb shank',
#  18361: 'pastry',
#  20077: 'wheat bran',
#  1012: 'curd cottage cheese',
#  2039: 'savory',
#  9181: 'Melons, cantaloupe, raw',
#  6008: 'beef bouillon',
#  11475: 'summer squash',
#  1011: 'colby',
#  4511: 'safflower oil',
#  35138: 'squash',
#  19154: 'sesame',
#  11984: 'epazote',
#  20113: 'noodle',
#  7058: 'pimiento',
#  11987: 'oyster mushroom',
#  43212: 'bacon bit',
#  10130: 'canadian bacon',
#  1191: 'velveeta',
#  20012: 'bulgur',
#  11253: 'green lettuce',
#  10088: 'sparerib',
#  20065: 'rye flour',
#  7954: 'breakfast sausage',
#  9132: 'seedless green grape',
#  11435: 'rutabaga',
#  13227: 'beef shank',
#  15139: 'crab',
#  12131: 'macadamia nut',
#  18097: 'chocolate cake mix',
#  20087: 'wheat',
#  9081: 'cranberry sauce',
#  1193: "breakstone'",
#  36020: 'chicken finger',
#  42157: 'fat-free',
#  9542: 'plantain',
#  19270: 'ice cream',
#  11976: 'banana pepper',
#  1022: 'gouda',
#  9442: 'pomegranate juice',
#  6626: 'pesto sauce',
#  14533: 'gin',
#  1180: 'fat sour cream',
#  4609: 'bacon',
#  7912: 'beef roast',
#  7955: 'turkey sausage',
#  18621: 'ritz cracker',
#  19124: 'chocolate',
#  9546: 'cherry',
#  11322: 'peas and carrot',
#  28307: 'naan',
#  14534: 'liqueur',
#  3046: 'cheese ravioli',
#  22978: 'chicken tender',
#  16080: 'mung bean',
#  20011: 'buckwheat flour',
#  11250: 'boston lettuce bibb',
#  11945: 'relish',
#  16398: 'smooth peanut butter',
#  19375: 'Frostings, glaze, prepared-from-recipe',
#  11354: 'white potato',
#  43109: 'pretzel',
#  9191: 'nectarine',
#  15101: 'snapper',
#  11989: 'straw mushroom',
#  15261: 'tilapia',
#  11149: 'chayote',
#  14152: 'burgundy',
#  43390: 'Turkey, light or dark meat, smoked, cooked, with skin, bone removed',
#  43276: 'cheese spread',
#  9128: 'grapefruit',
#  9414: 'bosc pear',
#  19107: 'candy',
#  18172: 'Cookies, gingersnaps',
#  21319: 'hash brown',
#  17180: 'rabbit',
#  44158: 'filling',
#  28293: 'sugar',
#  10207: 'pork rib',
#  18264: 'english muffin',
#  5145: 'duck breast',
#  19297: 'jam',
#  18010: 'biscuit',
#  15130: 'whitefish',
#  11568: 'turnip green',
#  23094: 'beef',
#  19106: 'Candies, gumdrops, starch jelly pieces',
#  21228: 'hamburger',
#  25022: 'french onion',
#  11900: 'white corn',
#  48052: 'vital wheat gluten',
#  18081: 'stuffing mix',
#  11167: 'yellow corn',
#  19918: 'stevia',
#  19074: 'caramel',
#  43100: 'coconut sugar',
#  4704: 'creamy salad dressing',
#  9097: 'cocktail cherry',
#  1314: 'plain nonfat yogurt',
#  19416: 'rice cake',
#  19823: 'potato chip',
#  1034: 'port',
#  22973: 'dog',
#  19912: 'Sweetener, syrup, agave',
#  14211: 'black tea',
#  5165: 'turkey meat',
#  17425: 'cutlet',
#  20135: 'wheat pasta',
#  6032: 'beef consomme',
#  35190: 'filet',
#  20019: 'masa',
#  2016: 'dill seed',
#  16147: 'veggie',
#  35144: 'dumpling',
#  1047: 'cheese food',
#  35030: 'or cranberry',
#  10040: 'center pork chop',
#  4583: 'mustard oil',
#  16118: 'soy flour',
#  7915: 'chicken sausage',
#  12016: 'pepita',
#  21416: 'coleslaw',
#  9063: 'sour cherry',
#  23372: 'steak',
#  27059: 'peanut sauce',
#  10149: 'ham steak',
#  14260: 'green tea',
#  6121: 'gravy',
#  18947: 'deep dish pie crust',
#  14144: 'soda',
#  18973: 'Focaccia, Italian flatbread, plain',
#  8639: 'cinnamon sugar',
#  14136: 'ale',
#  18952: 'tostada',
#  36024: 'chicken tenderloin',
#  15270: 'raw shrimp',
#  17278: 'shank',
#  20054: 'glutinous rice',
#  15038: 'halibut',
#  1285: 'nonfat greek yogurt',
#  9503: 'gala',
#  7028: 'deli ham',
#  43392: 'of',
#  4014: 'miracle whip dressing',
#  16114: 'tempeh',
#  4706: 'honey mustard',
#  15048: 'jack',
#  8156: 'rice cereal',
#  11697: 'arrowroot',
#  9251: 'peach nectar',
#  19294: 'apple butter',
#  11445: 'kelp',
#  19312: 'apple pie filling',
#  16158: 'hummu',
#  23607: 'new york strip steak',
#  15091: 'sea bass',
#  9184: 'honeydew',
#  9412: 'bartlett',
#  18022: 'mix',
#  12195: 'almond butter',
#  36055: 'Restaurant, Italian, cheese ravioli with marinara sauce',
#  13335: 'suet',
#  5015: 'fryer',
#  5309: 'cornish game hen',
#  4708: 'fat mayonnaise',
#  27049: 'tartar sauce',
#  17078: 'lamb loin chop',
#  11578: 'vegetable juice',
#  9351: 'fruit cocktail',
#  7973: 'turkey bacon',
#  11450: 'soybean',
#  7934: 'kielbasa',
#  4648: 'flavoring',
#  10006: 'pork fat',
#  20031: 'millet',
#  6053: 'cream of potato soup',
#  20068: 'pearl tapioca',
#  9149: 'kumquat',
#  13407: 'cube steak',
#  15186: 'solid white tuna in water',
#  8402: 'quick oat',
#  18370: 'double-acting baking powder',
#  4594: 'sardine',
#  18964: 'bun',
#  19300: 'jelly',
#  16123: 'shoyu',
#  20050: 'rice',
#  35141: 'mutton',
#  9278: 'yellow',
#  16011: 'bean sauce',
#  15031: 'grouper',
#  23181: 'back rib',
#  5193: 'turkey leg',
#  9504: 'fuji apple',
#  18280: 'corn mix muffin',
#  42173: 'bulk pork sausage',
#  4635: 'thousand island dressing',
#  28348: 'dinner roll',
#  16115: 'soy',
#  18069: 'soft bread crumb',
#  19027: 'peanut butter chip',
#  16010: 'pork and bean',
#  18152: 'brownie mix',
#  25036: 'granola',
#  1137: 'yolk',
#  6116: 'beef gravy',
#  42307: 'butter-margarine blend',
#  18204: 'vanilla sugar',
#  11963: 'nopale',
#  11199: 'yardlong bean',
#  14461: 'lemon-lime beverage',
#  15010: 'catfish',
#  1039: 'roquefort',
#  13926: 'filet mignon',
#  18353: 'roll',
#  6042: 'mushroom soup',
#  35240: 'corn bread',
#  16172: 'fat-free bean',
#  1003: 'butter oil',
#  17343: 'venison',
#  14189: 'coca-cola',
#  1306: 'chocolate sauce',
#  27050: 'sour sauce',
#  23059: 'iron steak',
#  7040: 'liver',
#  19279: 'coffee bean',
#  19021: 'soft butter',
#  18268: 'toast',
#  31033: 'artificial sweetener',
#  19365: 'marshmallow cream',
#  4367: 'french dressing',
#  11170: 'brine',
#  6243: 'fat cream of mushroom soup',
#  16082: 'mung bean noodle',
#  15033: 'haddock',
#  18017: 'biscuit dough',
#  16101: 'pigeon pea',
#  5000: 'chicken breast meat',
#  18376: 'crumb',
#  11518: 'taro',
#  19226: 'chocolate frosting',
#  9286: 'pomegranate',
#  7050: 'mortadella',
#  42153: 'blue cheese dressing',
#  28335: 'gluten-free vanilla',
#  28294: 'icing',
#  15115: 'trout',
#  6151: 'plum sauce',
#  1057: 'eggnog',
#  16171: 'vegetarian bean',
#  36043: 'lasagne',
#  12006: 'chia seed',
#  14073: 'cola',
#  22914: 'tomato pasta sauce',
#  11669: 'wakame',
#  11239: 'chanterelle',
#  15012: 'caviar',
#  9296: 'quince',
#  11161: 'collard',
#  5157: 'quail',
#  1166: 'asadero',
#  8025: 'crisp rice cereal',
#  42040: 'grenadine',
#  20036: 'long-grain brown rice',
#  18114: 'cake mix',
#  15143: 'dungeness crab',
#  13383: 'pot roast',
#  22899: 'ravioli',
#  28324: 'pancake mix',
#  27051: 'cocktail sauce',
#  43344: 'preserve',
#  15108: 'raw pumpkin seed',
#  14155: 'water',
#  14145: 'sprite',
#  19911: 'maple',
#  4617: 'stick margarine',
#  19364: 'caramel topping',
#  9036: 'apricot nectar',
#  18349: 'french roll',
#  19332: 'lemon pudding mix',
#  19091: 'peppermint candy',
#  1229: 'Cheese, white, queso blanco',
#  10080: 'pork',
#  11240: 'morel',
#  17461: 'lamb rib chop',
#  5284: 'turkey broth',
#  17353: 'lean lamb',
#  14613: 'passion fruit',
#  18133: 'sponge',
#  14242: 'cranberry juice cocktail',
#  9413: 'anjou pear',
#  19438: 'rice krispy',
#  43015: 'caesar salad dressing',
#  10963: 'sirloin tip roast',
#  11940: 'bread and butter pickle',
#  11696: 'yellow tomato',
#  14160: 'chardonnay',
#  14097: 'cabernet sauvignon',
#  7914: 'italian sausage link',
#  7051: 'loaf',
#  8160: 'corn grit',
#  18234: 'butter cracker',
#  14218: 'coffee powder',
#  9144: 'jackfruit',
#  13023: 'brisket',
#  1225: 'dulce de leche',
#  16095: 'raw peanut',
#  1088: 'lowfat buttermilk',
#  6981: 'bouillon',
#  36018: 'hand',
#  35054: 'octopus',
#  11413: 'potato flour',
#  1031: 'neufchatel cheese',
#  19230: 'vanilla frosting',
#  28339: 'grain bread',
#  90480: 'cane syrup',
#  44074: 'grape juice',
#  16032: 'kidney',
#  9140: 'guava',
#  6307: 'kraft original barbecue sauce',
#  21505: 'pizza',
#  17156: 'lean meat',
#  6611: 'lower beef broth',
#  25017: 'chocolate bar',
#  6930: 'cheese sauce',
#  15083: 'pink salmon',
#  20132: 'oat flour',
#  21525: 'breadstick',
#  21396: 'condiment',
#  14132: 'riesling',
#  16315: 'black salt',
#  18239: 'croissant',
#  11978: 'ancho',
#  12097: 'unpeeled',
#  13339: 'beef tongue',
#  23342: 'filet mignon steak',
#  43408: 'pear juice',
#  15107: 'white fish',
#  43112: 'ranch style bean',
#  5282: 'foie gra',
#  16119: 'meal',
#  32011: 'yellow rice',
#  16001: 'adzuki bean',
#  14075: 'sparkling water',
#  43026: 'sugar syrup',
#  20647: 'millet flour',
#  4581: 'avocado oil',
#  9038: 'california avocado',
#  11254: 'lotus root',
#  9138: 'poha',
#  43137: 'meatloaf',
#  16258: 'key lime',
#  2010: 'cassia cinnamon',
#  7053: 'liver pate',
#  2076: 'chili seasoning mix',
#  21238: 'french fry',
#  1162: 'fat greek yogurt',
#  7956: 'beef sausage',
#  20420: 'elbow pasta',
#  4055: 'palm oil',
#  7910: 'bratwurst',
#  5227: 'turkey wing',
#  1014: 'nonfat cottage cheese',
#  20141: 'spelt',
#  20655: 'flour',
#  18320: 'meringue',
#  18228: 'cracker',
#  16235: 'plain',
#  1305: 'lowfat milk',
#  8061: 'bran cereal',
#  14639: 'rice milk',
#  9404: 'pink grapefruit',
#  13325: 'beef liver',
#  27066: 'horseradish sauce',
#  23431: 'beef rib',
#  1167: 'chihuahua cheese',
#  10980: 'bone-in',
#  7059: 'polish sausage',
#  2066: 'spearmint',
#  32018: 'spanish rice',
#  11024: 'bitter',
#  21244: 'chicken fillet',
#  9107: 'gooseberry',
#  4128: 'fat margarine',
#  13891: 'london broil',
#  1286: 'nonfat vanilla yogurt',
#  43589: 'fat swiss cheese',
#  12154: 'black walnut',
#  20648: 'sorghum flour',
#  4530: 'kernel',
#  18323: 'pie',
#  16040: 'pink bean',
#  6620: 'french lentil',
#  5171: 'giblet',
#  8083: 'corn cereal',
#  25037: 'pita chip',
#  20131: 'barley flour',
#  90560: 'snail',
#  9520: 'kiwifruit',
#  11207: 'dandelion green',
#  6126: 'turkey gravy',
#  6011: 'cheese soup',
#  6192: 'or pea',
#  23646: 'bottom roast',
#  7043: 'deli roast beef',
#  14099: 'pinot noir',
#  9164: 'lychee',
#  13342: 'flaked',
#  35028: 'cockle',
#  5295: 'roast turkey',
#  12119: 'coconut water',
#  11637: 'white radish',
#  16019: 'cranberry bean',
#  1140: 'quail egg',
#  7071: 'hard salami',
#  7919: 'turkey breakfast sausage',
#  19183: 'pudding',
#  19340: 'maple sugar',
#  6377: "campbell's tomato soup",
#  18044: 'pumpernickel bread',
#  12078: 'brazil nut',
#  12021: 'safflower',
#  14157: 'root beer',
#  19186: 'crisp',
#  11134: 'cassava',
#  17074: 'lamb leg',
#  9436: 'mango nectar',
#  23360: 'eye of roast',
#  13464: 'porterhouse steak',
#  28397: 'whole-grain bread',
#  14366: 'tea powder',
#  27065: 'bean dip',
#  18363: 'or corn',
#  5016: 'batter',
#  14250: 'hard cider',
#  4668: 'soy margarine',
#  5023: 'chicken gizzard',
#  16125: 'vegetable protein',
#  20136: 'wheat penne',
#  20124: 'whole-wheat',
#  1293: 'milk greek yogurt',
#  14102: 'zinfandel',
#  1071: 'ounce',
#  18205: 'sugar cookie dough',
#  9433: 'clementine',
#  42281: 'guar gum',
#  17383: 'lamb shoulder chop',
#  3007: 'pork meat',
#  19110: 'chocolate candy bar',
#  6338: "campbell's cream of mushroom soup",
#  20067: 'sorghum',
#  14411: 'tap water',
#  4551: 'or coconut',
#  12012: 'hemp seed',
#  21247: 'french',
#  10934: 'bone-in ham',
#  19129: 'pancake syrup',
#  ...}

# %% [markdown]
# > Some ingredients may have been mapped to the same representative without having the same usda matching. Did it happened ?

# %%
con = collections.Counter()
con.update([representative_keys[x] for x in representative_keys])
len([c for c in con.most_common() if c[1] >=2])
# Out:
# 24

# %%
[(c, representative_keys[c]) for c in representative_keys][:10]
# Out:
# [(2047, 'salt'),
#  (11282, 'onion'),
#  (1145, 'butter'),
#  (14555, 'water'),
#  (1123, 'egg'),
#  (19908, 'turbinado sugar'),
#  (2030, 'black pepper'),
#  (4053, 'oil'),
#  (11981, 'pepper'),
#  (11215, 'garlic')]

# %% [markdown]
# > It indeed happened, should we map them to the same usda entry ? let's look at the different ingredient sets

# %%
for c in con.most_common()[:10] :
    print("Representative term : ", c[0], " (", c[1], " times)")
    matching_keys = []
    for key in representative_keys :
        if representative_keys[key]== c[0] :
            print("\tusda food item : ", item_describe[str(key)])
            
            for ing in collisions[key] :
                print("\t\tingredient : ", ing)
            print("\n")
            
    print("\n")
# Out:
# Representative term :  oil  ( 3  times)
# 	usda food item :  Oil, olive, salad or cooking
# 		ingredient :  olive oil
# 		ingredient :  salad oil
#
#
# 	usda food item :  Oil, hazelnut
# 		ingredient :  oil
# 		ingredient :  hazelnut oil
#
#
# 	usda food item :  Oil, corn and canola
# 		ingredient :  canola oil
# 		ingredient :  corn oil
#
#
#
#
# Representative term :  flour  ( 3  times)
# 	usda food item :  Rye flour, dark
# 		ingredient :  flour
#
#
# 	usda food item :  Wheat flour, white, cake, enriched
# 		ingredient :  cake flour
# 		ingredient :  white wheat flour
#
#
# 	usda food item :  Pasta, gluten-free, corn flour and quinoa flour, cooked, ANCIENT HARVEST
# 		ingredient :  gluten-free flour
# 		ingredient :  quinoa flour
#
#
#
#
# Representative term :  mushroom  ( 3  times)
# 	usda food item :  Mushrooms, maitake, raw
# 		ingredient :  mushroom
#
#
# 	usda food item :  Mushrooms, brown, italian, or crimini, raw
# 		ingredient :  crimini mushroom
# 		ingredient :  brown mushroom
#
#
# 	usda food item :  Mushrooms, portabella, raw
# 		ingredient :  portabello mushroom
# 		ingredient :  portabella mushroom
#
#
#
#
# Representative term :  sauce  ( 3  times)
# 	usda food item :  Sauce, barbecue
# 		ingredient :  sauce
# 		ingredient :  barbecue sauce
#
#
# 	usda food item :  Spaghetti with meat sauce, frozen entree
# 		ingredient :  spaghetti sauce
# 		ingredient :  meat sauce
#
#
# 	usda food item :  Sauce, hot chile, sriracha
# 		ingredient :  chile sauce
# 		ingredient :  sriracha sauce
#
#
#
#
# Representative term :  rice  ( 3  times)
# 	usda food item :  Rice crackers
# 		ingredient :  rice
# 		ingredient :  rice cracker
#
#
# 	usda food item :  Rice and vermicelli mix, rice pilaf flavor, unprepared
# 		ingredient :  rice vermicelli
# 		ingredient :  rice pilaf
#
#
# 	usda food item :  Rice, white, medium-grain, raw, enriched
# 		ingredient :  medium-grain rice
# 		ingredient :  raw white rice
#
#
#
#
# Representative term :  pork  ( 3  times)
# 	usda food item :  Pork, fresh, backfat, raw
# 		ingredient :  pork
#
#
# 	usda food item :  Pork, fresh, shoulder, whole, separable lean only, raw
# 		ingredient :  pork shoulder
# 		ingredient :  lean pork
#
#
# 	usda food item :  Pork, fresh, shoulder, (Boston butt), blade (steaks), separable lean and fat, raw
# 		ingredient :  pork shoulder butt
# 		ingredient :  pork steak
#
#
#
#
# Representative term :  steak  ( 3  times)
# 	usda food item :  Beef, grass-fed, strip steaks, lean only, raw
# 		ingredient :  lean beef
# 		ingredient :  beef steak
# 		ingredient :  lean steak
# 		ingredient :  strip steak
#
#
# 	usda food item :  Salisbury steak with gravy, frozen
# 		ingredient :  steak
#
#
# 	usda food item :  Beef, loin, tenderloin steak, boneless, separable lean only, trimmed to 0" fat, all grades, raw
# 		ingredient :  beef tenderloin steak
# 		ingredient :  beef fillet
# 		ingredient :  steak fillet
# 		ingredient :  tenderloin steak
#
#
#
#
# Representative term :  chocolate  ( 3  times)
# 	usda food item :  SILK Chocolate, soymilk
# 		ingredient :  chocolate
#
#
# 	usda food item :  Baking chocolate, unsweetened, squares
# 		ingredient :  squares chocolate
# 		ingredient :  square chocolate
# 		ingredient :  squares baking chocolate
# 		ingredient :  chocolate square
#
#
# 	usda food item :  Baking chocolate, mexican, squares
# 		ingredient :  baking chocolate
# 		ingredient :  mexican chocolate
#
#
#
#
# Representative term :  onion  ( 2  times)
# 	usda food item :  Onions, raw
# 		ingredient :  onion
# 		ingredient :  raw onion
#
#
# 	usda food item :  Onions, spring or scallions (includes tops and bulb), raw
# 		ingredient :  scallion
# 		ingredient :  spring onion
# 		ingredient :  or onion
#
#
#
#
# Representative term :  butter  ( 2  times)
# 	usda food item :  Butter, without salt
# 		ingredient :  butter
#
#
# 	usda food item :  Butter, light, stick, without salt
# 		ingredient :  stick butter
# 		ingredient :  sticks butter

# %% [markdown]
# > We choose to remember the representative string because we find it good

# %%
if high_score :
    json.dump(representative_keys, open("./../generated/high_score_key_representative.json" , 'w'))
else :
    json.dump(representative_keys, open("./../generated/low_score_key_representative.json" , 'w'))

# %% [markdown]
# ### rewrite recipes with usda_id, or original name if no id found

# %%
frequent_ingredients = set(ingredients_count.keys())
usda_mapped = set([ing for ing in ing_mapping])
deleted = 0

a = cleaned_kaggle_recipes.copy()
a.extend(cleaned_cookies_recipes.copy())

representative_count = 0
unmapped_count = 0
total_count = 0
all_repr_recipes = []

for recipe in a :
    repr_ingredients = []

    for ing in recipe :
        if ing in frequent_ingredients :

            total_count += 1

            if ing in usda_mapped :
                usda_id = ing_mapping[ing]
                repr_ingredients.append("usda_id=" + str(usda_id)) 
                representative_count += 1
               
            else :
                repr_ingredients.append(ing)
                unmapped_count += 1

    if len(repr_ingredients) != 0 :
        all_repr_recipes.append(repr_ingredients)
    else :
        deleted += 1
    
repr_perc = 100 * representative_count / total_count
unmapped_perc = 100*unmapped_count / total_count
print("representative : ", repr_perc, "%")
print("unmapped : ", unmapped_perc, "%")
print(deleted, " recipes were deleted :(")

#save result
if high_score :
    json.dump(all_repr_recipes, open("./../generated/high_score_repr_recipes.json", 'w'))
else :
    json.dump(all_repr_recipes, open("./../generated/low_score_repr_recipes.json", 'w'))
# Out:
# representative :  79.53772509292816 %
# unmapped :  20.46227490707185 %
# 234  recipes were deleted :(

# %%
print("Final nb of ingredients : ", len(set([ingr for rec in all_repr_recipes for ingr in rec])))
kaggle_nb = len(set([ingr for rec in cleaned_kaggle_recipes for ingr in rec]))
cookies_nb = len(set([ingr for rec in cleaned_cookies_recipes for ingr in rec]))
print("orignial nb : ", kaggle_nb + cookies_nb, " (=", kaggle_nb, "+", cookies_nb, ")" )
# Out:
# Final nb of ingredients :  4658
# orignial nb :  32960  (= 5422 + 27538 )
