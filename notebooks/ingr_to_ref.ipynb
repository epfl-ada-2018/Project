# %%
import json
from tqdm import tqdm_notebook
import matplotlib.pyplot as plt
import numpy as np

# %%
ids = json.load(open('../generated/all_recipes_any_ids.json'))
id2ref = json.load(open('../generated/high_score_key_representative_3d.json'))

# %%
all_refs = []
i = 0
for r in ids:
    ++i
    refs = list(map(lambda x: id2ref[str(x)],r))
    all_refs.append(refs)

# %%
all_refs
# Out:
# [['romaine', 'garlic', 'pepper', 'taco seasoning', 'garbanzo bean', 'feta'],
#  ['plain flour',
#   'pepper',
#   'salt',
#   'tomato',
#   'black pepper',
#   'thyme',
#   'egg',
#   'green tomato',
#   'milk',
#   'vegetable oil'],
#  ['egg',
#   'pepper',
#   'salt',
#   'cooking',
#   'chily',
#   'chicken breast',
#   'garlic powder',
#   'yellow onion',
#   'tamari soy sauce',
#   'butter',
#   'chicken liver'],
#  ['water', 'vegetable oil', 'wheat', 'salt'],
#  ['black pepper',
#   'shallot',
#   'cayenne',
#   'onion',
#   'garlic',
#   'milk',
#   'butter',
#   'salt',
#   'lemon juice',
#   'water',
#   'chili powder',
#   'oil',
#   'cumin',
#   'chicken drumstick',
#   'yogurt',
#   'bay'],
#  ['plain flour',
#   'turbinado sugar',
#   'butter',
#   'egg',
#   'ginger',
#   'salt',
#   'cinnamon',
#   'milk',
#   'vanilla',
#   'ginger',
#   'turbinado sugar',
#   'baking powder'],
#  ['oil',
#   'salt',
#   'shrimp',
#   'pepper',
#   'garlic',
#   'cilantro',
# ...

# %%
json.dump(all_refs,open('../generated/all_recipes_refs.json', 'w'))
