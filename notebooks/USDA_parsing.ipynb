# %% [markdown]
# # imports

# %%
import pandas as pd
import numpy as np
import re
import tqdm
import itertools
import json
import inflect

# %%
def print_bold(str):
    print('\033[1m' + str + '\033[0m')

# %% [markdown]
# # files paths

# %%
#where to find useful data
food_des_path = "./../data/usda/FOOD_DES.txt"
food_groups_path = "./../data/usda/FD_GROUP.txt"
nut_data_path = "./../data/usda/NUT_DATA.txt"
nut_def_path = "./../data/usda/NUTR_DEF.txt"

all_paths = [food_des_path, food_groups_path, nut_data_path, nut_def_path]

# %% [markdown]
# # tilde removal

# %% [markdown]
# #text columns are indicated by '~', remove them
# for p in all_paths :
#     string = open(p).read()
#     new_str = re.sub('[~]', '', string)
#     open(p, 'w').write(new_str)

# %% [markdown]
# # Load and filter food group description

# %% [markdown]
# ### info about the different food groups contained in the USDA database

# %%
columns = ["food_group_id", "food_group_name"]

food_groups = pd.read_csv(food_groups_path, sep="^", encoding="ISO-8859-1", names=columns, header=None)

food_groups.set_index("food_group_id", inplace=True)

food_groups
# Out:
#                                    food_group_name
# food_group_id
# 100                         Dairy and Egg Products
# 200                               Spices and Herbs
# 300                                     Baby Foods
# 400                                  Fats and Oils
# 500                               Poultry Products
# 600                     Soups, Sauces, and Gravies
# 700                    Sausages and Luncheon Meats
# 800                              Breakfast Cereals
# 900                        Fruits and Fruit Juices
# 1000                                 Pork Products
# 1100             Vegetables and Vegetable Products
# 1200                         Nut and Seed Products
# 1300                                 Beef Products
# 1400                                     Beverages
# 1500                Finfish and Shellfish Products
# 1600                   Legumes and Legume Products
# 1700                 Lamb, Veal, and Game Products
# 1800                                Baked Products
# 1900                                        Sweets
# 2000                       Cereal Grains and Pasta
# 2100                                    Fast Foods
# 2200               Meals, Entrees, and Side Dishes
# 2500                                        Snacks
# 3500           American Indian/Alaska Native Foods
# 3600                              Restaurant Foods

# %% [markdown]
# ### we decide to drop :
#
# >* Baby food (300)
# >* dressing in 400
# >* soup in 600
# >* Breakfast Cereals (800)
# >* Beverages (1400) except water
# >* Baked products (1800)
# >* Sweets (1900) except Baking products (chocolate)
# >* Fast Foods (2100)
# >* Meals, Entrees, and Side Dishes (2200)
# >* Snacks (2500)
# >* Restaurant food (3600)

# %% [markdown]
# # Load and clean food description table

# %% [markdown]
# #### Info about each individual product

# %%
#take a description-like syntax and return the list of words, filtering  no negation
def split_des_in_list(des) :
    
    cats = re.sub("[()]", "", des).strip().lower().split(',')    
    final_list = []
    
    for c in cats :        
        words_list = c.strip().split(" ")
        
        if (("no" not in words_list) and ("without" not in words_list)) :
            final_list.extend([c.strip().lower() for c in words_list if c != "with"])
    
    return final_list
    
    
#return [w.strip() for c in des.split(",") for w in c.strip().lower().split(' ')]

#singularize a word if plural
def singularize_word(x) :
    if engine.singular_noun(x) :
        return engine.singular_noun(x)
    else :
        return x
        
#clean the description(lowercases, strips, singularization)
def format_long_des(x) :
        
    if str(x) == "nan" :
        return ""    
    
    split = split_des_in_list(x)
    
    #decompose description
    words = [c for c in split]
    
    #singularize words
    sing_words = [singularize_word(x) for x in words]
    
    #rebuild description
    return str(" ".join(sing_words))

def concat_common_and_des(common, des) :
    if common != "" :
        return common.split(" ") + des.split(" ")
    else :
        return des.split(" ")

# %%
#generate singularization engine
engine = inflect.engine()

#columns we want to retrieve from the database files
columns = ["food_id", "food_group_id", "long_description", "common_names"]
use_cols = [0, 1, 2, 4]

#get the info from file
food_des = pd.read_csv(food_des_path, sep="^", encoding="ISO-8859-1", names=columns, usecols=use_cols, header=None)

#display original table format
print_bold("original table format : ")
print(food_des.head())


# generate search_words
food_des['search_words'] = food_des.apply(lambda row : concat_common_and_des(format_long_des(row['common_names']),
                                                                             format_long_des(row['long_description'])),
                                                                             axis=1)

#drop common_names column
food_des = food_des.drop("common_names", axis=1)
            
print_bold("\n\nnew table format")
food_des.head()
# Out:
# original table format :
#    food_id  food_group_id            long_description common_names
# 0     1001            100              Butter, salted          NaN
# 1     1002            100  Butter, whipped, with salt          NaN
# 2     1003            100       Butter oil, anhydrous          NaN
# 3     1004            100                Cheese, blue          NaN
# 4     1005            100               Cheese, brick          NaN
#
#
# new table format
#    food_id  food_group_id            long_description             search_words
# 0     1001            100              Butter, salted         [butter, salted]
# 1     1002            100  Butter, whipped, with salt  [butter, whipped, salt]
# 2     1003            100       Butter oil, anhydrous  [butter, oil, anhydrou]
# 3     1004            100                Cheese, blue           [cheese, blue]
# 4     1005            100               Cheese, brick          [cheese, brick]

# %%
food_des[food_des["food_id"] == 2014]
# Out:
#      food_id  food_group_id    long_description          search_words
# 276     2014            200  Spices, cumin seed  [spice, cumin, seed]

# %% [markdown]
# #### drop the unwanted food groups

# %% [markdown]
# print("number of entries before full food groups dropping : ", len(food_des), "\n")
#
#
# #drop whole categories
# food_des = food_des[~food_des["food_group_id"].isin([300, 800, 1800, 2100, 2200, 2500, 3600])]
#
# print("number of entries before after food groups dropping : ", len(food_des), "\n")
#
# #drop parts of categories
#
# food_des = food_des[~((food_des["food_group_id"]==1400) & (~food_des['search_words'].apply(lambda x : "water" in x)))]
# food_des = food_des[~((food_des["food_group_id"]==400) & (food_des['search_words'].apply(lambda x : "dressing" in x)))]
# food_des = food_des[~((food_des["food_group_id"]==600) & (food_des['search_words'].apply(lambda x : "soup" in x)))]
# food_des = food_des[~((food_des["food_group_id"]==1900) & (food_des['search_words'].apply(lambda x : "baking" in x)))]
#
# print("number of entries after partial food groups dropping : ", len(food_des), "\n")

# %% [markdown]
# #### Drop lines with unwanted categories

# %% [markdown]
# #define categories
# type_1_categories = set(["cooked", "roasted", "boiled", "grilled", "braised",
#                      "ready-to-serve", "fried", "baked", "pan-fried", "oven-roasted"])
#
# print("items count before type 1 deletion : ", len(food_des))
#
# #delete items that have type 1 categories
# food_des = food_des[food_des['search_words'].apply(lambda x : len(set(x).intersection(type_1_categories)) == 0)]
#
# print("items count after type 1 deletion : ", len(food_des))

# %% [markdown]
# #### define a search function for mapping recipes ingredients

# %%
def search_ingredient(ingredient, print_search_candidates=False) :
    
    #do not penalize the presence of those words, 'table' is for the salt
    non_complexificators = set(["fresh", "raw", "skin", "peel", "whole"])
    
    def search_score(categories, ing_words) :
        
        # singularize search words
        ing_words = set([singularize_word(x) for x in ing_words])
        
        #prioritize matching query terms
        nb_matching = len(ing_words.intersection(set(categories)))
        
        #non_complexificators should not be penalized,ignore them AFTER computing number of matching words
        categories = [c for c in categories if (c not in non_complexificators)]
        
        
        #matching keywords one by one 
        matching = [len(set([x]).intersection(ing_words)) != 0 for x in categories]
            
        
        #first keywords are more important
        weights = np.linspace(2, 1, num=len(matching))
        weights = weights / sum(weights)
        
        #the query should have as many ingredients words as possible
        score = (10 * nb_matching) + sum([c[0] * c[1] for c in zip(matching, weights)])
        
        return score
    
    
    ing_words = set(ingredient.split(" "))       
    
    #compute search score for each entry and sort them by score (descending order)
    food_des["search_score"] = food_des["search_words"].apply(lambda x : search_score(x, ing_words))  
    food_des_sorted = food_des.sort_values(by=['search_score'], ascending=False)

    #print best candidates
    if print_search_candidates :
        print(food_des_sorted.head())

    #best score
    result = food_des_sorted[["food_id", "search_words", "search_score"]].head(1)        

    #check if we found a positive score
    if result["search_score"].values[0] != 0 :
        return result, result["search_score"].values[0]
    else :
        return None, 0
    
    
" ".join(search_ingredient("asparagus", print_search_candidates=True)[0]['search_words'].values[0])
# Out:
#       food_id  food_group_id                               long_description  \
# 2439    11011           1100                                 Asparagus, raw
# 2443    11018           1100                  Asparagus, frozen, unprepared
# 2442    11015           1100              Asparagus, canned, drained solids
# 2440    11012           1100             Asparagus, cooked, boiled, drained
# 2936    11705           1100  Asparagus, cooked, boiled, drained, with salt
#
#                                    search_words  search_score
# 2439                            [asparagu, raw]     11.000000
# 2443             [asparagu, frozen, unprepared]     10.444444
# 2442         [asparagu, canned, drained, solid]     10.333333
# 2440        [asparagu, cooked, boiled, drained]     10.333333
# 2936  [asparagu, cooked, boiled, drained, salt]     10.266667
# 'asparagu raw'

# %%
at_least_one_ingredients_ids = {}
all_ingredients_ids = {}
total_ing_count = 0
mapped_at_least_one_ing_count = 0
mapped_all_ing_count = 0
ingredients = json.load(open("./../generated/ingredients_count.json"))['count']

for k, v in tqdm.tqdm(ingredients.items()) :
    #print(k, v)
    cats, score = search_ingredient(k, print_search_candidates=False)
    total_ing_count += v
    
    #we found at list one matching word
    if score >= 10 :
        mapped_at_least_one_ing_count += v
        at_least_one_ingredients_ids[k] = int(cats['food_id'].values[0])
        
    if score >= 10 * len(k.split(" ")) :
        mapped_all_ing_count += v
        all_ingredients_ids[k] = int(cats['food_id'].values[0])
                         
        
#save mapping
json.dump(at_least_one_ingredients_ids, open("./../generated/ing_usda_mapping_low_score.json", 'w'))
json.dump(all_ingredients_ids, open("./../generated/ing_usda_mapping_high_score.json", 'w'))
# Out:
# 100%|██████████| 5127/5127 [1:17:34<00:00,  1.22it/s]

# %% [markdown]
# > Good, the mapping is done ! How many ingredients were we able to map effectively ?

# %%
print_bold("{0:.2f}".format(100 * len(all_ingredients_ids) / len(ingredients)) + "% of ingredients were mapped succesfully (all words matched)")
print_bold("{0:.2f}".format(100 * len(at_least_one_ingredients_ids) / len(ingredients)) + "% of ingredients were mapped succesfully (at least one word matched)")
# Out:
# 32.05% of ingredients were mapped succesfully (all words matched)
# 89.82% of ingredients were mapped succesfully (at least one word matched)

# %% [markdown]
# > It occurs that some ingredients are much more common that others, thus, it is more important to map those ingredients than to map the less frequent ones. What if we weight the success rate given the number of times the ingredients appear in recipes ?

# %%
print_bold("high score : you have {0:.2f}".format(100 * mapped_all_ing_count / total_ing_count) + "% of chance to find a matching database entry for any recipe ingredients entry")
print_bold("low score  : you have {0:.2f}".format(100 * mapped_at_least_one_ing_count / total_ing_count) + "% of chance to find a matching database entry for any recipe ingredients entry")
# Out:
# high score : you have 79.36% of chance to find a matching database entry for any recipe ingredients entry
# low score  : you have 97.43% of chance to find a matching database entry for any recipe ingredients entry

# %% [markdown]
# > Pretty good, but it is not worth a lot if we have a low-quality mapping. What are the mappings for the most frequent ingredients ?

# %%
#load mappings
low_mapping = json.load(open("./../generated/ing_usda_mapping_low_score.json"))
high_mapping = json.load(open("./../generated/ing_usda_mapping_high_score.json"))

#evaluate low_score mapping
[(c, food_des[food_des['food_id'] == low_mapping[c]]['long_description'].values[0]) for c in low_mapping][:20]
# Out:
# [('salt', 'Salt, table'),
#  ('onion', 'Onions, raw'),
#  ('butter', 'Butter, without salt'),
#  ('water', 'Water, bottled, generic'),
#  ('egg', 'Egg, whole, raw, fresh'),
#  ('sugar', 'Sugar, turbinado'),
#  ('black pepper', 'Spices, pepper, black'),
#  ('olive oil', 'Oil, olive, salad or cooking'),
#  ('pepper', 'Peppers, hungarian, raw'),
#  ('garlic', 'Garlic, raw'),
#  ('all-purpose flour', 'Wheat flour, white, all-purpose, unenriched'),
#  ('tomato', 'Tomatoes, orange, raw'),
#  ('milk', 'Milk, producer, fluid, 3.7% milkfat'),
#  ('garlic clove', 'Garlic, raw'),
#  ('vegetable oil', 'Oil, vegetable, soybean, refined'),
#  ('cilantro', 'Coriander (cilantro) leaves, raw'),
#  ('parsley', 'Parsley, fresh'),
#  ('vanilla', 'Vanilla extract'),
#  ('ginger', 'Ginger root, raw'),
#  ('lemon juice', 'Lemon juice, raw')]

# %% [markdown]
# > The results are good enough, let's just correct the tomato and milk mappings not to feel guilty

# %%
# investigate the tomato entries
food_des[food_des['search_words'].apply(lambda x : 'tomato' in x)]
# Out:
#       food_id  food_group_id  \
# 352      3044            300
# 353      3045            300
# 354      3046            300
# 358      3050            300
# 359      3051            300
# 1222     6061            600
# 1224     6063            600
# 1258     6158            600
# 1259     6159            600
# 1301     6358            600
# 1302     6359            600
# 1303     6377            600
# 1334     6461            600
# 1335     6463            600
# 1347     6498            600
# 1351     6558            600
# 1352     6559            600
# 1382     6956            600
# 1390     6964            600
# 1398     6972            600
# 2836    11527           1100
# 2837    11529           1100
# 2838    11530           1100
# 2839    11531           1100
# 2840    11533           1100
# 2841    11537           1100
# 2842    11540           1100
# 2843    11546           1100
# 2844    11547           1100
# 2845    11548           1100
# ...       ...            ...
# 6165    21152           2100
# 6166    21153           2100
# 6167    21154           2100
# 6168    21155           2100
# 6169    21156           2100
# 6172    21159           2100
# 6173    21160           2100
# 6174    21161           2100
# 6175    21162           2100
# 6177    21207           2100
# 6178    21209           2100
# 6179    21210           2100
# 6180    21211           2100
# 6181    21213           2100
# 6182    21214           2100
# 6354    21461           2100
# 6355    21462           2100
# 6381    21490           2100
# 6419    22402           2200
# 6420    22522           2200
# 6426    22900           2200
# 6436    22912           2200
# 6437    22914           2200
# 6462    22976           2200
# 7118    27048            600
# 7267    32021           2200
# 7689    43217           1100
# 7714    43331            400
# 7722    43365           1100
# 7743    43432            300
#
#                                        long_description  \
# 352   Babyfood, dinner, macaroni and tomato and beef...
# 353   Babyfood, dinner, macaroni and tomato and beef...
# 354   Babyfood, ravioli, cheese filled, with tomato ...
# 358   Babyfood, dinner, spaghetti and tomato and mea...
# 359   Babyfood, dinner, spaghetti and tomato and mea...
# 1222   Soup, tomato beef with noodle, canned, condensed
# 1224               Soup, tomato rice, canned, condensed
# 1258             Soup, tomato bisque, canned, condensed
# 1259                    Soup, tomato, canned, condensed
# 1301  Soup, tomato bisque, canned, prepared with equ...
# 1302  Soup, tomato, canned, prepared with equal volu...
# 1303                 CAMPBELL'S, Tomato Soup, condensed
# 1334  Soup, tomato beef with noodle, canned, prepare...
# 1335  Soup, tomato rice, canned, prepared with equal...
# 1347        Soup, tomato, dry, mix, prepared with water
# 1351  Soup, tomato bisque, canned, prepared with equ...
# 1352  Soup, tomato, canned, prepared with equal volu...
# 1382    Soup, tomato, canned, condensed, reduced sodium
# 1390               Soup, tomato, low sodium, with water
# 1398      Sauce, tomato chili sauce, bottled, with salt
# 2836                               Tomatoes, green, raw
# 2837       Tomatoes, red, ripe, raw, year round average
# 2838                        Tomatoes, red, ripe, cooked
# 2839  Tomatoes, red, ripe, canned, packed in tomato ...
# 2840                Tomatoes, red, ripe, canned, stewed
# 2841    Tomatoes, red, ripe, canned, with green chilies
# 2842              Tomato juice, canned, with salt added
# 2843  Tomato products, canned, paste, without salt a...
# 2844  Tomato products, canned, puree, without salt a...
# 2845                                      Tomato powder
# ...                                                 ...
# 6165  SUBWAY, SUBWAY CLUB sub on white bread with le...
# 6166  Fast foods, submarine sandwich, turkey, roast ...
# 6167  Fast foods, submarine sandwich, oven roasted c...
# 6168  Fast foods, submarine sandwich, turkey breast ...
# 6169  Fast foods, submarine sandwich, ham on white b...
# 6172  SUBWAY, steak & cheese sub on white bread with...
# 6173  Fast foods, submarine sandwich, steak and chee...
# 6174  SUBWAY, B.L.T. sub on white bread with bacon, ...
# 6175  Fast foods, submarine sandwich, bacon, lettuce...
# 6177  SUBWAY, turkey breast sub on white bread with ...
# 6178  SUBWAY, black forest ham sub on white bread wi...
# 6179  SUBWAY, roast beef sub on white bread with let...
# 6180  SUBWAY, oven roasted chicken sub on white brea...
# 6181  SUBWAY, cold cut sub on white bread with lettu...
# 6182  SUBWAY, tuna sub on white bread with lettuce a...
# 6354  Fast foods, grilled chicken, bacon and tomato ...
# 6355  Fast foods, crispy chicken, bacon, and tomato ...
# 6381  Fast Foods, grilled chicken filet sandwich, wi...
# 6419  Beef macaroni with tomato sauce, frozen entree...
# 6420  Pasta with Sliced Franks in Tomato Sauce, cann...
# 6426  Ravioli, meat-filled, with tomato sauce or mea...
# 6436  Spaghetti, with meatballs in tomato sauce, canned
# 6437           Pasta with tomato sauce, no meat, canned
# 6462  Ravioli, cheese with tomato sauce, frozen, not...
# 7118                         Sauce, steak, tomato based
# 7267  Spanish rice mix, dry mix, prepared (with cano...
# 7689                Tomato sauce, canned, no salt added
# 7714                   Salad dressing, bacon and tomato
# 7722             Tomato and vegetable juice, low sodium
# 7743  Babyfood, dinner, macaroni, beef and tomato sa...
#
#                                            search_words  search_score
# 352   [babyfood, dinner, macaroni, and, tomato, and,...      0.000000
# 353   [babyfood, dinner, macaroni, and, tomato, and,...      0.000000
# 354   [babyfood, ravioli, cheese, filled, tomato, sa...     10.177778
# 358   [babyfood, dinner, spaghetti, and, tomato, and...      0.000000
# 359   [babyfood, dinner, spaghetti, and, tomato, and...      0.000000
# 1222    [soup, tomato, beef, noodle, canned, condensed]      0.000000
# 1224            [soup, tomato, rice, canned, condensed]      0.000000
# 1258          [soup, tomato, bisque, canned, condensed]      0.000000
# 1259                  [soup, tomato, canned, condensed]      0.000000
# 1301  [soup, tomato, bisque, canned, prepared, equal...      0.000000
# 1302  [soup, tomato, canned, prepared, equal, volume...      0.000000
# 1303               [campbell', tomato, soup, condensed]      0.000000
# 1334  [soup, tomato, beef, noodle, canned, prepared,...      0.000000
# 1335  [soup, tomato, rice, canned, prepared, equal, ...      0.000000
# 1347          [soup, tomato, dry, mix, prepared, water]      0.000000
# 1351  [soup, tomato, bisque, canned, prepared, equal...      0.000000
# 1352  [soup, tomato, canned, prepared, equal, volume...      0.000000
# 1382  [soup, tomato, canned, condensed, reduced, sod...      0.000000
# 1390                 [soup, tomato, low, sodium, water]      0.000000
# 1398       [sauce, tomato, chili, sauce, bottled, salt]      0.000000
# 2836                               [tomato, green, raw]      0.000000
# 2837     [tomato, red, ripe, raw, year, round, average]      0.000000
# 2838                        [tomato, red, ripe, cooked]      0.000000
# 2839  [tomato, red, ripe, canned, packed, in, tomato...      0.000000
# 2840                [tomato, red, ripe, canned, stewed]      0.000000
# 2841          [tomato, red, ripe, canned, green, chily]      0.000000
# 2842               [tomato, juice, canned, salt, added]      0.000000
# 2843                   [tomato, product, canned, paste]      0.000000
# 2844                   [tomato, product, canned, puree]      0.000000
# 2845                                   [tomato, powder]      0.000000
# ...                                                 ...           ...
# 6165  [subway, subway, club, sub, on, white, bread, ...      0.000000
# 6166  [fast, food, submarine, sandwich, turkey, roas...      0.000000
# 6167  [fast, food, submarine, sandwich, oven, roaste...      0.000000
# 6168  [fast, food, submarine, sandwich, turkey, brea...      0.000000
# 6169  [fast, food, submarine, sandwich, ham, on, whi...      0.000000
# 6172  [subway, steak, &, cheese, sub, on, white, bre...     10.153846
# 6173  [fast, food, submarine, sandwich, steak, and, ...     10.131868
# 6174  [blt, subway, b.l.t., sub, on, white, bread, b...      0.000000
# 6175  [blt, fast, food, submarine, sandwich, bacon, ...      0.000000
# 6177  [subway, turkey, breast, sub, on, white, bread...      0.000000
# 6178  [subway, black, forest, ham, sub, on, white, b...      0.000000
# 6179  [subway, roast, beef, sub, on, white, bread, l...      0.000000
# 6180  [subway, oven, roasted, chicken, sub, on, whit...      0.000000
# 6181  [subway, cold, cut, sub, on, white, bread, let...      0.000000
# 6182  [subway, tuna, sub, on, white, bread, lettuce,...      0.000000
# 6354  [fast, food, grilled, chicken, bacon, and, tom...     10.064103
# 6355  [fast, food, crispy, chicken, bacon, and, toma...     10.064103
# 6381  [fast, food, grilled, chicken, filet, sandwich...      0.000000
# 6419  [beef, macaroni, tomato, sauce, frozen, entree...      0.000000
# 6420  [pasta, sliced, frank, in, tomato, sauce, cann...      0.000000
# 6426  [ravioli, meat-filled, tomato, sauce, or, meat...      0.000000
# 6436   [spaghetti, meatball, in, tomato, sauce, canned]      0.000000
# 6437                     [pasta, tomato, sauce, canned]      0.000000
# 6462  [ravioli, cheese, tomato, sauce, frozen, not, ...     10.106061
# 7118                      [sauce, steak, tomato, based]      0.000000
# 7267  [spanish, rice, mix, dry, mix, prepared, canol...      0.000000
# 7689                            [tomato, sauce, canned]      0.000000
# 7714              [salad, dressing, bacon, and, tomato]      0.000000
# 7722       [tomato, and, vegetable, juice, low, sodium]      0.000000
# 7743  [babyfood, dinner, macaroni, beef, and, tomato...      0.000000
#
# [86 rows x 5 columns]

# %%
# investigate the milk entries
food_des[food_des['search_words'].apply(lambda x : 'milk' in x)]
# Out:
#       food_id  food_group_id  \
# 25       1026            100
# 26       1027            100
# 27       1028            100
# 35       1036            100
# 36       1037            100
# 57       1059            100
# 58       1060            100
# 66       1071            100
# 70       1076            100
# 71       1077            100
# 72       1078            100
# 73       1079            100
# 74       1080            100
# 75       1081            100
# 76       1082            100
# 77       1083            100
# 78       1084            100
# 79       1085            100
# 80       1086            100
# 81       1087            100
# 82       1088            100
# 83       1089            100
# 84       1090            100
# 85       1091            100
# 86       1092            100
# 87       1093            100
# 88       1094            100
# 89       1095            100
# 90       1096            100
# 91       1097            100
# ...       ...            ...
# 5689    19214           1900
# 5693    19219           1900
# 5695    19221           1900
# 5697    19223           1900
# 5703    19231           1900
# 5704    19232           1900
# 5708    19236           1900
# 5718    19249           1900
# 5720    19252           1900
# 5721    19254           1900
# 5723    19256           1900
# 5735    19279           1900
# 5760    19319           1900
# 5762    19321           1900
# 5764    19323           1900
# 5766    19325           1900
# 5771    19331           1900
# 5901    19896           1900
# 6317    21412           2100
# 6451    22960           2200
# 7056    25009           2500
# 7065    25020           2500
# 7209    28359           1800
# 7581    42131           1900
# 7586    42139           2500
# 7602    42185           1900
# 7605    42189            100
# 7636    42290            100
# 7725    43369           1400
# 7764    43543            100
#
#                                        long_description  \
# 25                       Cheese, mozzarella, whole milk
# 26         Cheese, mozzarella, whole milk, low moisture
# 27                   Cheese, mozzarella, part skim milk
# 35                          Cheese, ricotta, whole milk
# 36                      Cheese, ricotta, part skim milk
# 57    Milk, filled, fluid, with blend of hydrogenate...
# 58            Milk, filled, fluid, with lauric acid oil
# 66    Dessert topping, powdered, 1.5 ounce prepared ...
# 70        Milk substitutes, fluid, with lauric acid oil
# 71     Milk, whole, 3.25% milkfat, with added vitamin D
# 72                  Milk, producer, fluid, 3.7% milkfat
# 73    Milk, reduced fat, fluid, 2% milkfat, with add...
# 74    Milk, reduced fat, fluid, 2% milkfat, with add...
# 75    Milk, reduced fat, fluid, 2% milkfat, protein ...
# 76    Milk, lowfat, fluid, 1% milkfat, with added vi...
# 77    Milk, lowfat, fluid, 1% milkfat, with added no...
# 78    Milk, lowfat, fluid, 1% milkfat, protein forti...
# 79    Milk, nonfat, fluid, with added vitamin A and ...
# 80    Milk, nonfat, fluid, with added nonfat milk so...
# 81    Milk, nonfat, fluid, protein fortified, with a...
# 82            Milk, buttermilk, fluid, cultured, lowfat
# 83                              Milk, low sodium, fluid
# 84               Milk, dry, whole, with added vitamin D
# 85    Milk, dry, nonfat, regular, without added vita...
# 86    Milk, dry, nonfat, instant, with added vitamin...
# 87                   Milk, dry, nonfat, calcium reduced
# 88                              Milk, buttermilk, dried
# 89                   Milk, canned, condensed, sweetened
# 90    Milk, canned, evaporated, with added vitamin D...
# 91    Milk, canned, evaporated, nonfat, with added v...
# ...                                                 ...
# 5689    Rennin, vanilla, dry mix, prepared with 2% milk
# 5693  Puddings, coconut cream, dry mix, regular, pre...
# 5695  Rennin, chocolate, dry mix, prepared with whol...
# 5697  Rennin, vanilla, dry mix, prepared with whole ...
# 5703  Flan, caramel custard, dry mix, prepared with ...
# 5704  Flan, caramel custard, dry mix, prepared with ...
# 5708  Candies, HERSHEY'S MILK CHOCOLATE WITH ALMOND ...
# 5718  Candies, HERSHEY, REESESTICKS crispy wafers, p...
# 5720  Candies, REESE'S, FAST BREAK, milk chocolate p...
# 5721    Candies, MARS SNACKFOOD US, DOVE Milk Chocolate
# 5723  Candies, MARS SNACKFOOD US, MILKY WAY Caramels...
# 5735        Candies, milk chocolate coated coffee beans
# 5760  Puddings, banana, dry mix, instant, prepared w...
# 5762  Puddings, banana, dry mix, regular, prepared w...
# 5764  Puddings, coconut cream, dry mix, instant, pre...
# 5766  Puddings, coconut cream, dry mix, regular, pre...
# 5771  Puddings, lemon, dry mix, instant, prepared wi...
# 5901  Candies, REESE's Fast Break, milk chocolate, p...
# 6317  Light Ice Cream, soft serve, blended with milk...
# 6451  Macaroni and cheese, dry mix, prepared with 2%...
# 7056  Snacks, M&M MARS, KUDOS Whole Grain Bar, M&M's...
# 7065  Formulated bar, SLIM-FAST OPTIMA meal bar, mil...
# 7209        Glutino, Gluten Free Wafers, Milk Chocolate
# 7581     Milk dessert, frozen, milk-fat free, chocolate
# 7586  Granola bar, soft, milk chocolate coated, pean...
# 7602  Frozen yogurts, chocolate, nonfat milk, sweete...
# 7605     Milk, buttermilk, fluid, cultured, reduced fat
# 7636  Milk, fluid, nonfat, calcium fortified (fat fr...
# 7725  Beverages, Chocolate-flavored drink, whey and ...
# 7764                           Milk, imitation, non-soy
#
#                                            search_words  search_score
# 25                    [cheese, mozzarella, whole, milk]     10.444444
# 26     [cheese, mozzarella, whole, milk, low, moisture]     10.266667
# 27               [cheese, mozzarella, part, skim, milk]     10.266667
# 35                       [cheese, ricotta, whole, milk]     10.444444
# 36                  [cheese, ricotta, part, skim, milk]     10.266667
# 57    [milk, filled, fluid, blend, of, hydrogenated,...      0.000000
# 58             [milk, filled, fluid, lauric, acid, oil]      0.000000
# 66    [dessert, topping, powdered, 1.5, ounce, prepa...      0.000000
# 70         [milk, substitute, fluid, lauric, acid, oil]      0.000000
# 71     [milk, whole, 3.25%, milkfat, added, vitamin, d]      0.000000
# 72               [milk, producer, fluid, 3.7%, milkfat]      0.000000
# 73    [milk, reduced, fat, fluid, 2%, milkfat, added...      0.000000
# 74    [milk, reduced, fat, fluid, 2%, milkfat, added...      0.000000
# 75    [milk, reduced, fat, fluid, 2%, milkfat, prote...      0.000000
# 76    [milk, lowfat, fluid, 1%, milkfat, added, vita...      0.000000
# 77    [milk, lowfat, fluid, 1%, milkfat, added, nonf...      0.000000
# 78    [milk, lowfat, fluid, 1%, milkfat, protein, fo...      0.000000
# 79    [milk, nonfat, fluid, added, vitamin, a, and, ...      0.000000
# 80    [milk, nonfat, fluid, added, nonfat, milk, sol...      0.000000
# 81    [milk, nonfat, fluid, protein, fortified, adde...      0.000000
# 82          [milk, buttermilk, fluid, cultured, lowfat]      0.000000
# 83                           [milk, low, sodium, fluid]      0.000000
# 84                [milk, dry, whole, added, vitamin, d]      0.000000
# 85                         [milk, dry, nonfat, regular]      0.000000
# 86    [milk, dry, nonfat, instant, added, vitamin, a...      0.000000
# 87                [milk, dry, nonfat, calcium, reduced]      0.000000
# 88                            [milk, buttermilk, dried]      0.000000
# 89                 [milk, canned, condensed, sweetened]      0.000000
# 90                           [milk, canned, evaporated]      0.000000
# 91    [milk, canned, evaporated, nonfat, added, vita...      0.000000
# ...                                                 ...           ...
# 5689    [rennin, vanilla, dry, mix, prepared, 2%, milk]      0.000000
# 5693  [pudding, coconut, cream, dry, mix, regular, p...      0.000000
# 5695  [rennin, chocolate, dry, mix, prepared, whole,...      0.000000
# 5697  [rennin, vanilla, dry, mix, prepared, whole, m...      0.000000
# 5703  [flan, caramel, custard, dry, mix, prepared, 2...      0.000000
# 5704  [flan, caramel, custard, dry, mix, prepared, w...      0.000000
# 5708   [candy, hershey', milk, chocolate, almond, bite]      0.000000
# 5718  [candy, hershey, reesestick, crispy, wafer, pe...      0.000000
# 5720  [candy, reese', fast, break, milk, chocolate, ...      0.000000
# 5721  [candy, mar, snackfood, me, dove, milk, chocol...      0.000000
# 5723  [candy, mar, snackfood, me, milky, way, carame...      0.000000
# 5735     [candy, milk, chocolate, coated, coffee, bean]      0.000000
# 5760  [pudding, banana, dry, mix, instant, prepared,...      0.000000
# 5762  [pudding, banana, dry, mix, regular, prepared,...      0.000000
# 5764  [pudding, coconut, cream, dry, mix, instant, p...      0.000000
# 5766  [pudding, coconut, cream, dry, mix, regular, p...      0.000000
# 5771  [pudding, lemon, dry, mix, instant, prepared, ...      0.000000
# 5901  [candy, reese', fast, break, milk, chocolate, ...      0.000000
# 6317  [light, ice, cream, soft, serve, blended, milk...      0.000000
# 6451  [macaroni, and, cheese, dry, mix, prepared, 2%...     10.082540
# 7056  [snack, m&m, mar, kudo, whole, grain, bar, m&m...      0.000000
# 7065  [formulated, bar, slim-fast, optima, meal, bar...      0.000000
# 7209    [glutino, gluten, free, wafer, milk, chocolate]      0.000000
# 7581  [milk, dessert, frozen, milk-fat, free, chocol...      0.000000
# 7586  [granola, bar, soft, milk, chocolate, coated, ...      0.000000
# 7602          [frozen, yogurt, chocolate, nonfat, milk]      0.000000
# 7605  [milk, buttermilk, fluid, cultured, reduced, fat]      0.000000
# 7636  [milk, fluid, nonfat, calcium, fortified, fat,...      0.000000
# 7725  [beverage, chocolate-flavored, drink, whey, an...      0.000000
# 7764                         [milk, imitation, non-soy]      0.000000
#
# [209 rows x 5 columns]

# %%
low_mapping['milk']   = 1078
low_mapping['tomato'] = 11695

#save corrected mapping
json.dump(low_mapping, open("./../generated/ing_usda_mapping_low_score.json", 'w'))

# %% [markdown]
# #### save the long_description for food items description purposes

# %%
id_describe = dict()

all_ids = list(set([low_mapping[c] for c in low_mapping]).union([high_mapping[c] for c in high_mapping]))
for index in tqdm.tqdm(all_ids) :
    id_describe[index] = food_des[food_des['food_id'] == index]['long_description'].values[0]
    
print(len(id_describe))
json.dump(id_describe, open("./../generated/usda_id_describe.json", 'w'))
# Out:
# 100%|██████████| 1530/1530 [00:00<00:00, 2338.99it/s]
# 1530

# %% [markdown]
# # nutrient and RDI linking

# %% [markdown]
# #### import RDI values

# %%
rdi = pd.read_excel("./../data/RDI.xlsx")
rdi_nutrients = rdi['nutrient'].values
rdi_nutrients

# %% [markdown]
# #### Load and filter Nutrient definition

# %%
use_cols = [0, 1, 2, 3]

columns = ["nutrient_id", "units", "tagname", "description"]

nut_def = pd.read_csv(nut_def_path, sep="^", encoding="ISO-8859-1", names=columns, usecols=use_cols, header=None)

nut_def.head(5)

# %% [markdown]
# #### map rdi values with corresponding USDA nutrients

# %%
#try to map rdi elements with database elements automatically
mapping = {}
still_unmapped = list(rdi_nutrients)

for r in rdi_nutrients :
    
    mapped_count = 0
    sev_des = []
    
    for des in nut_def['description'].values :
        if ((r in des) or (des in r)) :
            
            sev_des.append(des)
            mapped_count += 1
            
            
    if mapped_count == 1 :
        mapping[r] = sev_des[0]
        still_unmapped.remove(r)
    
    elif mapped_count > 1:
        print("\nconflict for ", r , " : ")
        [print("\t- ", c) for c in sev_des]
        print("\n")
            
    else :
        print("No mapping for ", r)

print_bold("mapping found for the following nutrients : ")
mapping

# %%
# solve conficlts manually
mapping['Folate'] = "Folate, total"
mapping['Vitamin A'] = "Vitamin A, RAE"
mapping['Vitamin D'] = "Vitamin D (D2 + D3)"
mapping["Vitamin E"] = "Vitamin E (alpha-tocopherol)"
mapping["Monounsaturated fat"] = "Fatty acids, total monounsaturated"
mapping["Polyunsaturated fat"] = "Fatty acids, total polyunsaturated"
mapping["Saturated fat"] = "Fatty acids, total saturated"
mapping['alpha-linoleic acid'] = "Alanine"
mapping["Vitamin B6"] = "Vitamin B-6"
mapping["Vitamin B12"] = "Vitamin B-12"
mapping['Fat'] = "Total lipid (fat)"

#we do not want to keep the USDA name, change it in the database
mapping['Linoleic acid'] = "Linoleic acid"
nut_def["description"] = nut_def["description"].replace("18:2 undifferentiated", "Linoleic acid")



conflicts_solved = ["Folate", "Vitamin A", "Vitamin D", "Vitamin E", "Saturated fat",
                   "Monounsaturated fat", "Polyunsaturated fat", "alpha-linoleic acid",
                   "Vitamin B6", "Vitamin B12", "Fat", "Linoleic acid"]

still_unmapped = [su for su in still_unmapped if (su not in conflicts_solved)]


print_bold("no mapping found for the following nutrients : ")

still_unmapped

# %% [markdown]
# #### change elements names in rdi data, add nutrient_id column

# %%
# change rdi elements names
rdi['nutrient'] = rdi['nutrient'].apply(lambda x : mapping[x] if x in mapping.keys() else x)
rdi = rdi[~(rdi['nutrient'].apply(lambda x : x in still_unmapped))]
rdi.set_index("nutrient", inplace=True)

#add nutrient_id column
#rdi["nutrient_id"] = rdi['element'].apply(lambda x : nut_def[nut_def['description'] == x]['nutrient_id'].values[0])

rdi.head()

#filter nut_def to keep only mapped elements
nut_def = nut_def[nut_def['description'].apply(lambda x : x in rdi.index.values)]

# %% [markdown]
# #### change RDI values to match USDA units

# %%
def change_value(unit, value) :
    
    if unit == 'mg' or unit == 'IU' :
        return value

    elif unit == 'g' :
        return (float(value) / 1000)
    
    else :
        return (float(value) * 1000)

    
new_male_rdis = []
new_female_rdis = []

for n in rdi.index.values :
    unit = nut_def[nut_def['description'] == n]['units'].values[0]
    male_rdi = rdi.loc[n]['Male_RDI(19-30)']
    female_rdi = rdi.loc[n]['Female_RDI(19-30)']
    new_male_rdis.append(change_value(unit, male_rdi))
    new_female_rdis.append(change_value(unit, female_rdi))
                  
    
#change values
rdi['Male_RDI(19-30)'] = pd.Series(new_male_rdis).values
rdi['Female_RDI(19-30)'] = pd.Series(new_female_rdis).values

#save new RDI file as csv
rdi.to_csv("./../generated/matching_rdi.csv")

rdi

# %% [markdown]
# # load and filter nutrient data

# %% [markdown]
# #### load nutrient data

# %%
use_cols = [0, 1, 2]

columns = ["food_id", "nutrient_id", "nutr_per_100g"]

nut_data = pd.read_csv(nut_data_path, sep="^", encoding="ISO-8859-1", names=columns, usecols=use_cols, header=None)

nut_data.head()

# %% [markdown]
# #### keep only nutrients that are included in RDI

# %%
print_bold("length before filtering : " + str(len(nut_data)))

#drop non-exploitable lines
nut_data = nut_data[nut_data['nutrient_id'].apply(lambda x : x in nut_def['nutrient_id'].values)]

print_bold("length after filtering : " + str(len(nut_data)))

#replace id by name to have more convenient reading
nut_data['nutrient'] = nut_data['nutrient_id'].apply(lambda x : nut_def[nut_def['nutrient_id'] == x]['description'].values[0])
nut_data = nut_data.drop("nutrient_id", axis=1)

# %% [markdown]
# #### keep only ids matching ingredients

# %%
m = json.load(open("./../generated/ing_usda_mapping.json"))
matching_ids = [str(m[k]) for k in m]

print_bold("length before filtering : " + str(len(nut_data)))

#apply filtering
nut_data = nut_data[nut_data['food_id'].apply( lambda x : str(x) in matching_ids)]

print_bold("length after filtering : " + str(len(nut_data)))

# %%
#what average percentage of info do we have per mapped food ?
perc = 100 * nut_data.groupby('food_id').count().mean()[0] / len(rdi)
print_bold("percentage of available nutritional information : " + str(perc))

# %% [markdown]
# > Pretty nice !

# %% [markdown]
# #### add rdi percentage columns

# %%
nut_data["percentage_male_rdi"] = nut_data.apply(lambda row : 100*row['nutr_per_100g'] / rdi.loc[row['nutrient']]['Male_RDI(19-30)'], axis=1)
nut_data["percentage_female_rdi"] = nut_data.apply(lambda row : 100*row['nutr_per_100g'] / rdi.loc[row['nutrient']]['Female_RDI(19-30)'], axis=1)
nut_data.head()

# %% [markdown]
# #### pivot table to facilitate search by food id, save the resulting dataframe

# %%
#pivot table
nut_data = nut_data.pivot(index='food_id', columns='nutrient', values=['nutr_per_100g', 'percentage_male_rdi', 'percentage_female_rdi'])

#save table using h5 (easier for multi-index table storage)
nut_data.to_hdf('./../generated/nut_data.h5','table', append=True)

# %%
#check that the storage went fine
a = pd.read_hdf('./../generated/nut_data.h5', 'table', where=['index>2'])
nut_data.loc[1003]['percentage_male_rdi']
